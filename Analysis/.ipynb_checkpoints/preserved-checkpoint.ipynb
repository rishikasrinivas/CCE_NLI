# %%
#preserved concepts
import concept_getters
import pandas as pd
import re
SPARSITY_RATIOS_LTH = [0.0, 20.0, 36.0, 48.8, 59.04, 67.232, 73.786, 79.028, 83.223, 86.578, 89.263, 91.41, 93.128, 94.502]
SPARSITY_RATIOS_WANDA = [0.0, 19.987, 35.97, 48.796, 59.017, 67.22, 73.763, 79.004, 83.203, 86.556, 89.258, 91.406, 93.099, 94.499]

import collections

def get_indiv_concepts_per_unit(df) -> dict:
    concepts = {}
    for unit,expl in zip(df.unit, df.best_name):
        concps = re.findall(r'(?<!\bNOT\s)(?:\b(?:hyp|pre|oth):[^\s)]+)', expl)
        for i in range(len(concps)):
            while concps[i][-1] == ')':
                concps[i] = concps[i][:-1]
        concepts[unit] = concps
    return concepts

def get_concepts_across_pruning_per_neuron(method, filename, sparsity_list):
    explanations = {}
    for sparsity in sparsity_list:
        cluster3_expls = pd.read_csv(f"/workspace/CCE_NLI/BERT/exp/{method}/{filename}/Expls/{sparsity}%Pruned/Cluster3IOUS1024N.csv")
        explanations[sparsity] = get_indiv_concepts_per_unit(cluster3_expls) 
    reordered = collections.defaultdict(dict)
    for sparsity, neurons in explanations.items():
        for neuron, concepts in neurons.items():
            reordered[neuron][sparsity] = concepts
    return reordered 

def get_concepts_assoc_sparsities(method, filename, sparsity_list):
    explanations = {}
    for sparsity in sparsity_list:
        cluster3_expls = pd.read_csv(f"/workspace/CCE_NLI/BERT/exp/{method}/{filename}/Expls/{sparsity}%Pruned/Cluster3IOUS1024N.csv")
        explanations[sparsity] = get_indiv_concepts_per_unit(cluster3_expls) 
    reordered = collections.defaultdict(lambda: collections.defaultdict(set))
    for sparsity, neurons in explanations.items():
        for neuron, concepts in neurons.items():
            for concept in concepts:
                reordered[neuron][concept].add(sparsity)
    return reordered

# %%
def count_frequencies(concepts_dict, neuron):
    concept_freq = []
    for list_of_concepts in concepts_dict[neuron].values():
        concept_freq.extend(list_of_concepts)
    concept_freq = collections.Counter(concept_freq)
    return {concept: freq for concept, freq in concept_freq.items() if freq > 5}
        
unique_concepts =set()
def num_unique_concepts_for_a_neuron(concepts_dict, neuron):
    concept_freq = []
    for list_of_concepts in concepts_dict[neuron].values():
        concept_freq.extend(list_of_concepts)
    concept_freq = collections.Counter(concept_freq)
    for concept in concept_freq:
        unique_concepts.add()
    return {concept: freq for concept, freq in concept_freq.items() if freq > 5}

# %%
list_of_repeated_concepts = set()

for neuron in reordered.keys():
    frequencies = count_frequencies(reordered,neuron)
    concepts = list(frequencies.keys())
    for c in concepts:
        list_of_repeated_concepts.add(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 list_of_repeated_concepts = set()
# ----> 3 for neuron in reordered.keys():
#       4     frequencies = count_frequencies(reordered,neuron)
#       5     concepts = list(frequencies.keys())
#
# NameError: name 'reordered' is not defined

# %%
len(list_of_repeated_concepts) 
#across all neurons and all iterations, 160 concepts repeat within a neuron at least 5 times 
#(meaning across 1024 neurons there are 106 uniue concepts where across pruning they are dominant 5/14 iterations ) 
#doesnt show whether they're dominant in begining/middle/end just that they're preserved 30% of iters for at least 1 neuron
# Out:
# 0

# %%
#graph for each neuron on avg how many concepts are repeated % of times
list_of_repeated_concepts = set()
unique = 0
for neuron in reordered.keys():
    frequencies = count_frequencies(reordered,neuron)
    num_u = num_unique_concepts_for_a_neuron(reordered,neuron)
    unique+=len(num_u)
    
    concepts = list(frequencies.keys())
num_u
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 list_of_repeated_concepts = set()
#       3 unique = 0
# ----> 4 for neuron in reordered.keys():
#       5     frequencies = count_frequencies(reordered,neuron)
#       6     num_u = num_unique_concepts_for_a_neuron(reordered,neuron)
#
# NameError: name 'reordered' is not defined

# %% [raw]
# neuron wise: % of concepts preserved for at least first k iters
#     at each neuron count how many concepts assoc w that neuron are preserved for first k iters
#     %of cocnepts preserved for at least first k iters by that neuron = that number / number of concepts originally explained by that neuron
#     sum that for all neurons and divide by number of neurons in original
#     save number for index k in list
#     plot list
#
# so for first 1 iters (ie only 1 iter 0.0%), should be 1.0 (all concepts are preserved for at least 1 iter)

# %%
import matplotlib.pyplot as plt

def get_num_concpets_explained_originally(method, filename):
    unique_concepts=set()
    explanations = {}
    cluster3_expls = pd.read_csv(f"/workspace/CCE_NLI/BERT/exp/{method}/{filename}/Expls/{0.0}%Pruned/Cluster3IOUS1024N.csv")
    all_concept_at_original = get_indiv_concepts_per_unit(cluster3_expls) 
    for neuron, concepts in all_concept_at_original.items():
        for concept in concepts:
            unique_concepts.add(concept)
    return len(unique_concepts) 



def dropoff(method, filename, k, **kwargs):
    if method == 'wanda':
        sparsity_list = SPARSITY_RATIOS_WANDA
    elif method == 'lottery_ticket':
        sparsity_list = SPARSITY_RATIOS_LTH
        
    num_orig_cps = kwargs['num_orig_cps']
    concept_and_assoc_sparsities = kwargs['concept_assoc_sparsity']
    sparsity_mapping = kwargs['neuron_concept_sparsity_mapping']
    percent_cocnepts_preserved=[]
    for neuron in sparsity_mapping.keys():
        concepts_preserved=set()
        for concept in concept_and_assoc_sparsities[neuron]:
            list_of_concepts_and_sprsty = list(concept_and_assoc_sparsities[neuron][concept])
            first_k_iters_present = sorted(list_of_concepts_and_sprsty)[:k]
            if first_k_iters_present == sparsity_list[:k]: #this concept is preserved for at lesat the first 6 iters
                concepts_preserved.add(concept)
        percent_cocnepts_preserved.append(len(concepts_preserved)/len(concept_and_assoc_sparsities[neuron]))
    return sum(percent_cocnepts_preserved)/len(percent_cocnepts_preserved)


dropoffs_lth = []
method = 'lottery_ticket'
filename = 'Run2Full'
sparsity_list = SPARSITY_RATIOS_LTH
for k in range(1,15):
    num_orig_cps = get_num_concpets_explained_originally(method, filename)
    neuron_concept_sparsity_mapping = get_concepts_across_pruning_per_neuron(method, filename,sparsity_list)
    concept_assoc_sparsity=get_concepts_assoc_sparsities(method, filename,sparsity_list)
    percent_of_concepts_preserved = dropoff(method, filename, k, num_orig_cps=num_orig_cps, concept_assoc_sparsity= concept_assoc_sparsity,neuron_concept_sparsity_mapping=neuron_concept_sparsity_mapping)
    dropoffs_lth.append(percent_of_concepts_preserved)
    
    
dropoffs_wanda = []
method = 'wanda'
filename = 'Run2Full'
sparsity_list = SPARSITY_RATIOS_WANDA
for k in range(1,15):
    num_orig_cps = get_num_concpets_explained_originally(method, filename)
    neuron_concept_sparsity_mapping = get_concepts_across_pruning_per_neuron(method, filename,sparsity_list)
    concept_assoc_sparsity=get_concepts_assoc_sparsities(method, filename,sparsity_list)
    percent_of_concepts_preserved = dropoff(method, filename, k, num_orig_cps=num_orig_cps, concept_assoc_sparsity= concept_assoc_sparsity,neuron_concept_sparsity_mapping=neuron_concept_sparsity_mapping)
    dropoffs_wanda.append(percent_of_concepts_preserved)
x=[SPARSITY_RATIOS_WANDA[i] for i in range(0,14)] 
plt.plot(x, dropoffs_lth, label='lth',color='blue', marker='o')
plt.plot(x, dropoffs_wanda, label='wanda',color='green', marker='x')
plt.title("neuron wise: % of concepts preserved for at least first k iters")
plt.xlabel("sparsities")
plt.ylabel("% of concepts preserved")
plt.legend()
plt.grid(True)

plt.show()

# %%
neuron wise: % of neurons that preserve concepts for at lesat first k iters
    at each neuron set = true if there exists 1 concept that is preserved in the first k iters at least
    return num neurons=true/num neurons total  
    savee this val at index k in list 
    plot list
# Out:
#   Cell In[7], line 1
#     neuron wise: % of neurons that preserve concepts for at lesat first k iters
#            ^
# SyntaxError: invalid syntax

# %%
import torch
def get_neurons_explained_originally(method, filename):
    unique_concepts=set()
    explanations = {}
    cluster3_expls = pd.read_csv(f"/workspace/CCE_NLI/BERT/exp/{method}/{filename}/Expls/{0.0}%Pruned/Cluster3IOUS1024N.csv")
    all_concept_at_original = get_indiv_concepts_per_unit(cluster3_expls) 
    return len(list(all_concept_at_original.keys()))

def dropoff(method, filename, k, **kwargs):
    if method == 'wanda':
        sparsity_list = SPARSITY_RATIOS_WANDA
    elif method == 'lottery_ticket':
        sparsity_list = SPARSITY_RATIOS_LTH
        
    num_orig_neurons = kwargs['num_orig_neurons']
    concept_and_assoc_sparsities = kwargs['concept_assoc_sparsity']
    sparsity_mapping = kwargs['neuron_concept_sparsity_mapping']
    neurons_preserved = [False for i in range(num_orig_neurons)]
    for i,neuron in enumerate(sparsity_mapping.keys()):
        for concept in concept_and_assoc_sparsities[neuron]:
            list_of_concepts_and_sprsty = list(concept_and_assoc_sparsities[neuron][concept])
            first_k_iters_present = sorted(list_of_concepts_and_sprsty)[:k]
            if first_k_iters_present == sparsity_list[:k]: #this concept is preserved for at lesat the first 6 iters
                neurons_preserved[i] = True
                break
    return torch.where(torch.tensor(neurons_preserved)==1, 1,0).sum()/num_orig_neurons

dropoffs_lth = []
method = 'lottery_ticket'
filename = 'Run2Full'
sparsity_list = SPARSITY_RATIOS_LTH


for k in range(1,15):
    neurons_orig_explained = get_neurons_explained_originally(method, filename)
    neuron_concept_sparsity_mapping = get_concepts_across_pruning_per_neuron(method, filename,sparsity_list)
    concept_assoc_sparsity=get_concepts_assoc_sparsities(method, filename,sparsity_list)
    percent_of_neurons_preserved = dropoff(method, filename, k, num_orig_neurons=neurons_orig_explained, concept_assoc_sparsity= concept_assoc_sparsity,neuron_concept_sparsity_mapping=neuron_concept_sparsity_mapping)
    dropoffs_lth.append(percent_of_neurons_preserved)
    
dropoffs_wanda = []
method = 'wanda'
filename = 'Run2Full'
sparsity_list = SPARSITY_RATIOS_WANDA
for k in range(1,15):
    neurons_orig_explained = get_neurons_explained_originally(method, filename)
    neuron_concept_sparsity_mapping = get_concepts_across_pruning_per_neuron(method, filename,sparsity_list)
    concept_assoc_sparsity=get_concepts_assoc_sparsities(method, filename,sparsity_list)
    percent_of_neurons_preserved = dropoff(method, filename, k, num_orig_neurons=neurons_orig_explained, concept_assoc_sparsity= concept_assoc_sparsity,neuron_concept_sparsity_mapping=neuron_concept_sparsity_mapping)
    dropoffs_wanda.append(percent_of_neurons_preserved)
    
    
x=[SPARSITY_RATIOS_WANDA[i] for i in range(0,14)] 
plt.plot(x, dropoffs_lth, label='lth',color='blue', marker='o')
plt.plot(x, dropoffs_wanda, label='wanda',color='green', marker='x')
plt.title("neuron wise: % of neurons preserved for at least first k iters")
plt.xlabel("sparsities")
plt.ylabel("% of concepts preserved")
plt.legend()
plt.grid(True)

plt.show()

# %%
globally: % of concepts that are preserved in kth pruning iter compared to original
    % of concepts preserved in kth pruning iter compared to the one prior to it

# %%
def get_concepts_across_pruning_per_neuron(method, filename, sparsity_list):
    explanations = {}
    for sparsity in sparsity_list:
        cluster3_expls = pd.read_csv(f"/workspace/CCE_NLI/BERT/exp/{method}/{filename}/Expls/{sparsity}%Pruned/Cluster3IOUS1024N.csv")
        explanations[sparsity] = get_indiv_concepts_per_unit(cluster3_expls) 
    reordered = collections.defaultdict(dict)
    for sparsity, neurons in explanations.items():
        for neuron, concepts in neurons.items():
            reordered[neuron][sparsity] = concepts
    return reordered 

method='wanda'
filename='Run2Full'
sparsity_list = SPARSITY_RATIOS_WANDA
get_concepts_across_pruning_per_neuron(method, filename, sparsity_list)
# Out:
# defaultdict(dict,
#             {0: {0.0: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:tall',
#                'hyp:tok:day'],
#               19.987: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:friends',
#                'hyp:tok:day'],
#               35.97: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:friends',
#                'hyp:tok:day'],
#               48.796: ['hyp:tag:vb',
#                'hyp:tok:for',
#                'hyp:tok:friends',
#                'hyp:tok:day'],
#               59.017: ['hyp:tag:vb', 'hyp:tok:for', 'hyp:tok:friends'],
#               73.763: ['hyp:tok:for',
#                'hyp:tok:to',
#                'pre:tok:street',
#                'hyp:tok:day',
#                'hyp:tag:md'],
#               83.203: ['hyp:tok:man',
#                'pre:tok:standing',
#                'hyp:tok:person',
#                'hyp:tok:train'],
#               91.406: ['hyp:tag:in', 'hyp:tok:to']},
#              1: {0.0: ['hyp:tok:people',
#                'pre:tok:young',
#                'pre:tok:children',
#                'pre:tok:soccer'],
#               19.987: ['hyp:tok:people', 'pre:tok:young', 'pre:tok:children'],
#               35.97: ['hyp:tok:people',
#                'pre:tok:boy',
#                'pre:tok:children',
#                'pre:tok:pool'],
#               48.796: ['hyp:tok:people',
#                'pre:tok:pool',
#                'hyp:tok:person',
#                'pre:tok:boy'],
#               59.017: ['hyp:tok:people',
#                'hyp:tok:person',
#                'pre:tok:pool',
#                'hyp:tok:there'],
#               67.22: ['hyp:tok:people',
#                'hyp:tok:person',
#                'pre:tok:car',
#                'hyp:tok:group',
#                'pre:tag:vb'],
#               73.763: ['pre:tag:nns', 'pre:tok:woman', 'hyp:tag:prp$'],
#               79.004: ['pre:tok:man',
#                'pre:tok:people',
#                'pre:tok:woman',
#                'pre:tok:street',
#                'hyp:tok:person'],
#               83.203: ['pre:tok:are',
#                'pre:tok:man',
#                'hyp:tok:person',
#                'pre:tok:standing']},
#              2: {0.0: ['hyp:tag:jj', 'hyp:tok:wearing'],
#               19.987: ['hyp:tag:jj', 'hyp:tok:wearing', 'pre:tok:ocean'],
#               35.97: ['hyp:tag:jj', 'hyp:tok:wearing'],
#               48.796: ['hyp:tag:jj', 'pre:tok:ocean'],
#               79.004: ['pre:tag:nn'],
#               86.556: ['pre:tag:nn', 'hyp:tok:wearing'],
#               89.258: ['pre:tag:nn'],
#               91.406: ['pre:tag:nn', 'hyp:tag:nns'],
#               93.099: ['hyp:tag:in',
#                'hyp:tag:nn',
#                'hyp:tok:to',
#                'hyp:tok:there'],
#               94.499: ['hyp:tag:cd',
#                'hyp:tag:nn',
#                'hyp:tag:in',
#                'hyp:tok:there',
#                'hyp:tok:to']},
#              3: {0.0: ['pre:tok:dog',
#                'pre:tok:woman',
#                'hyp:tok:girl',
#                'pre:tok:walking'],
#               19.987: ['pre:tok:dog',
#                'pre:tok:woman',
#                'hyp:tok:girl',
#                'hyp:tok:women'],
#               35.97: ['pre:tok:dog',
#                'pre:tok:walking',
#                'hyp:tok:playing',
#                'hyp:tok:her',
#                'hyp:tok:girl'],
#               48.796: ['hyp:tok:dog',
#                'hyp:tok:walking',
#                'hyp:tok:dogs',
#                'hyp:tok:walks',
#                'hyp:tok:snow'],
#               86.556: ['hyp:tag:in',
#                'hyp:tok:to',
#                'hyp:tok:playing',
#                'pre:tok:while'],
#               89.258: ['pre:tag:jj', 'pre:tag:vbz'],
#               91.406: ['oth:overlap:overlap25', 'pre:tok:dog'],
#               93.099: ['pre:tag:nn', 'hyp:tok:outdoors', 'hyp:tok:cat'],
#               94.499: ['pre:tag:nn']},
#              4: {0.0: ['hyp:tag:in',
#                'hyp:tag:jj',
#                'hyp:tag:prp$',
#                'hyp:tag:nnp'],
#               19.987: ['hyp:tag:in', 'hyp:tag:jj', 'hyp:tag:prp$'],
#               35.97: ['hyp:tag:jj',
#                'hyp:tag:nnp',
#                'pre:tok:working',
#                'hyp:tag:in']},
#              6: {0.0: ['hyp:tok:inside',
#                'hyp:tok:sitting',
#                'hyp:tok:sits',
#                'hyp:tok:indoors'],
#               73.763: ['pre:tag:vbp',
#                'pre:tok:street',
#                'pre:tok:car',
#                'pre:tok:riding']},
#              7: {0.0: ['hyp:tok:people',
#                'hyp:tok:person',
#                'hyp:tag:ex',
#                'hyp:tok:outdoors'],
#               19.987: ['hyp:tok:people',
#                'hyp:tok:person',
#                'hyp:tok:there',
#                'hyp:tok:outdoors'],
#               35.97: ['hyp:tok:people',
#                'hyp:tok:person',
#                'hyp:tok:there',
#                'hyp:tok:outdoors'],
#               48.796: ['hyp:tok:people',
#                'hyp:tok:person',
#                'hyp:tag:ex',
#                'hyp:tok:water'],
#               59.017: ['hyp:tok:people',
#                'hyp:tok:there',
#                'hyp:tok:outside',
#                'hyp:tok:nobody',
#                'hyp:tok:not'],
#               67.22: ['hyp:tok:people',
#                'pre:tag:vbp',
#                'hyp:tok:person',
#                'hyp:tok:outside'],
#               73.763: ['pre:tag:nns', 'pre:tok:woman'],
#               79.004: ['pre:tag:dt'],
#               83.203: ['pre:tag:dt'],
#               86.556: ['pre:tag:.'],
#               89.258: ['pre:tag:.'],
#               91.406: ['hyp:tag:nns',
#                'hyp:tok:bike',
#                'hyp:tok:dog',
#                'hyp:tok:bicycle',
#                'hyp:tok:bench'],
#               93.099: ['hyp:tag:in',
#                'hyp:tok:to',
#                'hyp:tok:wearing',
#                'hyp:tag:prp$',
#                'hyp:tag:cc'],
#               94.499: ['hyp:tag:in',
#                'hyp:tag:nn',
#                'hyp:tag:rb',
#                'hyp:tok:to']},
#              8: {0.0: ['pre:tok:man', 'hyp:tok:running', 'hyp:tok:eating'],
#               19.987: ['pre:tok:man', 'hyp:tok:running', 'hyp:tok:eating']},
#              9: {0.0: ['hyp:tag:nn', 'hyp:tok:sleeping'],
#               19.987: ['hyp:tag:vbz', 'hyp:tok:sleeping', 'hyp:tok:no'],
#               35.97: ['hyp:tag:rb',
#                'hyp:tok:no',
#                'hyp:tok:sleeping',
#                'hyp:tok:skateboard'],
#               48.796: ['hyp:tag:nn'],
#               59.017: ['hyp:tag:vbz', 'hyp:tag:rb'],
#               67.22: ['pre:tag:nn', 'hyp:tok:sitting'],
#               73.763: ['hyp:tag:nn'],
#               79.004: ['hyp:tag:nn'],
#               86.556: ['pre:tok:in',
#                'pre:tok:man',
#                'pre:tag:,',
#                'pre:tok:playing'],
#               89.258: ['hyp:tag:in', 'pre:tag:dt', 'hyp:tag:cc']},
#              10: {0.0: ['hyp:tok:for', 'hyp:tok:to', 'hyp:tok:after'],
#               19.987: ['hyp:tok:for', 'hyp:tok:to', 'hyp:tok:after'],
#               35.97: ['hyp:tok:for', 'hyp:tok:to', 'hyp:tok:after'],
#               48.796: ['hyp:tok:for', 'hyp:tok:to', 'hyp:tok:after'],
#               59.017: ['hyp:tok:for', 'hyp:tok:to', 'hyp:tok:after'],
#               91.406: ['hyp:tag:vb',
#                'hyp:tok:little',
#                'pre:tok:skateboard',
#                'hyp:tok:after',
#                'hyp:tok:while']},
#              11: {0.0: ['hyp:tag:nnp',
#                'hyp:tag:prp$',
#                'hyp:tok:tall',
#                'hyp:tok:birthday'],
#               19.987: ['hyp:tag:nnp',
#                'hyp:tag:prp$',
#                'hyp:tok:tall',
#                'hyp:tok:birthday'],
#               35.97: ['hyp:tag:prp$',
#                'hyp:tag:nnp',
#                'hyp:tok:tall',
#                'hyp:tok:birthday'],
#               48.796: ['hyp:tag:prp$',
#                'hyp:tok:tall',
#                'hyp:tag:nnp',
#                'hyp:tok:birthday']},
#              12: {0.0: ['hyp:tag:jj', 'hyp:tag:nnp', 'hyp:tok:eating'],
#               19.987: ['hyp:tag:vb',
#                'hyp:tok:for',
#                'hyp:tok:tall',
#                'hyp:tok:eating'],
#               35.97: ['hyp:tag:nnp',
#                'hyp:tag:vb',
#                'hyp:tok:eating',
#                'hyp:tok:for'],
#               48.796: ['hyp:tag:dt', 'hyp:tok:eating'],
#               73.763: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:race',
#                'hyp:tok:white',
#                'hyp:tag:jjr'],
#               83.203: ['hyp:tok:man', 'hyp:tok:men', 'pre:tok:horse']},
#              13: {0.0: ['hyp:tag:prp$',
#                'hyp:tok:for',
#                'hyp:tok:about',
#                'hyp:tok:because'],
#               19.987: ['hyp:tag:prp$',
#                'hyp:tok:for',
#                'hyp:tok:about',
#                'hyp:tok:because'],
#               35.97: ['hyp:tag:prp$',
#                'hyp:tok:for',
#                'hyp:tok:about',
#                'hyp:tok:because'],
#               48.796: ['hyp:tag:prp$',
#                'hyp:tok:for',
#                'hyp:tok:because',
#                'hyp:tok:after'],
#               59.017: ['hyp:tag:prp$',
#                'hyp:tok:for',
#                'hyp:tok:family',
#                'hyp:tok:after'],
#               67.22: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:their',
#                'hyp:tok:son',
#                'hyp:tok:family'],
#               73.763: ['hyp:tag:in', 'hyp:tok:to', 'hyp:tag:prp$'],
#               79.004: ['pre:tok:man',
#                'pre:tok:street',
#                'hyp:tok:to',
#                'pre:tok:group'],
#               83.203: ['hyp:tag:in', 'hyp:tag:cc', 'hyp:tok:to']},
#              14: {0.0: ['hyp:tok:at', 'hyp:tok:for', 'hyp:tok:to'],
#               19.987: ['hyp:tok:at',
#                'hyp:tok:for',
#                'hyp:tok:his',
#                'hyp:tok:new'],
#               35.97: ['hyp:tok:at',
#                'hyp:tok:for',
#                'hyp:tok:his',
#                'hyp:tok:store'],
#               48.796: ['hyp:tok:at',
#                'hyp:tok:his',
#                'hyp:tok:for',
#                'hyp:tok:store'],
#               59.017: ['hyp:tok:at',
#                'pre:tok:shirt',
#                'hyp:tok:for',
#                'hyp:tok:playing'],
#               67.22: ['hyp:tok:playing', 'hyp:tok:sitting', 'pre:tok:shirt']},
#              15: {0.0: ['hyp:tag:in', 'pre:tok:snow'],
#               19.987: ['hyp:tag:in', 'pre:tok:snow'],
#               35.97: ['hyp:tag:in', 'pre:tok:snow'],
#               48.796: ['hyp:tag:in', 'pre:tok:snow'],
#               59.017: ['hyp:tok:man',
#                'pre:tok:race',
#                'hyp:tok:skateboard',
#                'pre:tok:racing']},
#              16: {0.0: ['pre:tag:.'],
#               19.987: ['hyp:tok:are', 'pre:tok:for', 'pre:tok:race'],
#               35.97: ['pre:tok:for',
#                'pre:tok:race',
#                'pre:tok:beach',
#                'pre:tok:after',
#                'pre:tok:night']},
#              17: {0.0: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:homeless',
#                'hyp:tok:black'],
#               19.987: ['hyp:tag:vb',
#                'hyp:tok:his',
#                'hyp:tok:homeless',
#                'hyp:tok:beach',
#                'pre:tok:tent'],
#               35.97: ['hyp:tag:vb',
#                'hyp:tok:for',
#                'hyp:tag:prp',
#                'hyp:tok:homeless'],
#               48.796: ['hyp:tag:vb',
#                'hyp:tok:his',
#                'hyp:tok:for',
#                'hyp:tok:homeless'],
#               59.017: ['hyp:tag:prp$', 'pre:tok:beach', 'hyp:tok:he']},
#              18: {0.0: ['pre:tag:jj', 'hyp:tok:there', 'hyp:tok:near'],
#               19.987: ['pre:tag:jj', 'hyp:tok:there', 'hyp:tok:near'],
#               35.97: ['pre:tag:jj', 'hyp:tok:there', 'hyp:tok:near'],
#               48.796: ['pre:tag:jj', 'hyp:tok:there', 'hyp:tok:outside'],
#               59.017: ['hyp:tag:ex',
#                'hyp:tok:outside',
#                'hyp:tok:outdoors',
#                'pre:tok:mountain',
#                'pre:tok:bridge'],
#               67.22: ['hyp:tok:people',
#                'hyp:tok:women',
#                'pre:tok:race',
#                'pre:tok:street'],
#               73.763: ['pre:tag:nns', 'pre:tok:white', 'pre:tok:street'],
#               79.004: ['pre:tok:man',
#                'pre:tok:people',
#                'pre:tok:street',
#                'pre:tok:men',
#                'pre:tok:race'],
#               83.203: ['pre:tag:nns', 'pre:tok:man', 'pre:tok:person'],
#               86.556: ['hyp:tok:man', 'pre:tag:nns'],
#               89.258: ['hyp:tag:in', 'hyp:tok:to', 'hyp:tok:and'],
#               91.406: ['hyp:tag:in', 'hyp:tok:to', 'hyp:tag:cc'],
#               93.099: ['hyp:tag:in', 'hyp:tok:to', "hyp:tok:'s", 'hyp:tag:nn'],
#               94.499: ['pre:tag:.', 'hyp:tag:,', 'hyp:tok:while']},
#              19: {0.0: ['hyp:tag:vb',
#                'hyp:tok:woman',
#                'hyp:tag:in',
#                'hyp:tok:eating'],
#               19.987: ['hyp:tag:vb',
#                'hyp:tok:woman',
#                'hyp:tag:in',
#                'hyp:tok:eating'],
#               35.97: ['hyp:tag:vb',
#                'hyp:tok:woman',
#                'hyp:tok:eating',
#                'hyp:tok:fishing'],
#               48.796: ['hyp:tag:vb',
#                'hyp:tok:eating',
#                'hyp:tok:swimming',
#                'hyp:tok:cooking'],
#               59.017: ['hyp:tag:vb',
#                'hyp:tok:eating',
#                'hyp:tok:swimming',
#                'hyp:tok:reading'],
#               73.763: ['hyp:tok:to',
#                'hyp:tok:woman',
#                'hyp:tok:women',
#                'hyp:tok:other',
#                'hyp:tok:running']},
#              20: {0.0: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:tall',
#                'hyp:tok:about'],
#               19.987: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:tall',
#                'hyp:tok:about'],
#               35.97: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:tall',
#                'hyp:tok:vacation'],
#               48.796: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:tall',
#                'hyp:tok:just'],
#               86.556: ['hyp:tag:in', 'hyp:tok:to'],
#               89.258: ['hyp:tag:in', 'oth:overlap:overlap50'],
#               91.406: ['hyp:tag:.', 'hyp:tok:her', 'hyp:tok:to'],
#               93.099: ['hyp:tag:in',
#                'oth:overlap:overlap50',
#                'hyp:tok:to',
#                'hyp:tag:prp$',
#                'hyp:tok:there'],
#               94.499: ['hyp:tag:cd',
#                'hyp:tag:nn',
#                'hyp:tag:in',
#                'hyp:tok:there',
#                'hyp:tok:to']},
#              21: {0.0: ['hyp:tok:girl',
#                'oth:overlap:overlap50',
#                'hyp:tok:outdoors'],
#               19.987: ['hyp:tok:women',
#                'oth:overlap:overlap50',
#                'hyp:tok:outdoors'],
#               35.97: ['hyp:tok:women',
#                'oth:overlap:overlap50',
#                'hyp:tok:outdoors'],
#               48.796: ['hyp:tok:girl',
#                'hyp:tok:woman',
#                'hyp:tok:outside',
#                'hyp:tok:outdoors'],
#               59.017: ['hyp:tok:girl',
#                'hyp:tok:woman',
#                'hyp:tok:women',
#                'hyp:tok:outdoors'],
#               67.22: ['hyp:tok:to',
#                'hyp:tok:women',
#                'hyp:tok:race',
#                'hyp:tok:for'],
#               73.763: ['hyp:tag:in', 'hyp:tok:to', 'hyp:tok:are'],
#               79.004: ['hyp:tag:dt'],
#               83.203: ['hyp:tag:in', 'hyp:tok:man', 'hyp:tag:rb'],
#               86.556: ['pre:tag:,', 'pre:tag:jj', 'hyp:tag:nn', 'hyp:tag:cc'],
#               89.258: ['pre:tag:jj',
#                'pre:tok:ball',
#                'hyp:tag:nn',
#                'pre:tok:from'],
#               91.406: ['hyp:tag:.', 'hyp:tag:nn'],
#               93.099: ['pre:tag:nn', 'pre:tok:ocean'],
#               94.499: ['pre:tag:.']},
#              22: {0.0: ['pre:tag:.', 'pre:tok:skateboard'],
#               19.987: ['pre:tag:.', 'pre:tok:city'],
#               35.97: ['pre:tag:in', 'pre:tok:park'],
#               48.796: ['pre:tag:.']},
#              23: {0.0: ['hyp:tok:eating',
#                'hyp:tok:swimming',
#                'hyp:tok:eat',
#                'hyp:tok:pool',
#                'hyp:tok:break'],
#               19.987: ['hyp:tok:eating',
#                'pre:tok:white',
#                'hyp:tok:swimming',
#                'hyp:tag:nnp',
#                'hyp:tag:vbg'],
#               35.97: ['hyp:tok:eating',
#                'hyp:tok:swimming',
#                'hyp:tok:eat',
#                'hyp:tok:swim',
#                'hyp:tok:break']},
#              24: {0.0: ['hyp:tag:vb',
#                'hyp:tok:tall',
#                'hyp:tok:he',
#                'pre:tok:chair',
#                'hyp:tok:homeless'],
#               19.987: ['hyp:tag:vb',
#                'hyp:tok:tall',
#                'hyp:tok:for',
#                'pre:tok:sits',
#                'hyp:tok:because'],
#               35.97: ['hyp:tag:vb',
#                'hyp:tok:tall',
#                'hyp:tok:for',
#                'hyp:tok:because',
#                'hyp:tok:break'],
#               48.796: ['hyp:tag:vb',
#                'hyp:tok:tall',
#                'hyp:tag:prp',
#                'hyp:tok:break'],
#               59.017: ['hyp:tag:vb',
#                'hyp:tok:tall',
#                'hyp:tok:for',
#                'hyp:tok:he']},
#              25: {0.0: ['hyp:tag:dt', 'hyp:tok:person', 'hyp:tok:for'],
#               19.987: ['hyp:tok:is',
#                'hyp:tok:person',
#                'pre:tok:playing',
#                'pre:tok:riding'],
#               35.97: ['hyp:tag:dt', 'hyp:tok:person'],
#               48.796: ['hyp:tok:is',
#                'hyp:tok:tall',
#                'pre:tok:riding',
#                'pre:tok:playing'],
#               59.017: ['hyp:tok:playing',
#                'pre:tok:woman',
#                'pre:tok:water',
#                'hyp:tok:bike'],
#               67.22: ['hyp:tag:vb',
#                'hyp:tok:race',
#                'hyp:tok:day',
#                'hyp:tok:having'],
#               73.763: ['pre:tag:nns', 'pre:tok:woman', 'hyp:tag:prp$'],
#               79.004: ['hyp:tag:dt'],
#               83.203: ['pre:tok:are',
#                'pre:tok:man',
#                'pre:tok:men',
#                'pre:tok:person'],
#               86.556: ['hyp:tag:in',
#                'hyp:tag:vb',
#                'hyp:tag:prp$',
#                'pre:tok:riding'],
#               89.258: ['hyp:tag:in', 'hyp:tag:vbg'],
#               91.406: ['hyp:tag:in', 'hyp:tag:nns', 'hyp:tag:vb'],
#               94.499: ['pre:tag:nn', 'hyp:tok:nobody']},
#              26: {0.0: ['hyp:tok:naked',
#                'hyp:tok:swimming',
#                'hyp:tok:alone',
#                'hyp:tok:sleeping',
#                'hyp:tok:no'],
#               19.987: ['hyp:tok:naked',
#                'hyp:tok:swimming',
#                'hyp:tok:alone',
#                'hyp:tok:no',
#                'hyp:tok:sleeping'],
#               35.97: ['hyp:tok:alone',
#                'hyp:tok:swimming',
#                'hyp:tok:naked',
#                'hyp:tok:sleeping',
#                'hyp:tok:no']},
#              27: {0.0: ['pre:tag:jj',
#                'pre:tok:man',
#                'hyp:tok:at',
#                'hyp:tok:watching'],
#               19.987: ['pre:tag:jj',
#                'pre:tok:man',
#                'pre:tok:looking',
#                'pre:tok:sitting'],
#               35.97: ['pre:tok:blue', 'pre:tok:sitting', 'pre:tok:orange'],
#               48.796: ['hyp:tok:man',
#                'pre:tok:shirt',
#                'pre:tok:sitting',
#                'hyp:tok:looking'],
#               59.017: ['hyp:tok:man',
#                'pre:tok:blue',
#                'pre:tok:shirt',
#                'pre:tok:looking'],
#               67.22: ['hyp:tok:sitting',
#                'pre:tok:man',
#                'hyp:tok:sleeping',
#                'pre:tok:boy'],
#               73.763: ['hyp:tok:dog',
#                'hyp:tok:sleeping',
#                'hyp:tok:pool',
#                'hyp:tok:football',
#                'hyp:tok:sits'],
#               79.004: ['hyp:tag:nn'],
#               83.203: ['hyp:tok:playing',
#                'hyp:tok:sleeping',
#                'hyp:tok:eating',
#                'hyp:tok:play',
#                'hyp:tok:plays'],
#               86.556: ['pre:tag:nns', 'pre:tok:man', 'pre:tag:,'],
#               89.258: ['pre:tag:.', 'hyp:tok:outside', 'pre:tok:sitting'],
#               91.406: ['oth:overlap:overlap25'],
#               93.099: ['hyp:tag:nn'],
#               94.499: ['oth:overlap:overlap25',
#                'hyp:tok:for',
#                'hyp:tok:there']},
#              28: {0.0: ['oth:overlap:overlap50',
#                'pre:tag:jj',
#                'hyp:tok:horse',
#                'hyp:tok:phone',
#                'hyp:tok:baseball'],
#               19.987: ['oth:overlap:overlap50',
#                'pre:tag:jj',
#                'hyp:tok:race',
#                'hyp:tok:phone',
#                'hyp:tok:horse'],
#               35.97: ['hyp:tok:red',
#                'oth:overlap:overlap75',
#                'pre:tok:baseball',
#                'hyp:tok:brown',
#                'hyp:tok:horse'],
#               48.796: ['oth:overlap:overlap50',
#                'pre:tag:jj',
#                'pre:tok:ball',
#                'hyp:tok:dog',
#                'hyp:tok:shirt'],
#               59.017: ['hyp:tok:dog',
#                'hyp:tok:shirt',
#                'pre:tok:yellow',
#                'hyp:tok:boy',
#                'hyp:tok:phone'],
#               67.22: ['hyp:tok:to',
#                'pre:tok:car',
#                'pre:tok:men',
#                'pre:tok:race',
#                'pre:tok:street'],
#               73.763: ['pre:tag:cc', 'pre:tag:nns', 'hyp:tag:prp$'],
#               79.004: ['pre:tok:man',
#                'pre:tok:woman',
#                'pre:tok:are',
#                'pre:tok:street'],
#               83.203: ['pre:tok:are',
#                'pre:tok:man',
#                'hyp:tok:woman',
#                'hyp:tok:person'],
#               86.556: ['pre:tag:cc',
#                'pre:tok:wearing',
#                'pre:tok:-',
#                'pre:tag:jj',
#                'pre:tag:,'],
#               89.258: ['hyp:tag:in',
#                'pre:tok:wearing',
#                'hyp:tag:prp$',
#                'pre:tok:while',
#                'hyp:tok:riding'],
#               91.406: ['hyp:tok:man',
#                'pre:tag:vbz',
#                'pre:tok:shirt',
#                'pre:tok:holding',
#                'pre:tag:dt'],
#               93.099: ['pre:tag:nn', 'hyp:tok:beach', 'hyp:tok:smiling'],
#               94.499: ['pre:tag:nn', 'hyp:tok:nobody']},
#              29: {0.0: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:person',
#                'hyp:tok:street',
#                'pre:tok:shorts'],
#               19.987: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:street',
#                'hyp:tok:person'],
#               35.97: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:person',
#                'hyp:tok:picture'],
#               48.796: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:smiling',
#                'hyp:tok:beach',
#                'hyp:tok:enjoying'],
#               59.017: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:party',
#                'hyp:tok:having'],
#               67.22: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:street',
#                'hyp:tok:beach',
#                'hyp:tok:band'],
#               73.763: ['pre:tag:nns',
#                'hyp:tok:outside',
#                'pre:tok:street',
#                'hyp:tok:beach'],
#               79.004: ['hyp:tag:in', 'hyp:tok:outside', 'pre:tok:street'],
#               83.203: ['hyp:tag:in', 'hyp:tok:outside', 'hyp:tok:wearing']},
#              30: {0.0: ['oth:overlap:overlap50',
#                'hyp:tok:blue',
#                'hyp:tok:red'],
#               19.987: ['oth:overlap:overlap50', 'hyp:tok:blue'],
#               35.97: ['oth:overlap:overlap50',
#                'hyp:tok:blue',
#                'hyp:tok:water'],
#               48.796: ['hyp:tok:shirt',
#                'oth:overlap:overlap50',
#                'hyp:tok:water'],
#               59.017: ['hyp:tag:vbz', 'hyp:tok:and'],
#               67.22: ['hyp:tag:vbz', 'hyp:tok:people', 'pre:tok:man'],
#               73.763: ['hyp:tag:vbz', 'pre:tag:prp', 'hyp:tok:people'],
#               79.004: ['hyp:tag:in', 'hyp:tok:to', 'pre:tag:dt'],
#               83.203: ['hyp:tag:in', 'hyp:tok:to'],
#               86.556: ['pre:tag:vbz', 'pre:tok:man', 'pre:tag:,'],
#               89.258: ['pre:tag:cc',
#                'pre:tok:shirt',
#                'pre:tag:jj',
#                'pre:tag:,',
#                'hyp:tok:wearing'],
#               91.406: ['pre:tag:vbz',
#                'pre:tok:man',
#                'pre:tag:,',
#                'hyp:tag:in',
#                'pre:tag:,'],
#               93.099: ['hyp:tag:in',
#                'hyp:tok:to',
#                'hyp:tag:prp$',
#                'hyp:tok:wearing',
#                'hyp:tag:vb']},
#              31: {0.0: ['hyp:tag:nn', 'hyp:tok:sleeping'],
#               19.987: ['hyp:tag:nn', 'hyp:tok:swimming'],
#               35.97: ['pre:tag:nns', 'hyp:tok:swimming', 'hyp:tok:eating'],
#               73.763: ['pre:tok:street',
#                'pre:tok:women',
#                'hyp:tok:race',
#                'hyp:tok:old',
#                'hyp:tok:older']},
#              33: {0.0: ['oth:overlap:overlap50',
#                'pre:tok:during',
#                'pre:tok:just'],
#               19.987: ['oth:overlap:overlap50', 'pre:tok:during'],
#               35.97: ['oth:overlap:overlap50', 'pre:tok:just'],
#               48.796: ['oth:overlap:overlap50',
#                'pre:tag:prp$',
#                'pre:tag:jj',
#                'hyp:tok:standing',
#                'hyp:tok:holding'],
#               59.017: ['pre:tag:jj', 'pre:tok:to'],
#               67.22: ['pre:tag:jj', 'pre:tok:her'],
#               73.763: ['hyp:tag:nn'],
#               79.004: ['pre:tag:nn'],
#               83.203: ['hyp:tag:nn', 'hyp:tok:playing'],
#               86.556: ['hyp:tag:in',
#                'pre:tag:jj',
#                'pre:tag:,',
#                'pre:tok:as',
#                'pre:tok:baseball'],
#               89.258: ['pre:tag:in', 'pre:tag:jj', 'pre:tag:,', 'pre:tok:as'],
#               91.406: ['pre:tag:jj',
#                'pre:tok:to',
#                'hyp:tag:nn',
#                'pre:tok:from'],
#               93.099: ['hyp:tag:nn',
#                'hyp:tag:nns',
#                'hyp:tag:in',
#                'hyp:tok:to',
#                'hyp:tag:rb'],
#               94.499: ['hyp:tag:nn', 'hyp:tag:nns', 'hyp:tok:to']},
#              34: {0.0: ['oth:overlap:overlap50', 'pre:tok:football'],
#               19.987: ['oth:overlap:overlap50',
#                'pre:tok:football',
#                'hyp:tok:near'],
#               35.97: ['hyp:tok:there',
#                'oth:overlap:overlap75',
#                'pre:tok:football',
#                'hyp:tok:person',
#                'hyp:tok:human'],
#               48.796: ['hyp:tok:there',
#                'oth:overlap:overlap50',
#                'hyp:tok:person',
#                'hyp:tok:playing'],
#               59.017: ['hyp:tag:ex',
#                'oth:overlap:overlap25',
#                'hyp:tok:person'],
#               67.22: ['oth:overlap:overlap25',
#                'hyp:tok:person',
#                'pre:tok:dog'],
#               73.763: ['pre:tok:dog',
#                'pre:tok:pool',
#                'pre:tok:ball',
#                'pre:tok:playing'],
#               79.004: ['hyp:tag:nn'],
#               83.203: ['hyp:tok:playing',
#                'pre:tok:dog',
#                'hyp:tok:play',
#                'hyp:tok:eating',
#                'pre:tok:player'],
#               86.556: ['hyp:tag:in',
#                'pre:tok:dog',
#                'hyp:tok:playing',
#                'hyp:tok:boy',
#                'hyp:tok:eating'],
#               89.258: ['pre:tag:jj',
#                'pre:tok:shirt',
#                'pre:tok:as',
#                'pre:tok:food'],
#               91.406: ['pre:tag:nn', 'pre:tok:men', 'hyp:tok:playing'],
#               93.099: ['pre:tag:nn'],
#               94.499: ['pre:tag:nn']},
#              35: {0.0: ['pre:tok:and', 'hyp:tok:at', 'hyp:tag:dt'],
#               19.987: ['hyp:tok:at',
#                'hyp:tok:for',
#                'pre:tok:sunglasses',
#                'pre:tok:bag'],
#               35.97: ['hyp:tok:at', 'hyp:tok:for', 'pre:tok:helmet'],
#               48.796: ['hyp:tok:at', 'hyp:tok:for', 'pre:tok:pink'],
#               59.017: ['hyp:tok:at',
#                'hyp:tok:for',
#                'pre:tok:pink',
#                'pre:tag:jj'],
#               79.004: ['hyp:tag:nn'],
#               86.556: ['hyp:tag:in', 'hyp:tok:to', 'pre:tok:dog'],
#               89.258: ['hyp:tag:nn'],
#               91.406: ['hyp:tag:in',
#                'hyp:tok:to',
#                "hyp:tok:'s",
#                'hyp:tag:.',
#                'hyp:tag:vb'],
#               93.099: ['hyp:tag:nn', 'oth:overlap:overlap75'],
#               94.499: ['pre:tag:.']},
#              36: {0.0: ['hyp:tok:woman',
#                'hyp:tok:swimming',
#                'pre:tok:kitchen',
#                'hyp:tok:moon'],
#               19.987: ['hyp:tok:woman',
#                'hyp:tok:swimming',
#                'pre:tok:kitchen',
#                'hyp:tok:moon']},
#              37: {0.0: ['hyp:tag:rb',
#                'hyp:tok:nobody',
#                'hyp:tok:no',
#                'hyp:tok:inside'],
#               19.987: ['hyp:tok:inside',
#                'pre:tok:water',
#                'hyp:tok:no',
#                'hyp:tok:nobody',
#                'hyp:tok:alone'],
#               35.97: ['hyp:tok:inside',
#                'hyp:tok:nobody',
#                'hyp:tok:no',
#                'hyp:tok:not',
#                'hyp:tok:alone'],
#               73.763: ['pre:tag:nns', 'pre:tok:woman', 'hyp:tag:prp$'],
#               79.004: ['pre:tok:man',
#                'pre:tok:street',
#                'hyp:tok:woman',
#                'pre:tok:lady'],
#               83.203: ['pre:tok:are',
#                'pre:tok:man',
#                'pre:tok:men',
#                'pre:tok:person']},
#              39: {0.0: ['oth:overlap:overlap50'],
#               19.987: ['oth:overlap:overlap50'],
#               35.97: ['oth:overlap:overlap50'],
#               48.796: ['hyp:tok:there',
#                'oth:overlap:overlap50',
#                'pre:tok:performs'],
#               59.017: ['oth:overlap:overlap50',
#                'pre:tok:man',
#                'hyp:tok:people'],
#               67.22: ['hyp:tok:people',
#                'pre:tag:vbp',
#                'hyp:tok:to',
#                'pre:tok:car'],
#               73.763: ['pre:tag:nns', 'pre:tok:woman', 'hyp:tag:prp$'],
#               79.004: ['pre:tok:man',
#                'pre:tok:woman',
#                'pre:tok:street',
#                'pre:tok:people',
#                'pre:tok:lady'],
#               83.203: ['pre:tok:are',
#                'pre:tok:man',
#                'pre:tok:standing',
#                'hyp:tok:person'],
#               86.556: ['pre:tag:,',
#                'pre:tok:man',
#                'pre:tok:woman',
#                'pre:tag:dt',
#                'pre:tok:shirt'],
#               89.258: ['hyp:tag:nn',
#                'pre:tag:jj',
#                'pre:tok:holding',
#                'pre:tok:while'],
#               91.406: ['pre:tag:in',
#                'pre:tag:jj',
#                'pre:tok:standing',
#                'hyp:tag:nn'],
#               93.099: ['hyp:tag:.', 'pre:tag:dt', 'hyp:tok:man'],
#               94.499: ['hyp:tag:nn',
#                'hyp:tag:nns',
#                'hyp:tag:in',
#                'hyp:tok:to']},
#              40: {0.0: ['hyp:tok:running',
#                'pre:tok:sitting',
#                'hyp:tok:swimming',
#                'hyp:tok:alone'],
#               19.987: ['hyp:tok:running',
#                'pre:tok:sitting',
#                'hyp:tok:swimming',
#                'hyp:tok:alone']},
#              41: {0.0: ['hyp:tok:there',
#                'pre:tok:white',
#                'hyp:tok:sitting',
#                'pre:tok:blond',
#                'pre:tok:face'],
#               19.987: ['pre:tag:,',
#                'pre:tok:white',
#                'hyp:tok:there',
#                'hyp:tok:sitting'],
#               35.97: ['pre:tag:,',
#                'pre:tok:white',
#                'hyp:tag:ex',
#                'hyp:tok:sitting'],
#               48.796: ['hyp:tok:there',
#                'pre:tok:for',
#                'hyp:tok:indoors',
#                'hyp:tok:inside',
#                'pre:tok:martial'],
#               59.017: ['hyp:tok:there',
#                'pre:tok:race',
#                'hyp:tok:inside',
#                'hyp:tok:indoors',
#                'hyp:tok:human'],
#               67.22: ['pre:tok:race',
#                'pre:tok:their',
#                'pre:tok:other',
#                'pre:tok:car',
#                'pre:tok:"'],
#               73.763: ['pre:tag:nns',
#                'pre:tok:woman',
#                'pre:tag:prp$',
#                'pre:tok:to'],
#               79.004: ['pre:tag:dt'],
#               83.203: ['pre:tag:nns', 'pre:tok:man', 'pre:tag:cc'],
#               86.556: ['pre:tag:vbg', 'pre:tok:and', 'pre:tok:to'],
#               89.258: ['pre:tag:.', 'hyp:tag:cd'],
#               91.406: ['pre:tag:nns', 'pre:tok:men', 'hyp:tok:women'],
#               94.499: ['pre:tag:in', 'hyp:tok:nobody']},
#              42: {0.0: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:not',
#                'hyp:tok:human'],
#               19.987: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:human',
#                'hyp:tok:least'],
#               35.97: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:vehicle',
#                'hyp:tok:least'],
#               86.556: ['pre:tag:.'],
#               89.258: ['pre:tag:nn'],
#               91.406: ['pre:tag:nn'],
#               93.099: ['hyp:tag:nn', 'hyp:tok:two', 'hyp:tok:there'],
#               94.499: ['hyp:tag:in',
#                'hyp:tag:nn',
#                'oth:overlap:overlap50',
#                'hyp:tok:for']},
#              43: {0.0: ['hyp:tok:asleep',
#                'hyp:tok:sleeping',
#                'hyp:tok:eating',
#                'hyp:tok:sleeps',
#                'hyp:tok:cat']},
#              44: {0.0: ['hyp:tag:vb',
#                'hyp:tok:for',
#                'pre:tok:river',
#                'pre:tok:snow'],
#               19.987: ['hyp:tag:vb', 'hyp:tok:for', 'pre:tok:river'],
#               35.97: ['hyp:tag:vb', 'hyp:tok:for', 'pre:tok:river'],
#               48.796: ['hyp:tag:vb',
#                'hyp:tok:for',
#                'pre:tok:snow',
#                'pre:tok:river',
#                'pre:tok:snowboarder'],
#               59.017: ['hyp:tag:vb',
#                'hyp:tok:for',
#                'pre:tok:snow',
#                'pre:tok:snowboarder'],
#               67.22: ['hyp:tag:vb',
#                'hyp:tok:for',
#                'hyp:tok:after',
#                'pre:tag:in',
#                'pre:tok:river'],
#               73.763: ['hyp:tag:vb', 'hyp:tok:his', 'hyp:tag:jjr']},
#              45: {0.0: ['hyp:tag:in', 'hyp:tok:sleeping'],
#               19.987: ['hyp:tag:in', 'hyp:tok:sleeping'],
#               35.97: ['hyp:tok:woman',
#                'hyp:tok:park',
#                'hyp:tok:sleeping',
#                'hyp:tok:alone']},
#              46: {0.0: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:tired',
#                'hyp:tok:vacation',
#                'hyp:tok:moving'],
#               19.987: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:vacation',
#                'hyp:tok:tired',
#                'hyp:tok:traveling'],
#               35.97: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:vacation',
#                'pre:tok:sweeping',
#                'hyp:tok:tired'],
#               48.796: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:something',
#                'hyp:tok:day',
#                'hyp:tok:vacation'],
#               59.017: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'pre:tok:sits',
#                'pre:tok:wooden',
#                'hyp:tok:near'],
#               67.22: ['hyp:tok:outside',
#                'pre:tok:man',
#                'hyp:tok:outdoors',
#                'pre:tok:sitting',
#                'pre:tok:sits'],
#               73.763: ['pre:tag:nn', 'hyp:tok:outside'],
#               79.004: ['hyp:tag:nn'],
#               83.203: ['hyp:tag:in',
#                'hyp:tag:vb',
#                'hyp:tag:prp$',
#                'pre:tok:child'],
#               86.556: ['hyp:tag:in',
#                'hyp:tag:vb',
#                'hyp:tok:wearing',
#                'hyp:tag:prp$'],
#               89.258: ['hyp:tag:nn'],
#               91.406: ['hyp:tag:in', 'hyp:tok:to'],
#               93.099: ['hyp:tag:nn', 'hyp:tag:in', 'hyp:tok:to', 'hyp:tag:cc'],
#               94.499: ['hyp:tag:nn', 'hyp:tag:nns', 'hyp:tok:to']},
#              47: {0.0: ['hyp:tag:ex',
#                'hyp:tok:not',
#                'hyp:tok:human',
#                'hyp:tok:person',
#                'hyp:tok:indoors'],
#               19.987: ['hyp:tag:ex',
#                'pre:tok:sitting',
#                'hyp:tok:not',
#                'hyp:tok:human',
#                'pre:tok:bed'],
#               35.97: ['hyp:tag:ex',
#                'pre:tok:sitting',
#                'hyp:tok:not',
#                'hyp:tok:human',
#                'pre:tok:bed'],
#               48.796: ['hyp:tag:ex',
#                'pre:tok:sitting',
#                'pre:tok:bed',
#                'hyp:tok:not',
#                'hyp:tok:human'],
#               59.017: ['hyp:tag:ex',
#                'pre:tok:sitting',
#                'pre:tok:sits',
#                'hyp:tok:indoors'],
#               67.22: ['hyp:tok:sitting',
#                'hyp:tok:there',
#                'pre:tok:book',
#                'pre:tok:bicycle'],
#               86.556: ['pre:tag:,',
#                'pre:tok:shirt',
#                'pre:tok:wearing',
#                'pre:tok:ride'],
#               89.258: ['pre:tag:,',
#                'pre:tag:cc',
#                'pre:tok:while',
#                'pre:tok:riding'],
#               91.406: ['pre:tag:in', 'pre:tag:jj', 'pre:tok:bench'],
#               93.099: ['hyp:tag:in',
#                'hyp:tok:to',
#                'pre:tok:wearing',
#                'hyp:tok:wearing',
#                'pre:tag:,'],
#               94.499: ['hyp:tag:in',
#                'pre:tag:jj',
#                'hyp:tag:vb',
#                'hyp:tag:nnp',
#                'hyp:tag:nn']},
#              48: {0.0: ['pre:tok:men',
#                'pre:tok:white',
#                'hyp:tok:football',
#                'hyp:tok:race',
#                'hyp:tok:bike'],
#               19.987: ['pre:tok:men',
#                'pre:tok:white',
#                'hyp:tok:bike',
#                'hyp:tok:football',
#                'hyp:tok:race'],
#               35.97: ['pre:tok:men',
#                'pre:tok:white',
#                'hyp:tok:bike',
#                'hyp:tok:football',
#                'hyp:tok:race'],
#               48.796: ['hyp:tok:bike',
#                'pre:tok:white',
#                'hyp:tok:tall',
#                'pre:tok:race'],
#               59.017: ['pre:tok:race',
#                'pre:tok:white',
#                'hyp:tok:bike',
#                'hyp:tok:tall'],
#               67.22: ['hyp:tok:bike',
#                'pre:tok:ball',
#                'hyp:tok:football',
#                'pre:tok:hill',
#                'hyp:tok:riding']},
#              49: {0.0: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:street',
#                'hyp:tok:city'],
#               19.987: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:street',
#                'hyp:tok:event',
#                'hyp:tok:city'],
#               35.97: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:city',
#                'hyp:tok:event'],
#               48.796: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:event',
#                'hyp:tok:city',
#                'hyp:tok:concert'],
#               59.017: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:street',
#                'hyp:tok:event',
#                'hyp:tok:city'],
#               67.22: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'pre:tok:hill',
#                'hyp:tok:park'],
#               86.556: ['hyp:tag:in',
#                'pre:tag:jj',
#                'hyp:tok:playing',
#                'pre:tag:prp'],
#               89.258: ['hyp:tag:in',
#                'hyp:tag:jj',
#                'hyp:tok:dog',
#                'pre:tok:him',
#                'hyp:tag:,'],
#               91.406: ['hyp:tag:nns', 'oth:overlap:overlap25']},
#              51: {0.0: ['hyp:tok:woman',
#                'pre:tok:snow',
#                'hyp:tok:no',
#                'hyp:tok:alone'],
#               19.987: ['hyp:tok:sleeping',
#                'hyp:tok:woman',
#                'hyp:tok:no',
#                'hyp:tok:alone'],
#               35.97: ['hyp:tok:sleeping',
#                'hyp:tok:woman',
#                'hyp:tok:no',
#                'hyp:tok:alone'],
#               48.796: ['pre:tok:man',
#                'hyp:tok:swimming',
#                'hyp:tok:sleeping',
#                'hyp:tok:alone'],
#               59.017: ['hyp:tok:sleeping',
#                'hyp:tok:swimming',
#                'hyp:tok:nobody',
#                'hyp:tok:no',
#                'hyp:tok:not'],
#               89.258: ['pre:tag:in', 'hyp:tok:sleeping'],
#               93.099: ['pre:tag:nn'],
#               94.499: ['pre:tag:in']},
#              52: {0.0: ['pre:tag:cc', 'hyp:tok:running', 'hyp:tok:eating'],
#               19.987: ['pre:tag:jj'],
#               35.97: ['pre:tag:cc', 'hyp:tok:dinner', 'pre:tag:``'],
#               48.796: ['pre:tag:cc',
#                'hyp:tok:eating',
#                'hyp:tok:swimming',
#                'hyp:tok:dinner']},
#              53: {0.0: ['pre:tag:nn', 'hyp:tok:bike'],
#               19.987: ['hyp:tag:.', 'hyp:tok:football'],
#               35.97: ['hyp:tag:.', 'hyp:tok:bike'],
#               48.796: ['hyp:tag:.', 'hyp:tok:bike']},
#              54: {0.0: ['hyp:tag:jj', 'hyp:tag:ex', 'pre:tok:sitting'],
#               19.987: ['hyp:tag:jj', 'pre:tok:sitting', 'hyp:tag:ex'],
#               35.97: ['pre:tok:park',
#                'pre:tok:sitting',
#                'pre:tok:playing',
#                'pre:tok:skateboard'],
#               48.796: ['pre:tok:playing',
#                'pre:tok:sitting',
#                'pre:tok:skateboard',
#                'hyp:tok:tall'],
#               59.017: ['pre:tok:playing',
#                'pre:tok:skateboard',
#                'hyp:tok:tall',
#                'hyp:tok:enjoying'],
#               67.22: ['pre:tok:playing',
#                'pre:tok:skateboard',
#                'pre:tok:play',
#                'hyp:tok:tall'],
#               73.763: ['pre:tag:nn', 'hyp:tok:wearing', 'hyp:tok:horse'],
#               79.004: ['hyp:tag:nns', 'pre:tok:man', 'pre:tag:cd'],
#               83.203: ['hyp:tag:dt', 'oth:overlap:overlap50']},
#              55: {0.0: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:their',
#                'hyp:tok:after'],
#               19.987: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:their',
#                'hyp:tok:after'],
#               35.97: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:at',
#                'hyp:tok:after'],
#               48.796: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:at',
#                'hyp:tok:about',
#                'hyp:tok:after'],
#               59.017: ['hyp:tag:in',
#                'hyp:tag:vbg',
#                'hyp:tok:to',
#                'hyp:tok:at'],
#               67.22: ['hyp:tok:for',
#                'hyp:tok:to',
#                'hyp:tok:their',
#                'hyp:tok:party',
#                'hyp:tok:dinner'],
#               73.763: ['hyp:tag:in', 'hyp:tok:to', 'hyp:tag:prp$'],
#               79.004: ['pre:tag:dt'],
#               83.203: ['pre:tok:are',
#                'pre:tok:man',
#                'hyp:tok:people',
#                'pre:tok:person']},
#              56: {0.0: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:there',
#                'hyp:tok:indoors'],
#               19.987: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:there',
#                'hyp:tok:indoors'],
#               35.97: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:there',
#                'hyp:tok:human'],
#               48.796: ['hyp:tok:outdoors',
#                'hyp:tok:outside',
#                'hyp:tok:indoors',
#                'hyp:tok:human']},
#              57: {0.0: ['hyp:tok:woman',
#                'pre:tok:girl',
#                'hyp:tag:ex',
#                'hyp:tok:inside'],
#               19.987: ['hyp:tok:woman',
#                'pre:tok:girl',
#                'hyp:tag:ex',
#                'hyp:tok:inside'],
#               35.97: ['hyp:tok:woman',
#                'pre:tok:girl',
#                'hyp:tok:there',
#                'pre:tok:look'],
#               48.796: ['pre:tok:girl', 'pre:tok:woman', 'hyp:tok:there'],
#               59.017: ['pre:tok:girl', 'pre:tok:woman']},
#              58: {0.0: ['hyp:tok:sleeping',
#                'hyp:tok:swimming',
#                'hyp:tok:asleep',
#                'hyp:tok:alone',
#                'hyp:tok:nobody'],
#               19.987: ['hyp:tok:sleeping',
#                'hyp:tok:swimming',
#                'hyp:tok:asleep',
#                'hyp:tok:alone',
#                'hyp:tok:nobody'],
#               35.97: ['hyp:tok:sleeping',
#                'hyp:tok:swimming',
#                'hyp:tok:alone',
#                'hyp:tok:asleep',
#                'hyp:tok:nap']},
#              59: {0.0: ['pre:tag:jj', 'hyp:tok:at'],
#               19.987: ['pre:tag:jj', 'hyp:tok:at'],
#               35.97: ['pre:tag:jj', 'hyp:tok:at'],
#               48.796: ['pre:tag:jj', 'hyp:tok:park'],
#               59.017: ['pre:tag:jj', 'pre:tok:wearing'],
#               67.22: ['pre:tag:cc',
#                'pre:tag:vbp',
#                'pre:tag:jj',
#                'pre:tok:car',
#                'pre:tok:red'],
#               73.763: ['pre:tag:nns', 'pre:tok:woman', 'hyp:tag:prp$'],
#               79.004: ['pre:tag:dt'],
#               83.203: ['pre:tag:nns', 'pre:tok:man', 'pre:tok:person'],
#               86.556: ['pre:tag:,',
#                'pre:tok:and',
#                'pre:tag:in',
#                'pre:tag:wp',
#                "pre:tag:''"]},
#              60: {0.0: ['pre:tag:nns', 'pre:tok:street'],
#               19.987: ['pre:tag:nns', 'pre:tok:street'],
#               35.97: ['hyp:tag:vbd',
#                'pre:tok:street',
#                'hyp:tok:tall',
#                'pre:tok:walk'],
#               48.796: ['hyp:tag:vbd',
#                'pre:tok:street',
#                'hyp:tok:tall',
#                'pre:tok:walking'],
#               79.004: ['pre:tok:race',
#                'pre:tok:riding',
#                'pre:tok:road',
#                'pre:tok:horses',
#                'pre:tok:racing'],
#               83.203: ['hyp:tag:vbp',
#                'pre:tag:cd',
#                'pre:tok:street',
#                'hyp:tok:car'],
#               86.556: ['pre:tag:nn'],
#               89.258: ['pre:tag:nn', 'hyp:tok:bike'],
#               91.406: ['pre:tag:nn'],
#               93.099: ['pre:tag:nn', 'pre:tag:nns'],
#               94.499: ['hyp:tag:nn', 'hyp:tag:nns', 'hyp:tok:to']},
#              61: {0.0: ['hyp:tok:sleeping',
#                'hyp:tok:woman',
#                'pre:tok:park',
#                'hyp:tok:asleep',
#                'hyp:tok:black'],
#               19.987: ['hyp:tok:sleeping',
#                'hyp:tok:woman',
#                'pre:tok:park',
#                'hyp:tok:asleep'],
#               35.97: ['hyp:tok:her',
# ...
#                'hyp:tok:outdoors',
#                'pre:tok:pink'],
#               19.987: ['hyp:tok:outside',
#                'pre:tok:black',
#                'hyp:tok:outdoors',
#                'pre:tok:pink'],
#               35.97: ['hyp:tok:outside',
#                'pre:tok:black',
#                'hyp:tok:outdoors',
#                'pre:tok:pink'],
#               48.796: ['hyp:tok:outside',
#                'pre:tok:black',
#                'pre:tok:blue',
#                'hyp:tok:outdoors'],
#               59.017: ['hyp:tok:outside',
#                'pre:tok:blue',
#                'hyp:tok:outdoors',
#                'pre:tok:sunglasses',
#                'pre:tok:singing'],
#               67.22: ['hyp:tok:outside',
#                'pre:tok:and',
#                'hyp:tok:outdoors',
#                'hyp:tok:outside'],
#               73.763: ['pre:tag:jj', 'hyp:tok:outside'],
#               79.004: ['hyp:tag:in', 'hyp:tok:to'],
#               83.203: ['hyp:tag:in', 'hyp:tok:to'],
#               86.556: ['hyp:tag:in', 'hyp:tag:dt', 'hyp:tag:vb'],
#               89.258: ['hyp:tag:in', 'hyp:tag:vb', 'hyp:tok:playing'],
#               91.406: ['hyp:tag:in', 'hyp:tok:to', 'hyp:tag:dt'],
#               93.099: ['hyp:tag:in',
#                'hyp:tok:to',
#                'hyp:tag:cc',
#                'hyp:tok:playing',
#                'hyp:tok:wearing'],
#               94.499: ['hyp:tag:in',
#                'hyp:tag:nn',
#                'hyp:tok:to',
#                'hyp:tok:two']},
#              1017: {0.0: ['hyp:tag:jj', 'hyp:tok:there', 'hyp:tok:human'],
#               19.987: ['hyp:tag:jj', 'hyp:tok:there', 'hyp:tok:human'],
#               35.97: ['hyp:tag:jj', 'hyp:tok:there', 'hyp:tok:human'],
#               48.796: ['hyp:tag:jj', 'hyp:tok:there', 'hyp:tok:human']},
#              1018: {0.0: ['hyp:tok:watching',
#                'oth:overlap:overlap75',
#                'hyp:tok:eating'],
#               19.987: ['oth:overlap:overlap50',
#                'hyp:tok:watching',
#                'hyp:tok:eating'],
#               35.97: ['hyp:tok:watching',
#                'oth:overlap:overlap75',
#                'pre:tok:boy',
#                'hyp:tok:eating'],
#               48.796: ['oth:overlap:overlap75',
#                'pre:tok:boy',
#                'hyp:tok:sitting',
#                'hyp:tok:watching'],
#               59.017: ['pre:tok:boy',
#                'pre:tok:man',
#                'hyp:tok:sitting',
#                'hyp:tok:watching'],
#               67.22: ['hyp:tok:at',
#                'pre:tok:man',
#                'pre:tok:men',
#                'pre:tok:boy',
#                'hyp:tok:sitting'],
#               73.763: ['hyp:tag:nn', 'hyp:tok:sitting'],
#               79.004: ['hyp:tag:in',
#                'hyp:tok:dog',
#                'hyp:tag:vb',
#                'pre:tok:ball'],
#               83.203: ['hyp:tag:in',
#                'hyp:tok:to',
#                'pre:tag:in',
#                'hyp:tok:person'],
#               86.556: ['hyp:tag:in',
#                'hyp:tok:wearing',
#                'pre:tok:playing',
#                'pre:tok:ball'],
#               89.258: ['hyp:tag:in',
#                'hyp:tok:playing',
#                'hyp:tok:and',
#                'hyp:tag:nn'],
#               91.406: ['hyp:tag:vbg', 'oth:overlap:overlap50'],
#               93.099: ['hyp:tag:in', 'hyp:tag:nn', 'hyp:tok:to']},
#              1019: {0.0: ['hyp:tag:prp$',
#                'pre:tok:blue',
#                'hyp:tok:city',
#                'hyp:tok:championship'],
#               19.987: ['hyp:tag:prp$',
#                'pre:tok:blue',
#                'hyp:tok:city',
#                'hyp:tok:championship'],
#               35.97: ['hyp:tag:prp$',
#                'pre:tok:blue',
#                'hyp:tok:city',
#                'hyp:tok:championship'],
#               73.763: ['pre:tok:street',
#                'pre:tok:woman',
#                'hyp:tok:women',
#                'hyp:tok:race',
#                'hyp:tok:for'],
#               79.004: ['hyp:tok:talking',
#                'pre:tok:street',
#                'hyp:tok:building',
#                'hyp:tok:street',
#                'pre:tok:something'],
#               83.203: ['pre:tag:nn']},
#              1020: {0.0: ['hyp:tag:nnp',
#                'hyp:tok:tall',
#                'hyp:tok:professional',
#                'pre:tok:microphone',
#                'hyp:tok:first'],
#               19.987: ['hyp:tag:nnp',
#                'hyp:tok:tall',
#                'hyp:tok:professional',
#                'pre:tok:microphone',
#                'hyp:tok:first'],
#               35.97: ['hyp:tag:jj',
#                'hyp:tok:tall',
#                'hyp:tag:nnp',
#                'pre:tok:microphone'],
#               48.796: ['hyp:tag:nnp',
#                'hyp:tok:tall',
#                'pre:tok:talking',
#                'pre:tok:microphone',
#                'hyp:tok:first']},
#              1021: {0.0: ['oth:overlap:overlap50',
#                'pre:tok:red',
#                'hyp:tok:old',
#                'oth:overlap:overlap25'],
#               19.987: ['hyp:tok:man', 'oth:overlap:overlap50'],
#               35.97: ['oth:overlap:overlap50', 'pre:tag:nnp'],
#               48.796: ['hyp:tok:man', 'oth:overlap:overlap50', 'pre:tok:dog'],
#               59.017: ['pre:tag:jj', 'pre:tag:nnp'],
#               67.22: ['pre:tag:nnp',
#                'pre:tag:nns',
#                'pre:tok:red',
#                'pre:tag:vb'],
#               73.763: ['pre:tag:jj', 'pre:tag:vbp', 'pre:tok:street'],
#               79.004: ['pre:tag:dt'],
#               83.203: ['hyp:tag:in', 'pre:tok:man', 'pre:tok:are'],
#               86.556: ['hyp:tok:man',
#                'pre:tag:cc',
#                'hyp:tok:dog',
#                'pre:tok:shirt',
#                'pre:tag::'],
#               89.258: ['pre:tag:nn'],
#               91.406: ['pre:tag:dt', 'pre:tag:in', 'pre:tok:water'],
#               93.099: ['hyp:tag:in',
#                'oth:overlap:overlap25',
#                'hyp:tag:vb',
#                'hyp:tok:there',
#                'hyp:tag:prp$'],
#               94.499: ['hyp:tag:nn',
#                'hyp:tag:nns',
#                'hyp:tag:dt',
#                'hyp:tok:to']},
#              1022: {0.0: ['hyp:tok:people',
#                'pre:tok:woman',
#                'pre:tok:women',
#                'pre:tok:stage'],
#               19.987: ['hyp:tok:people',
#                'pre:tok:woman',
#                'pre:tok:stage',
#                'pre:tok:women'],
#               35.97: ['oth:overlap:overlap50', 'pre:tok:stage'],
#               48.796: ['hyp:tok:people',
#                'pre:tok:woman',
#                'pre:tok:girl',
#                'pre:tok:women'],
#               59.017: ['pre:tok:girl',
#                'pre:tok:woman',
#                'hyp:tag:ex',
#                'pre:tok:women'],
#               67.22: ['hyp:tok:people',
#                'pre:tok:woman',
#                'pre:tok:women',
#                'pre:tok:girl'],
#               73.763: ['pre:tag:nns', 'pre:tok:woman'],
#               79.004: ['hyp:tag:dt'],
#               83.203: ['hyp:tag:in', 'hyp:tok:man', 'pre:tok:woman'],
#               86.556: ['pre:tag:vbg',
#                'pre:tok:man',
#                'hyp:tag:nn',
#                'pre:tag:dt'],
#               89.258: ['hyp:tag:in', 'hyp:tag:vb', 'oth:overlap:overlap50'],
#               91.406: ['hyp:tag:in',
#                'hyp:tok:wearing',
#                'hyp:tok:person',
#                'hyp:tag:prp$'],
#               94.499: ['pre:tag:nn', 'hyp:tok:nobody']},
#              1023: {0.0: ['hyp:tok:outside',
#                'oth:overlap:overlap50',
#                'hyp:tok:walking'],
#               19.987: ['hyp:tok:outside',
#                'oth:overlap:overlap50',
#                'hyp:tok:walking'],
#               35.97: ['oth:overlap:overlap50',
#                'hyp:tok:outside',
#                'hyp:tok:walking'],
#               48.796: ['hyp:tok:people',
#                'oth:overlap:overlap75',
#                'hyp:tok:outside',
#                'pre:tok:bike'],
#               59.017: ['pre:tag:nns', 'pre:tok:man'],
#               67.22: ['pre:tag:nns', 'pre:tok:his', 'pre:tok:street'],
#               73.763: ['hyp:tag:in', 'hyp:tag:vbp', 'hyp:tag:prp$'],
#               79.004: ['hyp:tag:in', 'hyp:tok:to', 'hyp:tag:rb', 'pre:tag:dt'],
#               83.203: ['hyp:tag:in',
#                'hyp:tok:man',
#                'pre:tag:in',
#                'hyp:tag:cc'],
#               86.556: ['hyp:tag:vbg', 'pre:tag:cc', 'pre:tag:in', 'pre:tag:,'],
#               89.258: ['pre:tag:nn'],
#               91.406: ['hyp:tag:vbz', 'pre:tok:man'],
#               93.099: ['pre:tag:nn', 'pre:tok:dogs']},
#              50: {19.987: ['hyp:tok:man', 'pre:tok:pool', 'hyp:tok:eating']},
#              321: {19.987: ['hyp:tok:at', 'hyp:tok:in', 'pre:tok:helmet']},
#              367: {19.987: ['hyp:tok:inside',
#                'hyp:tok:sleeping',
#                'hyp:tok:asleep',
#                'hyp:tok:couch',
#                'hyp:tok:indoors']},
#              511: {19.987: ['hyp:tag:vbz',
#                'hyp:tok:sleeping',
#                'hyp:tok:alone'],
#               35.97: ['hyp:tag:rb',
#                'hyp:tok:sleeping',
#                'hyp:tok:couch',
#                'hyp:tok:eating'],
#               48.796: ['hyp:tok:alone',
#                'hyp:tok:sleeping',
#                'hyp:tok:couch',
#                'hyp:tok:asleep',
#                'hyp:tok:home']},
#              576: {19.987: ['hyp:tag:jj',
#                'hyp:tok:beach',
#                'hyp:tok:bench',
#                'hyp:tok:ocean']},
#              610: {19.987: ['hyp:tok:eating',
#                'hyp:tok:men',
#                'hyp:tok:nobody',
#                'hyp:tok:sits']},
#              665: {19.987: ['hyp:tok:woman',
#                'hyp:tok:sleeping',
#                'hyp:tok:swimming',
#                'hyp:tok:bench']},
#              690: {19.987: ['hyp:tok:sits', 'hyp:tok:sitting', 'hyp:tok:no'],
#               35.97: ['hyp:tok:sits',
#                'hyp:tok:sitting',
#                'hyp:tok:no',
#                'hyp:tok:laying'],
#               73.763: ['hyp:tok:her',
#                'hyp:tok:to',
#                'hyp:tok:women',
#                'hyp:tok:street',
#                'hyp:tok:race']},
#              736: {19.987: ['hyp:tok:running',
#                'pre:tok:sitting',
#                'pre:tok:small']},
#              749: {19.987: ['pre:tok:man', 'pre:tok:men', 'hyp:tok:cat'],
#               35.97: ['hyp:tok:women',
#                'pre:tok:water',
#                'hyp:tok:walking',
#                'pre:tok:ocean']},
#              842: {19.987: ['hyp:tag:.',
#                'hyp:tok:eating',
#                'hyp:tok:marathon']},
#              874: {19.987: ['pre:tok:people',
#                'pre:tok:standing',
#                'hyp:tok:eating'],
#               35.97: ['hyp:tok:eating',
#                'pre:tok:standing',
#                'hyp:tok:black',
#                'hyp:tok:drinking'],
#               48.796: ['hyp:tok:eating',
#                'hyp:tok:sitting',
#                'hyp:tok:black',
#                'hyp:tok:drinking']},
#              972: {19.987: ['hyp:tag:vb',
#                'hyp:tok:eating',
#                'pre:tok:elderly',
#                'hyp:tok:painting'],
#               48.796: ['hyp:tok:eating',
#                'hyp:tok:men',
#                'hyp:tok:blue',
#                'hyp:tok:cat',
#                'hyp:tok:drinking'],
#               73.763: ['hyp:tag:vbg', 'pre:tok:woman', 'pre:tok:women'],
#               79.004: ['pre:tag:dt', 'pre:tok:woman', 'hyp:tok:sitting'],
#               83.203: ['pre:tag:dt'],
#               86.556: ['pre:tag:dt', 'pre:tok:and', 'pre:tok:young'],
#               89.258: ['hyp:tag:nn', 'pre:tok:holding', 'pre:tag:vb'],
#               91.406: ['pre:tag:dt'],
#               93.099: ['pre:tag:nn'],
#               94.499: ['pre:tag:nn', 'hyp:tok:nobody']},
#              986: {19.987: ['hyp:tok:eating',
#                'hyp:tok:woman',
#                'hyp:tok:park']},
#              5: {35.97: ['hyp:tok:wearing', 'pre:tok:for', 'pre:tok:race'],
#               59.017: ['hyp:tok:sitting',
#                'hyp:tok:wearing',
#                'pre:tok:race',
#                'pre:tok:for']},
#              296: {35.97: ['pre:tag:.', 'hyp:tok:sleeping']},
#              342: {35.97: ['hyp:tok:nobody',
#                'hyp:tok:sitting',
#                'hyp:tok:swimming',
#                'hyp:tok:eating']},
#              470: {35.97: ['hyp:tok:alone',
#                'hyp:tok:sleeping',
#                'hyp:tok:swimming',
#                'hyp:tok:home',
#                'hyp:tok:laying'],
#               73.763: ['pre:tag:vbp',
#                'pre:tok:street',
#                'pre:tok:car',
#                'pre:tag:jjr'],
#               83.203: ['hyp:tok:man', 'pre:tok:are', 'pre:tok:people']},
#              529: {35.97: ['hyp:tok:eating',
#                'hyp:tok:sleeping',
#                'hyp:tok:sitting',
#                'hyp:tok:eats']},
#              602: {35.97: ['pre:tok:pool',
#                'pre:tok:street',
#                'hyp:tok:sitting',
#                'hyp:tok:alone'],
#               48.796: ['pre:tok:pool',
#                'pre:tok:street',
#                'hyp:tok:sitting',
#                'hyp:tok:park'],
#               59.017: ['hyp:tok:sitting',
#                'pre:tok:water',
#                'pre:tok:street',
#                'hyp:tok:park'],
#               67.22: ['pre:tag:nns', 'pre:tok:woman', 'pre:tok:water'],
#               73.763: ['hyp:tag:dt', 'hyp:tok:to'],
#               79.004: ['hyp:tok:man',
#                'pre:tok:street',
#                'hyp:tok:talking',
#                'hyp:tok:lady',
#                'hyp:tok:riding'],
#               83.203: ['hyp:tag:rb', 'oth:overlap:overlap25'],
#               91.406: ['oth:overlap:overlap25', 'oth:overlap:overlap75'],
#               93.099: ['pre:tag:nn']},
#              959: {35.97: ['hyp:tok:sitting',
#                'hyp:tok:sleeping',
#                'hyp:tok:eating',
#                'hyp:tok:sits']},
#              297: {73.763: ['hyp:tok:to',
#                'pre:tok:car',
#                'hyp:tok:old',
#                'hyp:tok:older',
#                'pre:tok:lot']},
#              334: {73.763: ['hyp:tag:prp$',
#                'hyp:tag:vbp',
#                'pre:tok:street',
#                'pre:tok:car']},
#              339: {73.763: ['hyp:tag:vbp',
#                'pre:tok:woman',
#                'hyp:tag:vb',
#                'hyp:tok:for'],
#               83.203: ['pre:tok:are', 'pre:tok:man', 'pre:tok:men']},
#              456: {73.763: ['hyp:tok:to',
#                'pre:tok:street',
#                'pre:tok:their',
#                'hyp:tok:race',
#                'hyp:tok:other']},
#              467: {73.763: ['hyp:tok:her',
#                'hyp:tok:women',
#                'pre:tok:race',
#                'hyp:tok:street',
#                'hyp:tok:couple']},
#              564: {73.763: ['hyp:tok:woman',
#                'hyp:tok:women',
#                'hyp:tok:her',
#                'hyp:tok:old',
#                'hyp:tok:older']},
#              614: {73.763: ['hyp:tag:prp$',
#                'hyp:tok:to',
#                'hyp:tok:women',
#                'hyp:tok:for',
#                'hyp:tok:race'],
#               83.203: ['pre:tok:are', 'pre:tok:man', 'pre:tok:horse']},
#              641: {73.763: ['hyp:tag:vbp',
#                'hyp:tok:woman',
#                'hyp:tok:to',
#                'hyp:tok:for'],
#               79.004: ['hyp:tok:are', 'hyp:tok:is', 'hyp:tok:woman'],
#               83.203: ['pre:tag:nns', 'pre:tok:man', 'pre:tok:person']},
#              786: {73.763: ['pre:tag:nns', 'pre:tok:woman', 'hyp:tag:prp$'],
#               79.004: ['hyp:tok:man',
#                'pre:tok:street',
#                'hyp:tok:lady',
#                'hyp:tok:talking'],
#               83.203: ['pre:tag:dt']},
#              835: {73.763: ['hyp:tag:vbp',
#                'pre:tok:woman',
#                'hyp:tok:to',
#                'hyp:tok:for'],
#               79.004: ['pre:tok:street', 'pre:tok:woman', 'hyp:tok:building'],
#               83.203: ['pre:tag:dt']},
#              965: {73.763: ['hyp:tok:her',
#                'hyp:tok:white',
#                'hyp:tok:women',
#                'hyp:tok:old',
#                'hyp:tok:older']}})
