# %%
import torch
dirs= [i for i in range(12)]

for d in dirs:
    for i in range(100):
        new_dir_in = f"New/In{0}/in{i}.pth"
        new_dir_out = f"New/Out{d}/out{i}.pth"
        old_dir_out = f"Old/Out{d}/out{i}.pth"
        old_dir_in = f"Old/In{6}/in{i}.pth"
        n = torch.load(new_dir_in)
        o = torch.load(old_dir_in)
        print(torch.where(o[0]==0,1,0).sum()/(o[0].shape[0]*o[0].shape[1]))
        print(n,o)
        break
    break
# Out:
# tensor(0., device='cuda:0')
# tensor([[[ 0.2700,  0.7876, -0.7428,  ...,  0.0771, -0.0668,  0.1543],
#          [ 0.5671, -0.0049,  0.1217,  ...,  0.4728,  0.7654,  0.0029],
#          [-0.4755,  1.1432, -0.6364,  ...,  0.0667,  0.1005, -0.0032],
#          ...,
#          [ 0.5922, -0.7185,  0.4286,  ...,  0.2101,  0.1039, -0.0624],
#          [-0.8044, -1.0833,  0.3990,  ..., -0.0045,  0.2063,  1.1872],
#          [-1.1291,  0.2671,  0.3025,  ...,  0.4508,  0.0549,  0.2338]]],
#        device='cuda:0') tensor([[[-0.4185, -0.7162,  0.2885,  ...,  0.0537, -0.3742,  0.2618],
#          [-1.8745,  0.6663,  0.5915,  ..., -0.1149,  0.7952,  0.2330],
#          [-0.2639, -1.0983,  0.5575,  ..., -0.4615, -0.1744, -0.6851],
#          ...,
#          [-0.1256,  0.6210,  0.3779,  ..., -0.1463,  0.3056,  0.1318],
#          [-0.1256,  0.6210,  0.3779,  ..., -0.1463,  0.3056,  0.1318],
#          [-0.4063,  0.4247,  0.7878,  ...,  0.1583,  0.2584, -0.3340]]],
# ...

# %% [markdown]
# o[0].shape

# %%
o[0].shape
# Out:
# torch.Size([100, 768])
