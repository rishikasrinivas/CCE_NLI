# %%
import torch
dirs= [i for i in range(12)]

for d in dirs:
    for i in range(100):
        new_dir_in = f"New/In{d}/in{i}.pth"
        new_dir_out = f"New/Out{d}/out{i}.pth"
        old_dir_out = f"Old/Out{d}/out{i}.pth"
        old_dir_in = f"Old/In{d}/in{i}.pth"
        n = torch.load(new_dir)
        o = torch.load(old_dir)
        print(n,o)
        break
    break
# Out:
# tensor([[ 0.0427, -0.0354, -0.1526,  ...,  0.0144, -0.0175,  0.1166],
#         [ 0.7282,  0.5802,  0.1120,  ...,  0.3854,  0.2284,  0.1472],
#         [-0.2671,  0.4019,  0.7899,  ..., -0.2557, -0.4917, -0.6056],
#         ...,
#         [ 0.1877,  0.6234, -0.2480,  ...,  0.1055,  0.3400, -0.1186],
#         [ 0.2569,  0.4342, -0.0906,  ...,  0.1130,  0.2055, -0.0542],
#         [ 0.2041,  0.5163, -0.0120,  ...,  0.1814,  0.4334,  0.0239]],
#        device='cuda:0', requires_grad=True) tensor([[ 0.0497, -0.0265, -0.0966,  ..., -0.0128, -0.0140,  0.0772],
#         [-0.0026,  0.4125,  0.1397,  ..., -0.4169,  0.1769, -0.4226],
#         [-0.0167, -0.1923,  0.3436,  ...,  0.3861,  1.0960, -0.5911],
#         ...,
#         [ 0.2607,  0.7204,  0.2430,  ..., -0.3257,  0.9039,  0.3780],
#         [ 0.2607,  0.7204,  0.2430,  ..., -0.3257,  0.9039,  0.3780],
#         [ 0.1765,  0.7418,  0.3822,  ...,  0.0280,  0.9028,  0.2065]],
#        device='cuda:0', requires_grad=True)
