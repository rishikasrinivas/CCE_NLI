# %%
import pandas as pd
import os
import re
from pathlib import Path
from collections import defaultdict
import json

class IterativeLotteryAnalyzer:
    def __init__(self, base_path):
        """
        base_path: Path to model/lottery_ticket directory
        """
        self.base_path = Path(base_path)
        self.prune_data = {}
    def get_indiv_concepts(self,formula) -> list:
        concepts = []
        concps = re.findall(r'(?<!\bNOT\s)(?:\b(?:hyp|pre|oth):[^\s)]+)', formula)
        for c in concps:
            try:
                end_idx = c.index(')')
            except:
                end_idx = len(c)
            concepts.append(c[:end_idx])
        return concepts

    def load_all_csvs(self):
        """Load all CSV files from the directory structure"""
        print("Loading CSV files...")
        
        for prune_dir in sorted(self.base_path.iterdir()):
      
            if not prune_dir.is_dir():
                continue
                
            try:
                match = str(prune_dir.name).split("%")
            except:
                continue
                
            prune_level = match[0]
            self.prune_data[prune_level] = {}
            print(prune_level)
            for csv_file in prune_dir.glob('Cluster*'):
                cluster_match = re.search(r'Cluster(\d+)', csv_file.name)
                if not cluster_match:
                    continue
                    
                cluster = cluster_match.group(1)
                
                try:
                    df = pd.read_csv(csv_file)
                    
                    if 'unit' not in df.columns or 'best_name' not in df.columns:
                        print(f"Warning: {csv_file} missing required columns")
                        continue
                    
                    df = df.dropna(subset=['unit', 'best_name'])
                    
                    concepts =[]
                    for row in df['best_name']:
                        concepts.append(set(self.get_indiv_concepts(row)))
                  
                    unit_to_concept = dict(zip(df['unit'], concepts))
                    concept=set()
                    for c in concepts:
                        concept.update(c)
                    self.prune_data[prune_level][cluster] = {
                        'concepts': concept,
                        'unit_to_concept': unit_to_concept,
                        'total_units': len(unit_to_concept),
                        'df': df
                    }
                    
                    
                    print(f"  Loaded: {prune_level}% prune, Cluster {cluster} - {len(concepts)} concepts, {len(unit_to_concept)} units")
                    
                except Exception as e:
                    print(f"Error loading {csv_file}: {e}")
        
        print(f"\nLoaded {len(self.prune_data)} pruning levels\n")
        return self
    def load_csv_data(self,filepath):
        """Load CSV and extract unit-concept mappings. Returns None if file not found."""
        if not Path(filepath).exists():
            return None
        try:
            df = pd.read_csv(filepath)
            unit_concepts = defaultdict(set)
            for _, row in df.iterrows():
                unit = row['unit']
                formula = row['best_name']
                #_, concepts , _= find_abstractions(get_indiv_concepts(formula))
                concepts= self.get_indiv_concepts(formula)
                unit_concepts[unit].update(concepts)
            return unit_concepts
        except Exception as e:
            print(f"  Warning: Could not load {filepath}: {e}")
            return None

    def analyze_iterative_changes(self):
        """Compare each pruning level to the previous one (iteration-to-iteration)"""
        prune_levels = sorted(self.prune_data.keys(), key=float)
        
        if len(prune_levels) < 2:
            print("Need at least 2 pruning levels for iterative analysis")
            return
        
        print(f"\n{'='*80}")
        print(f"ITERATIVE ANALYSIS: Changes Between Consecutive Pruning Levels")
        print(f"{'='*80}\n")
        csv_data_c1 = self.load_csv_data("/workspace/CCE_NLI/BERT/exp/pretrained/Expls/Cluster1IOUS1024N.csv")
        csv_data_c1 = set().union(*csv_data_c1.values())
        
        csv_data_c2 = self.load_csv_data("/workspace/CCE_NLI/BERT/exp/pretrained/Expls/Cluster2IOUS1024N.csv")
        csv_data_c2 = set().union(*csv_data_c2.values())
        
        csv_data_c3 = self.load_csv_data("/workspace/CCE_NLI/BERT/exp/pretrained/Expls/Cluster3IOUS1024N.csv")
        csv_data_c3 = set().union(*csv_data_c3.values())
        datas={'1':csv_data_c1, '2':csv_data_c2, '3':csv_data_c3}
        results = []
        baselines={}
        unique_to_iter={'1':set(), '2':set(), '3':set()}
        for i in range(len(prune_levels) - 1):
            prev_level = prune_levels[i]
            curr_level = prune_levels[i + 1]
            
            prev_data = self.prune_data[prev_level]
            curr_data = self.prune_data[curr_level]
            
            print(f"\n{'='*80}")
            print(f"FROM {prev_level}% → TO {curr_level}% PRUNING")
            print(f"{'='*80}")
            
            # Per-cluster analysis
            cluster_analysis = {}
            
            for cluster in sorted(curr_data.keys(), key=int):
                if cluster not in prev_data:
                    continue
                prev_cluster = prev_data[cluster]
                curr_cluster = curr_data[cluster]
                
                prev_concepts = prev_cluster['concepts']
                curr_concepts = curr_cluster['concepts']
                
                preserved = curr_concepts & prev_concepts
                lost = prev_concepts - curr_concepts
                new_concepts = curr_concepts - prev_concepts
                
                if prev_level=='0.0':
                    #unique_to_iter[cluster]=unique_to_iter[cluster].union(prev_concepts)
                    num_relearned=0
                    percent_relearned=0
                    numprevlost=0
                    baselines[cluster]=prev_concepts
        
                else:
                    num_relearned=len(new_concepts & prev_lost)
                    percent_relearned=num_relearned/len(prev_lost)
                    numprevlost=len(prev_lost)
                    unique_to_iter[cluster]=unique_to_iter[cluster].union(curr_concepts-baselines[cluster]-datas[cluster])
                    
                prev_lost=lost
                
                preservation_rate = (len(preserved) / len(prev_concepts) * 100) if prev_concepts else 0
                
                # Unit changes
                units_removed = prev_cluster['total_units'] - curr_cluster['total_units']
                units_removal_pct = (units_removed / prev_cluster['total_units'] * 100) if prev_cluster['total_units'] else 0
                
                cluster_analysis[cluster] = {
                    'preserved': len(preserved),
                    'lost': len(lost),
                    'new': len(new_concepts),
                    'preserved_list': sorted(preserved),
                    'lost_list': sorted(lost),
                    'new_list': sorted(new_concepts),
                    'prev_units': prev_cluster['total_units'],
                    'curr_units': curr_cluster['total_units'],
                    'units_removed': units_removed,
                    'units_removal_pct': units_removal_pct,
                    'preservation_rate': preservation_rate,
                    'num_relearned':num_relearned,
                    'percent_relearned':percent_relearned,
                    'prev_lost':numprevlost
                }
                
                '''print(f"\n  percent of lost that are in pretrained  {len(lost &datas[cluster])/len(lost)}:")
                print(f"\n  percent of lost that are in baselines  {len(lost &baselines[cluster])/len(lost)}:")
                print(f"\n  percent of lost that are in baseline&pretrained {len(lost &baselines[cluster]&datas[cluster])/len(lost)}:")
                print(f"\n  percent of lost that are in baseline&!pretrained {len(lost &baselines[cluster]-datas[cluster])/len(lost)}:")
                print(f"\n  percent of lost that are in !baseline&pretrained {len(lost &datas[cluster]-baselines[cluster])/len(lost)}:")
                print(f"\n  percent of lost that are not in baseline nor pretrained, they are in the {prev_level} at cluster {cluster} , {len(lost - datas[cluster]-baselines[cluster])/len(lost)}:")
                
                print(f"\n  percent of new concepts that are in baseline&pretrained {len(new_concepts &baselines[cluster]&datas[cluster])/len(new_concepts)}:")
                print(f"\n  percent of new concepts that are in baseline&!pretrained {len(new_concepts &baselines[cluster]-datas[cluster])/len(new_concepts)}:")
                print(f"\n  percent of new concepts that are in !baseline&pretrained {len(new_concepts &datas[cluster]-baselines[cluster])/len(new_concepts)}:")'''
                
                print(f"\n  Cluster {cluster}:")
                #lost concpets
                print("% of lost concepts that are lost from")
                print("\t\t dense&pretrained&previous_iter:", len(baselines[cluster]&datas[cluster]&prev_concepts&lost)/len(lost))
                print("\t\t dense&pretrained&notprevious_iter:", len(baselines[cluster]&datas[cluster]&lost-prev_concepts)/len(lost))
                
                print("\t\t pretrained but NOT dense&previous_iter:", len(datas[cluster]-baselines[cluster]&prev_concepts&lost)/len(lost))
                print("\t\t pretrained but NOT dense&!previous_iter:", len(datas[cluster]-baselines[cluster]&lost-prev_concepts)/len(lost))
                
                print("\t\t dense but NOT pretrained&previous_iter:", len(baselines[cluster]-datas[cluster]&prev_concepts&lost)/len(lost))
                print("\t\t previous_iter but not from dense nor pretrained:", len(prev_concepts-baselines[cluster]-datas[cluster]&lost)/len(lost))
                
                
                #new concepts
                
                print("% of new concepts that come from")
                truly_new = new_concepts - baselines[cluster] - datas[cluster] - unique_to_iter[cluster]
                print("\t\t truly brand new (never seen, not dense, not pt):", len(truly_new)/len(new_concepts))
                print("\t\t dense&pretrained:", len(baselines[cluster]&datas[cluster]&new_concepts)/len(new_concepts))
                print("\t\t pretrained but NOT dense:", len(datas[cluster]-baselines[cluster]&new_concepts)/len(new_concepts))
                print("\t\t dense but NOT pretrained:", len(baselines[cluster]-datas[cluster]&new_concepts)/len(new_concepts))
                print("\t\t not from dense nor pretrained:", len(new_concepts-baselines[cluster]-datas[cluster])/len(new_concepts))
                
               
                #existing concepts
                print("% of existing concepts that come from")
                print("\t\t dense&pretrained&previous_iter:", len(baselines[cluster]&datas[cluster]&prev_concepts&curr_concepts)/len(curr_concepts))
                print("\t\t dense&pretrained& not previous_iter:", len(baselines[cluster]&datas[cluster]-prev_concepts&curr_concepts)/len(curr_concepts))
                print("\t\t pretrained but NOT dense&previous_iter:", len(datas[cluster]-baselines[cluster]&prev_concepts&curr_concepts)/len(curr_concepts))
                print("\t\t pretrained but NOT dense& not previous_iter:", len(datas[cluster]-baselines[cluster]-prev_concepts&curr_concepts)/len(curr_concepts))
                print("\t\t dense but NOT pretrained&previous_iter:", len(baselines[cluster]-datas[cluster]&prev_concepts&curr_concepts)/len(curr_concepts))
                print("\t\t dense but NOT pretrained and not previous_iter:", len(baselines[cluster]-datas[cluster]-prev_concepts&curr_concepts)/len(curr_concepts))
                print("\t\t previous_iter but not from dense nor pretrained:", len(prev_concepts-baselines[cluster]-datas[cluster]&curr_concepts)/len(curr_concepts))
                print("\t\t not previous_iter , not from dense nor pretrained:", len(curr_concepts-prev_concepts-baselines[cluster]-datas[cluster])/len(curr_concepts))
                
                
                '''print(f"    Units: {prev_cluster['total_units']} → {curr_cluster['total_units']} (removed {units_removed}, {units_removal_pct:.1f}%)")
                print(f"    Concepts: {len(prev_concepts)} → {len(curr_concepts)}")
                print(f"    Preserved: {len(preserved)} ({preservation_rate:.1f}%)")
                print(f"    Lost: {len(lost)}")
                print(f"    New: {len(new_concepts)}")
                print(f"    num_relearned: {num_relearned}")
                print(f"    percent_relearned: {percent_relearned}")
                print(f"    prev_lost: {numprevlost}")
          
                if lost and len(lost) <= 10:
                    print(f"    Lost concepts: {', '.join(sorted(lost))}")
                elif lost:
                    print(f"    Lost concepts (sample): {', '.join(list(sorted(lost)))}")
                
                if new_concepts and len(new_concepts) <= 10:
                    print(f"    New concepts: {', '.join(sorted(new_concepts))}")
                elif new_concepts:
                    print(f"    New concepts (sample): {', '.join(list(sorted(new_concepts)))}...")'''
            
            # Global analysis
            all_prev_concepts = set()
            all_curr_concepts = set()
            for cluster_data in prev_data.values():
                all_prev_concepts.update(cluster_data['concepts'])
            for cluster_data in curr_data.values():
                all_curr_concepts.update(cluster_data['concepts'])
            
            global_preserved = all_curr_concepts & all_prev_concepts
            global_lost = all_prev_concepts - all_curr_concepts
            global_new = all_curr_concepts - all_prev_concepts
            
            global_preservation_rate = (len(global_preserved) / len(all_curr_concepts) * 100) if all_prev_concepts else 0
            
            if prev_level=='0.0':
                percent_relearned = 0
                num_relearned = 0
                num_lost = 0
                baseline=all_prev_concepts
            else:
                percent_relearned = len(global_new & prev_global_lost)/len(prev_global_lost)
                num_relearned = len(global_new & prev_global_lost)
                num_lost = len(prev_global_lost)
            print(f"\n  GLOBAL CHANGES:")
            '''print(f"    Total Concepts: {len(all_prev_concepts)} → {len(all_curr_concepts)}")
            print(f"    Preservation Rate from prev oter: {global_preservation_rate:.1f}%")
            print(f"    Lost in this step: {len(global_lost)}")
            print(f"    New in this step: {len(global_new)}")
            print(f"    percent_relearned in this step: {percent_relearned}")
            print(f"    num_relearned in this step: {num_relearned}")
            print(f"    num_lost in prev step: {num_lost}")'''
            print(f"    globally preservred from og: {len(baseline & all_curr_concepts)}/{len(all_curr_concepts)}= {len(baseline & all_curr_concepts) / len(all_curr_concepts)}")
            print(f"    globally preservred from og: {len(baseline & all_curr_concepts & csv_data_c1|csv_data_c2|csv_data_c3)}/{len(all_curr_concepts)}= {len(baseline & all_curr_concepts & csv_data_c1|csv_data_c2|csv_data_c3) / len(all_curr_concepts)}")
            
            ''''if global_lost:
                print(f"\n    Globally Lost Concepts in this step:")
                print(sorted(global_lost))
                print(f"total {len(global_lost)}")
            
            if global_new:
                print(f"\n    Globally New Concepts in this step:")
                print(sorted(global_new))
                print(f"total {len(global_new)}")
            
            results.append({
                'from_level': prev_level,
                'to_level': curr_level,
                'clusters': cluster_analysis,
                'global': {
                    'prev_total': len(all_prev_concepts),
                    'curr_total': len(all_curr_concepts),
                    'preserved': len(global_preserved),
                    'lost': len(global_lost),
                    'new': len(global_new),
                    'preservation_rate': global_preservation_rate,
                    'lost_concepts': sorted(global_lost),
                    'new_concepts': sorted(global_new),
                    'num_relearned': num_relearned,
                }
            })'''
            prev_global_lost=global_lost
        
        return results
    
    def concept_survival_rate(self):
        """Track which concepts survive the longest and which die first"""
        prune_levels = sorted(self.prune_data.keys(), key=int)
        
        print(f"\n{'='*80}")
        print(f"CONCEPT SURVIVAL ANALYSIS")
        print(f"{'='*80}\n")
        
        # Get all concepts from baseline
        baseline = self.prune_data[prune_levels[0]]
        all_concepts = set()
        for cluster_data in baseline.values():
            all_concepts.update(cluster_data['concepts'])
        
        # Track when each concept is lost
        concept_survival = {}
        for concept in all_concepts:
            last_seen = None
            for level in prune_levels:
                # Check if concept exists in this level
                exists = False
                for cluster_data in self.prune_data[level].values():
                    if concept in cluster_data['concepts']:
                        exists = True
                        last_seen = level
                        break
                if not exists and last_seen is not None:
                    break
            concept_survival[concept] = last_seen if last_seen else prune_levels[0]
        
        # Group by survival level
        survival_groups = defaultdict(list)
        for concept, last_level in concept_survival.items():
            survival_groups[last_level].append(concept)
        
        print("Concepts lost at each pruning step:\n")
        for level in prune_levels[1:]:  # Skip baseline
            prev_level = str(int(level) - (int(prune_levels[1]) - int(prune_levels[0])))
            if prev_level in survival_groups:
                concepts_lost = [c for c in survival_groups[prev_level]]
                if concepts_lost:
                    print(f"  Lost between {prev_level}% → {level}%: {len(concepts_lost)} concepts")
                    if len(concepts_lost) <= 15:
                        for c in sorted(concepts_lost):
                            print(f"    - {c}")
                    else:
                        for c in sorted(concepts_lost)[:10]:
                            print(f"    - {c}")
                        print(f"    ... and {len(concepts_lost) - 10} more")
                    print()
        
        # Survivors
        final_level = prune_levels[-1]
        survivors = survival_groups[final_level]
        print(f"\n  Concepts surviving to {final_level}% pruning: {len(survivors)}")
        if len(survivors) <= 30:
            print(f"  Survivors:")
            for c in sorted(survivors):
                print(f"    ✓ {c}")
        else:
            print(f"  Top survivors (sample):")
            for c in sorted(survivors)[:20]:
                print(f"    ✓ {c}")
            print(f"    ... and {len(survivors) - 20} more")
        
        return survival_groups
    
    def cluster_transfer_analysis(self):
        """Analyze if concepts move between clusters during pruning"""
        prune_levels = sorted(self.prune_data.keys(), key=int)
        
        print(f"\n{'='*80}")
        print(f"CLUSTER TRANSFER ANALYSIS")
        print(f"{'='*80}\n")
        
        for i in range(len(prune_levels) - 1):
            prev_level = prune_levels[i]
            curr_level = prune_levels[i + 1]
            
            print(f"\nFrom {prev_level}% → {curr_level}%:")
            
            # Track where each concept was and where it is now
            prev_concept_clusters = defaultdict(set)
            curr_concept_clusters = defaultdict(set)
            
            for cluster, cluster_data in self.prune_data[prev_level].items():
                for concept in cluster_data['concepts']:
                    prev_concept_clusters[concept].add(cluster)
            
            for cluster, cluster_data in self.prune_data[curr_level].items():
                for concept in cluster_data['concepts']:
                    curr_concept_clusters[concept].add(cluster)
            
            # Find concepts that changed clusters
            transferred = []
            for concept in curr_concept_clusters:
                if concept in prev_concept_clusters:
                    if prev_concept_clusters[concept] != curr_concept_clusters[concept]:
                        transferred.append({
                            'concept': concept,
                            'from': sorted(prev_concept_clusters[concept]),
                            'to': sorted(curr_concept_clusters[concept])
                        })
            
            if transferred:
                print(f"  Concepts that moved clusters: {len(transferred)}")
                for item in transferred[:15]:  # Show first 15
                    print(f"    '{item['concept']}': clusters {item['from']} → {item['to']}")
                if len(transferred) > 15:
                    print(f"    ... and {len(transferred) - 15} more")
            else:
                print(f"  No concepts transferred between clusters")
    
    def save_results(self, results, output_file='iterative_analysis_resultsBowman.json'):
        """Save analysis results to JSON"""
        def convert_sets(obj):
            if isinstance(obj, set):
                return sorted(list(obj))
            elif isinstance(obj, dict):
                return {k: convert_sets(v) for k, v in obj.items()}
            elif isinstance(obj, list):
                return [convert_sets(item) for item in obj]
            return obj
        
        results_serializable = convert_sets(results)
        
        with open(output_file, 'w') as f:
            json.dump(results_serializable, f, indent=2)
        print(f"\n\nResults saved to {output_file}")


# Example usage
if __name__ == "__main__":
    base_path = "/workspace/CCE_NLI/BERT/exp/lottery_ticket/Run0.25_5/Expls"  # Adjust this path
    
    analyzer = IterativeLotteryAnalyzer(base_path)
    analyzer.load_all_csvs()
    
    # Main iterative analysis (step-by-step changes)
    print("\n" + "="*80)
    print("RUNNING ITERATIVE ANALYSIS")
    print("="*80)
    results = analyzer.analyze_iterative_changes()
    analyzer.save_results(results)
    
    # Survival analysis (which concepts die first/last)
    analyzer.concept_survival_rate()
    
    # Transfer analysis (concepts moving between clusters)
    analyzer.cluster_transfer_analysis()
    
    print("\n\nAnalysis complete!")
# Out:
# Loading CSV files...
# 0.0
#   Loaded: 0.0% prune, Cluster 2 - 1024 concepts, 1024 units
#   Loaded: 0.0% prune, Cluster 3 - 934 concepts, 934 units
#   Loaded: 0.0% prune, Cluster 1 - 1024 concepts, 1024 units
# 25.0
#   Loaded: 25.0% prune, Cluster 1 - 1024 concepts, 1024 units
#   Loaded: 25.0% prune, Cluster 2 - 1024 concepts, 1024 units
#   Loaded: 25.0% prune, Cluster 3 - 942 concepts, 942 units
# 43.75
#   Loaded: 43.75% prune, Cluster 1 - 1024 concepts, 1024 units
#   Loaded: 43.75% prune, Cluster 2 - 1024 concepts, 1024 units
#   Loaded: 43.75% prune, Cluster 3 - 954 concepts, 954 units
# 57.812
#   Loaded: 57.812% prune, Cluster 1 - 1024 concepts, 1024 units
#   Loaded: 57.812% prune, Cluster 2 - 1024 concepts, 1024 units
#   Loaded: 57.812% prune, Cluster 3 - 977 concepts, 977 units
# 68.359
#   Loaded: 68.359% prune, Cluster 1 - 1024 concepts, 1024 units
#   Loaded: 68.359% prune, Cluster 2 - 1024 concepts, 1024 units
#   Loaded: 68.359% prune, Cluster 3 - 982 concepts, 982 units
# 76.27
#   Loaded: 76.27% prune, Cluster 1 - 1024 concepts, 1024 units
#   Loaded: 76.27% prune, Cluster 2 - 1024 concepts, 1024 units
#   Loaded: 76.27% prune, Cluster 3 - 961 concepts, 961 units
#
# Loaded 6 pruning levels
#
#
# ================================================================================
# RUNNING ITERATIVE ANALYSIS
# ================================================================================
#
# ================================================================================
# ITERATIVE ANALYSIS: Changes Between Consecutive Pruning Levels
# ================================================================================
#
#
# ================================================================================
# FROM 0.0% → TO 25.0% PRUNING
# ================================================================================
#
#   Cluster 1:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.3333333333333333
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.0
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.6666666666666666
# 		 previous_iter but not from dense nor pretrained: 0.0
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.5
# 		 dense&pretrained: 0.0
# 		 pretrained but NOT dense: 0.5
# 		 dense but NOT pretrained: 0.0
# 		 not from dense nor pretrained: 0.5
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.6818181818181818
# 		 dense&pretrained& not previous_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.0
# 		 pretrained but NOT dense& not previous_iter: 0.1038961038961039
# 		 dense but NOT pretrained&previous_iter: 0.11038961038961038
# 		 dense but NOT pretrained and not previous_iter: 0.0
# 		 previous_iter but not from dense nor pretrained: 0.0
# 		 not previous_iter , not from dense nor pretrained: 0.1038961038961039
#
#   Cluster 2:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.375
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.0
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.625
# 		 previous_iter but not from dense nor pretrained: 0.0
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.8070175438596491
# 		 dense&pretrained: 0.0
# 		 pretrained but NOT dense: 0.19298245614035087
# 		 dense but NOT pretrained: 0.0
# 		 not from dense nor pretrained: 0.8070175438596491
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.48826291079812206
# 		 dense&pretrained& not previous_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.0
# 		 pretrained but NOT dense& not previous_iter: 0.051643192488262914
# 		 dense but NOT pretrained&previous_iter: 0.24413145539906103
# 		 dense but NOT pretrained and not previous_iter: 0.0
# 		 previous_iter but not from dense nor pretrained: 0.0
# 		 not previous_iter , not from dense nor pretrained: 0.215962441314554
#
#   Cluster 3:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.125
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.0
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.875
# 		 previous_iter but not from dense nor pretrained: 0.0
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.8518518518518519
# 		 dense&pretrained: 0.0
# 		 pretrained but NOT dense: 0.14814814814814814
# 		 dense but NOT pretrained: 0.0
# 		 not from dense nor pretrained: 0.8518518518518519
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.26540284360189575
# 		 dense&pretrained& not previous_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.0
# 		 pretrained but NOT dense& not previous_iter: 0.037914691943127965
# 		 dense but NOT pretrained&previous_iter: 0.4786729857819905
# 		 dense but NOT pretrained and not previous_iter: 0.0
# 		 previous_iter but not from dense nor pretrained: 0.0
# 		 not previous_iter , not from dense nor pretrained: 0.21800947867298578
#
#   GLOBAL CHANGES:
#     globally preservred from og: 373/485= 0.7690721649484537
#     globally preservred from og: 323/485= 0.6659793814432989
#
# ================================================================================
# FROM 25.0% → TO 43.75% PRUNING
# ================================================================================
#
#   Cluster 1:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.1935483870967742
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.22580645161290322
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.12903225806451613
# 		 previous_iter but not from dense nor pretrained: 0.45161290322580644
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.1568627450980392
# 		 pretrained but NOT dense: 0.21568627450980393
# 		 dense but NOT pretrained: 0.21568627450980393
# 		 not from dense nor pretrained: 0.4117647058823529
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.5689655172413793
# 		 dense&pretrained& not previous_iter: 0.04597701149425287
# 		 pretrained but NOT dense&previous_iter: 0.05172413793103448
# 		 pretrained but NOT dense& not previous_iter: 0.06321839080459771
# 		 dense but NOT pretrained&previous_iter: 0.07471264367816093
# 		 dense but NOT pretrained and not previous_iter: 0.06321839080459771
# 		 previous_iter but not from dense nor pretrained: 0.011494252873563218
# 		 not previous_iter , not from dense nor pretrained: 0.1206896551724138
#
#   Cluster 2:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.15254237288135594
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.1016949152542373
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.3220338983050847
# 		 previous_iter but not from dense nor pretrained: 0.423728813559322
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.15254237288135594
# 		 pretrained but NOT dense: 0.2711864406779661
# 		 dense but NOT pretrained: 0.13559322033898305
# 		 not from dense nor pretrained: 0.4406779661016949
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.4460093896713615
# 		 dense&pretrained& not previous_iter: 0.04225352112676056
# 		 pretrained but NOT dense&previous_iter: 0.023474178403755867
# 		 pretrained but NOT dense& not previous_iter: 0.07511737089201878
# 		 dense but NOT pretrained&previous_iter: 0.15492957746478872
# 		 dense but NOT pretrained and not previous_iter: 0.03755868544600939
# 		 previous_iter but not from dense nor pretrained: 0.09859154929577464
# 		 not previous_iter , not from dense nor pretrained: 0.12206572769953052
#
#   Cluster 3:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.061224489795918366
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.11224489795918367
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.32653061224489793
# 		 previous_iter but not from dense nor pretrained: 0.5
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.05737704918032787
# 		 pretrained but NOT dense: 0.07377049180327869
# 		 dense but NOT pretrained: 0.23770491803278687
# 		 not from dense nor pretrained: 0.6311475409836066
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.23766816143497757
# 		 dense&pretrained& not previous_iter: 0.01569506726457399
# 		 pretrained but NOT dense&previous_iter: 0.011210762331838564
# 		 pretrained but NOT dense& not previous_iter: 0.020179372197309416
# 		 dense but NOT pretrained&previous_iter: 0.3811659192825112
# 		 dense but NOT pretrained and not previous_iter: 0.06502242152466367
# 		 previous_iter but not from dense nor pretrained: 0.09641255605381166
# 		 not previous_iter , not from dense nor pretrained: 0.1726457399103139
#
#   GLOBAL CHANGES:
#     globally preservred from og: 379/507= 0.747534516765286
#     globally preservred from og: 321/507= 0.6331360946745562
#
# ================================================================================
# FROM 43.75% → TO 57.812% PRUNING
# ================================================================================
#
#   Cluster 1:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.18
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.28
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.14
# 		 previous_iter but not from dense nor pretrained: 0.4
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.16666666666666666
# 		 pretrained but NOT dense: 0.16666666666666666
# 		 dense but NOT pretrained: 0.1
# 		 not from dense nor pretrained: 0.5666666666666667
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.6363636363636364
# 		 dense&pretrained& not previous_iter: 0.032467532467532464
# 		 pretrained but NOT dense&previous_iter: 0.03896103896103896
# 		 pretrained but NOT dense& not previous_iter: 0.032467532467532464
# 		 dense but NOT pretrained&previous_iter: 0.11038961038961038
# 		 dense but NOT pretrained and not previous_iter: 0.01948051948051948
# 		 previous_iter but not from dense nor pretrained: 0.01948051948051948
# 		 not previous_iter , not from dense nor pretrained: 0.11038961038961038
#
#   Cluster 2:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.1111111111111111
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.14814814814814814
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.16666666666666666
# 		 previous_iter but not from dense nor pretrained: 0.5740740740740741
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.14516129032258066
# 		 pretrained but NOT dense: 0.16129032258064516
# 		 dense but NOT pretrained: 0.24193548387096775
# 		 not from dense nor pretrained: 0.45161290322580644
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.4434389140271493
# 		 dense&pretrained& not previous_iter: 0.04072398190045249
# 		 pretrained but NOT dense&previous_iter: 0.058823529411764705
# 		 pretrained but NOT dense& not previous_iter: 0.04524886877828054
# 		 dense but NOT pretrained&previous_iter: 0.14479638009049775
# 		 dense but NOT pretrained and not previous_iter: 0.06787330316742081
# 		 previous_iter but not from dense nor pretrained: 0.07239819004524888
# 		 not previous_iter , not from dense nor pretrained: 0.12669683257918551
#
#   Cluster 3:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.027777777777777776
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.037037037037037035
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.32407407407407407
# 		 previous_iter but not from dense nor pretrained: 0.6111111111111112
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.04065040650406504
# 		 pretrained but NOT dense: 0.12195121951219512
# 		 dense but NOT pretrained: 0.2682926829268293
# 		 not from dense nor pretrained: 0.5691056910569106
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.2386117136659436
# 		 dense&pretrained& not previous_iter: 0.010845986984815618
# 		 pretrained but NOT dense&previous_iter: 0.021691973969631236
# 		 pretrained but NOT dense& not previous_iter: 0.03253796095444685
# 		 dense but NOT pretrained&previous_iter: 0.3557483731019523
# 		 dense but NOT pretrained and not previous_iter: 0.07158351409978309
# 		 previous_iter but not from dense nor pretrained: 0.11713665943600868
# 		 not previous_iter , not from dense nor pretrained: 0.15184381778741865
#
#   GLOBAL CHANGES:
#     globally preservred from og: 375/521= 0.7197696737044146
#     globally preservred from og: 321/521= 0.6161228406909789
#
# ================================================================================
# FROM 57.812% → TO 68.359% PRUNING
# ================================================================================
#
#   Cluster 1:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.23076923076923078
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.20512820512820512
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.20512820512820512
# 		 previous_iter but not from dense nor pretrained: 0.358974358974359
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.20512820512820512
# 		 pretrained but NOT dense: 0.28205128205128205
# 		 dense but NOT pretrained: 0.10256410256410256
# 		 not from dense nor pretrained: 0.41025641025641024
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.6103896103896104
# 		 dense&pretrained& not previous_iter: 0.05194805194805195
# 		 pretrained but NOT dense&previous_iter: 0.01948051948051948
# 		 pretrained but NOT dense& not previous_iter: 0.07142857142857142
# 		 dense but NOT pretrained&previous_iter: 0.07792207792207792
# 		 dense but NOT pretrained and not previous_iter: 0.025974025974025976
# 		 previous_iter but not from dense nor pretrained: 0.03896103896103896
# 		 not previous_iter , not from dense nor pretrained: 0.1038961038961039
#
#   Cluster 2:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.08333333333333333
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.23333333333333334
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.2
# 		 previous_iter but not from dense nor pretrained: 0.48333333333333334
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.12
# 		 pretrained but NOT dense: 0.26
# 		 dense but NOT pretrained: 0.18
# 		 not from dense nor pretrained: 0.44
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.4834123222748815
# 		 dense&pretrained& not previous_iter: 0.02843601895734597
# 		 pretrained but NOT dense&previous_iter: 0.04265402843601896
# 		 pretrained but NOT dense& not previous_iter: 0.061611374407582936
# 		 dense but NOT pretrained&previous_iter: 0.16587677725118483
# 		 dense but NOT pretrained and not previous_iter: 0.04265402843601896
# 		 previous_iter but not from dense nor pretrained: 0.07109004739336493
# 		 not previous_iter , not from dense nor pretrained: 0.10426540284360189
#
#   Cluster 3:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.034782608695652174
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.10434782608695652
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.1826086956521739
# 		 previous_iter but not from dense nor pretrained: 0.6782608695652174
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.056074766355140186
# 		 pretrained but NOT dense: 0.08411214953271028
# 		 dense but NOT pretrained: 0.3177570093457944
# 		 not from dense nor pretrained: 0.5420560747663551
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.24503311258278146
# 		 dense&pretrained& not previous_iter: 0.013245033112582781
# 		 pretrained but NOT dense&previous_iter: 0.02869757174392936
# 		 pretrained but NOT dense& not previous_iter: 0.019867549668874173
# 		 dense but NOT pretrained&previous_iter: 0.38852097130242824
# 		 dense but NOT pretrained and not previous_iter: 0.07505518763796909
# 		 previous_iter but not from dense nor pretrained: 0.10154525386313466
# 		 not previous_iter , not from dense nor pretrained: 0.1280353200883002
#
#   GLOBAL CHANGES:
#     globally preservred from og: 385/504= 0.7638888888888888
#     globally preservred from og: 322/504= 0.6388888888888888
#
# ================================================================================
# FROM 68.359% → TO 76.27% PRUNING
# ================================================================================
#
#   Cluster 1:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.1388888888888889
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.16666666666666666
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.19444444444444445
# 		 previous_iter but not from dense nor pretrained: 0.5
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.13953488372093023
# 		 pretrained but NOT dense: 0.3488372093023256
# 		 dense but NOT pretrained: 0.13953488372093023
# 		 not from dense nor pretrained: 0.37209302325581395
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.6024844720496895
# 		 dense&pretrained& not previous_iter: 0.037267080745341616
# 		 pretrained but NOT dense&previous_iter: 0.049689440993788817
# 		 pretrained but NOT dense& not previous_iter: 0.09316770186335403
# 		 dense but NOT pretrained&previous_iter: 0.055900621118012424
# 		 dense but NOT pretrained and not previous_iter: 0.037267080745341616
# 		 previous_iter but not from dense nor pretrained: 0.024844720496894408
# 		 not previous_iter , not from dense nor pretrained: 0.09937888198757763
#
#   Cluster 2:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.10204081632653061
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.2653061224489796
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.14285714285714285
# 		 previous_iter but not from dense nor pretrained: 0.4897959183673469
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.09615384615384616
# 		 pretrained but NOT dense: 0.21153846153846154
# 		 dense but NOT pretrained: 0.21153846153846154
# 		 not from dense nor pretrained: 0.4807692307692308
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.48130841121495327
# 		 dense&pretrained& not previous_iter: 0.02336448598130841
# 		 pretrained but NOT dense&previous_iter: 0.04205607476635514
# 		 pretrained but NOT dense& not previous_iter: 0.0514018691588785
# 		 dense but NOT pretrained&previous_iter: 0.17289719626168223
# 		 dense but NOT pretrained and not previous_iter: 0.0514018691588785
# 		 previous_iter but not from dense nor pretrained: 0.06074766355140187
# 		 not previous_iter , not from dense nor pretrained: 0.11682242990654206
#
#   Cluster 3:
# % of lost concepts that are lost from
# 		 dense&pretrained&previous_iter: 0.08928571428571429
# 		 dense&pretrained&notprevious_iter: 0.0
# 		 pretrained but NOT dense&previous_iter: 0.08035714285714286
# 		 pretrained but NOT dense&!previous_iter: 0.0
# 		 dense but NOT pretrained&previous_iter: 0.32142857142857145
# 		 previous_iter but not from dense nor pretrained: 0.5089285714285714
# % of new concepts that come from
# 		 truly brand new (never seen, not dense, not pt): 0.0
# 		 dense&pretrained: 0.009900990099009901
# 		 pretrained but NOT dense: 0.06930693069306931
# 		 dense but NOT pretrained: 0.31683168316831684
# 		 not from dense nor pretrained: 0.6039603960396039
# % of existing concepts that come from
# 		 dense&pretrained&previous_iter: 0.2420814479638009
# 		 dense&pretrained& not previous_iter: 0.0022624434389140274
# 		 pretrained but NOT dense&previous_iter: 0.029411764705882353
# 		 pretrained but NOT dense& not previous_iter: 0.01583710407239819
# 		 dense but NOT pretrained&previous_iter: 0.3936651583710407
# 		 dense but NOT pretrained and not previous_iter: 0.07239819004524888
# 		 previous_iter but not from dense nor pretrained: 0.10633484162895927
# 		 not previous_iter , not from dense nor pretrained: 0.13800904977375567
#
#   GLOBAL CHANGES:
#     globally preservred from og: 379/503= 0.7534791252485089
#     globally preservred from og: 323/503= 0.6421471172962226
#
#
# Results saved to iterative_analysis_resultsBowman.json
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 464
#     461 analyzer.save_results(results)
#     463 # Survival analysis (which concepts die first/last)
# --> 464 analyzer.concept_survival_rate()
#     466 # Transfer analysis (concepts moving between clusters)
#     467 analyzer.cluster_transfer_analysis()
#
# Cell In[49], line 320, in IterativeLotteryAnalyzer.concept_survival_rate(self)
#     318 def concept_survival_rate(self):
#     319     """Track which concepts survive the longest and which die first"""
# --> 320     prune_levels = sorted(self.prune_data.keys(), key=int)
#     322     print(f"\n{'='*80}")
#     323     print(f"CONCEPT SURVIVAL ANALYSIS")
#
# ValueError: invalid literal for int() with base 10: '0.0'

# %%
from collections import defaultdict
class LTH_Wanda_NumConcept_Comparison:
    def __init__(self):
        self.lottery_ticket_concepts = defaultdict(list)
        self.wanda_concepts = defaultdict(list)
        
    def get_indiv_concepts(self,formula) -> set:
        concepts = []
        concps = re.findall(r'(?<!\bNOT\s)(?:\b(?:hyp|pre|oth):[^\s)]+)', formula)
        for c in concps:
            try:
                end_idx = c.index(')')
            except:
                end_idx = len(c)
            concepts.append(c[:end_idx])
        return set(concepts)
    
    def lth_wanda_comparison(self, sparsity):
        for cluster in range(1,4):
            print(f"Cluster {cluster}:\n\tNumber of LTH Concpets: {len(self.lottery_ticket_concepts[sparsity][f'Cluster{cluster}'])}\n\tNumber of wanda concepts: {len(self.wanda_concepts[sparsity][f'Cluster{cluster}'])}")
        
    def get_lth_concepts(self, model, method, filename):
        path = os.path.join('/workspace/CCE_NLI', model.upper(), 'exp', method, filename, 'Expls')
        for pi in sorted(os.listdir(path)):
            print(pi)
            method_concepts = {}
            for cluster in range(1,4):
                concepts=set()
                try:
                    csv = pd.read_csv(f"{os.path.join(path, pi, f'Cluster{cluster}IOUS1024N.csv')}")
                except:
                    print(f"pass")
                    continue
                for formula in csv['best_name']:
                    
                    concepts=concepts.union(self.get_indiv_concepts(formula))
                    
                method_concepts.update({f'Cluster{cluster}': concepts})
            if method == 'lottery_ticket':
                self.lottery_ticket_concepts[pi]=(method_concepts)
            elif method == 'wanda':
                self.wanda_concepts[pi]=(method_concepts)
        print(self.wanda_concepts['0.0%Pruned'])
compare = LTH_Wanda_NumConcept_Comparison()
MODEL='BOWMAN'
FILENAME='Run0.25_3'
compare.get_lth_concepts(MODEL, 'lottery_ticket', FILENAME)
compare.get_lth_concepts(MODEL, 'wanda', FILENAME)
compare.lth_wanda_comparison('25.0%Pruned')
# Out:
# 0.0%Pruned
# 25.0%Pruned
# 43.75%Pruned
# 57.812%Pruned
# 68.359%Pruned
# pass
# 76.27%Pruned
# 82.202%Pruned
# []
# 25.0%Pruned
# 43.75%Pruned
# 57.812%Pruned
# 68.359%Pruned
# 76.27%Pruned
# []
# Cluster 1:
# 	Number of LTH Concpets: 37
# 	Number of wanda concepts: 43
# Cluster 2:
# 	Number of LTH Concpets: 30
# 	Number of wanda concepts: 34
# Cluster 3:
# 	Number of LTH Concpets: 6
# 	Number of wanda concepts: 15
