# %%
import pandas as pd
import re
from collections import defaultdict
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

import os
def get_indiv_concepts(formula) -> list:
    concepts = []
    concps = re.findall(r'(NOT\s+\w+:\w+:\S+|\w+:\w+:\S+)', formula)
    for c in concps:
        try:
            end_idx = c.index(')')
        except:
            end_idx = len(c)
        concepts.append(c[:end_idx])
    return concepts



def load_csv_data(filepath):
    """Load CSV and extract unit-concept mappings."""
    df = pd.read_csv(filepath)
    unit_concepts = defaultdict(set)
    raw_concepts= []
    for _, row in df.iterrows():
        unit = row['unit']
        formula = row['best_name']
        concepts = get_indiv_concepts(formula)
        
        unit_concepts[unit].update(concepts)
        raw_concepts.extend(concepts)
        
    
    return unit_concepts, raw_concepts

# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk import pos_tag
from collections import defaultdict
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')

SUPERSENSE_TO_CATEGORY = {
    # Verbs
    "verb.motion": "actions",
    "verb.contact": "actions",
    "verb.consumption": "actions",
    "verb.stative": "states",
    "verb.perception": "states",

    # Nouns
    "noun.location": "locations",
    "noun.person": "object",
    "noun.animal": "object",
    "noun.artifact": "object",
    "noun.object": "object",
    "noun.food": "object",
    "noun.substance": "object",

    # Adjectives
    "adj.all": "adjectives",
    "adj.pert": "adjectives"
}

def to_wn_pos(word):
    doc = nlp(word)
    for token in doc:
        
        if 'NN' in token.tag_ :
            return wn.NOUN
        elif 'VB' in token.tag_  :
            return wn.VERB
        elif 'JJ' in token.tag_:
            return wn.ADJ
        elif 'RB' in token.tag_:
            return wn.ADV
    return None

def get_supersense(word, pos):
    synsets = wn.synsets(word, pos=pos)
    if not synsets:
        return None
    return synsets[0].lexname()

def is_pos_ambiguous(word):
    pos_list = []
    for pos in [wn.NOUN, wn.VERB, wn.ADJ, wn.ADV]:
        if wn.synsets(word, pos=pos):
            pos_list.append(pos)
    return len(pos_list) > 1, pos_list

def categorize_words(words):
    words =list([word.split(":")[-1] for word in words])
    categories = defaultdict(list)



    for word in words:
        if word == 'AND' or word=='OR': continue
        wn_pos = to_wn_pos(word)

        if wn_pos is None:
            categories["function_words"].append(word)
            continue

        supersense = get_supersense(word, wn_pos)

        if supersense is None:
            categories["POS"].append(word)
            continue

        category = SUPERSENSE_TO_CATEGORY.get(supersense, "other")
        categories[category].append(word)

    return dict(categories)

_, rawc1 = load_csv_data(filepath='/workspace/CCE_NLI/BERT/exp/CoFi/Run0.25_5/Expls/0.27243559109531656%Pruned/Cluster1IOUS1024N.csv')
_, rawc2 = load_csv_data(filepath='/workspace/CCE_NLI/BERT/exp/CoFi/Run0.25_new/Expls/0.27243559109531656%Pruned/Cluster2IOUS1024N.csv')
_, rawc3 = load_csv_data(filepath='/workspace/CCE_NLI/BERT/exp/CoFi/Run0.25_new/Expls/0.27243559109531656%Pruned/Cluster3IOUS1024N.csv')
print("Loaded CSV Data")
categsc1=categorize_words(rawc1)
categsc2=categorize_words(rawc2)
categsc3=categorize_words(rawc3)

# %%
def count(concepts, token, remove_not=False):
    inc = 0
    raw = []
    for i in concepts:
        if 'AND' in i or 'OR' in i:
            assert False
        if remove_not:
            
            if token in i and 'NOT' not in i:
                
                inc += 1
        else:
            if token in i:
                inc += 1
        raw.append(i)
    return raw, inc

# %%
pd.DataFrame(cluster_results).to_csv("/workspace/CCE_NLI/BERT/exp/CoFi/Run0.25_5/concept_count_without_redundnacy.csv")

# %%
#unique concept dist

methods = ['CoFi', 'lottery_ticket']
fig_concept_counts, axes_concept_counts = plt.subplots(2, 3, figsize=(15, 8), sharey=True)
fig_accuracies, axes_accuracies = plt.subplots(1,2, figsize=(8, 4), sharey=True)
fig_totalConcepts, axes_totalConcepts = plt.subplots(1,2, figsize=(8, 4), sharey=True)
fig_explNeurons, axes_explNeurons = plt.subplots(1,2, figsize=(8, 4), sharey=True)

for row, m in enumerate(methods):
    # Collect filepaths for this method
    filepaths = [
        f'/workspace/CCE_NLI/BERT/exp/{m}/Run0.25_5/Expls/', 
        f'/workspace/CCE_NLI/BERT/exp/{m}/Run0.25_6/Expls/'
    ]
    acc_filepaths = [
        f"/workspace/CCE_NLI/BERT/models/{m}/Run0.25_5/accuracy.csv",
        f"/workspace/CCE_NLI/BERT/models/{m}/Run0.25_6/accuracy.csv"
    ]
    
    # Filter to existing paths
    existing_filepaths = [fp for fp, acc_fp in zip(filepaths, acc_filepaths) 
                          if os.path.exists(fp) and os.path.exists(acc_fp)]
    
    if not existing_filepaths:
        print(f"Skipping method {m}: no valid filepaths found")
        continue
    
    # Accumulate results across files
    cluster_results_accumulator = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: {'sum': 0, 'count': 0})))
    accuracy_accumulator = defaultdict(lambda: {'sum': 0, 'count': 0})
    
    for i, filepath in enumerate(existing_filepaths):
        accs=None
        all_pres = []
        all_hyps = []
        all_nots = []
        if os.path.exists(acc_filepaths[i]):
            accs = pd.read_csv(acc_filepaths[i])
           
            
        
        for i, sparsity_explanation_folder in enumerate(sorted(os.listdir(filepath))):
            sparsity_level = sparsity_explanation_folder.split("%")[0]
            
            # Accumulate accuracy
            if accs is not None:
                accuracy_accumulator[sparsity_level]['sum'] += accs.iloc[i]['accs']
                accuracy_accumulator[sparsity_level]['count'] += 1
            
            for cluster in range(1, 4):
                try:
                    cluster_explanations_per_unit, cluster_explanations_all = load_csv_data(
                        os.path.join(filepath, sparsity_explanation_folder, f'Cluster{cluster}IOUS1024N.csv')
                    )
                    cluster_explanations_all_set = set(cluster_explanations_all)
                except:
                    print("Skipping ", os.path.join(filepath, sparsity_explanation_folder, f'Cluster{cluster}IOUS1024N.csv'))
                    continue
                pre_cp, pre_count_val = count(cluster_explanations_all_set, 'pre', True)
                hyp_cp, hyp_count_val = count(cluster_explanations_all_set, 'hyp', True)
                not_cp, not_count_val = count(cluster_explanations_all_set, "NOT")
                not_uniquecp, not_count_notunique_val = count(cluster_explanations_all, "NOT")
                
                # Accumulate metrics
                cluster_results_accumulator[sparsity_level][cluster]['pre']['sum'] += pre_count_val
                cluster_results_accumulator[sparsity_level][cluster]['pre']['count'] += 1
                
                
                cluster_results_accumulator[sparsity_level][cluster]['hyp']['sum'] += hyp_count_val
                cluster_results_accumulator[sparsity_level][cluster]['hyp']['count'] += 1
                
                cluster_results_accumulator[sparsity_level][cluster]['not']['sum'] += not_count_val
                cluster_results_accumulator[sparsity_level][cluster]['not']['count'] += 1
                
                cluster_results_accumulator[sparsity_level][cluster]['total']['sum'] += len(cluster_explanations_all) - not_count_notunique_val
                cluster_results_accumulator[sparsity_level][cluster]['total']['count'] += 1
                
                cluster_results_accumulator[sparsity_level][cluster]['positive_unique']['sum'] += len(cluster_explanations_all_set) - not_count_val
                cluster_results_accumulator[sparsity_level][cluster]['positive_unique']['count'] += 1
                
                cluster_results_accumulator[sparsity_level][cluster]['num_explainable_neurons']['sum'] += len(cluster_explanations_per_unit)
                cluster_results_accumulator[sparsity_level][cluster]['num_explainable_neurons']['count'] += 1
                
                all_pres.extend(pre_cp)
                all_hyps.extend(hyp_cp)
                all_nots.extend(not_uniquecp)
            cluster = 'global'
            cluster_results_accumulator[sparsity_level][cluster]['global_pre']['sum'] += len(set(all_pres))
            cluster_results_accumulator[sparsity_level][cluster]['global_pre']['count'] += 1
            cluster_results_accumulator[sparsity_level][cluster]['global_hyp']['sum'] += len(set(hyp_cp))
            cluster_results_accumulator[sparsity_level][cluster]['global_hyp']['count'] += 1
            cluster_results_accumulator[sparsity_level][cluster]['global_not_unique']['sum'] += len(set(all_nots))
            cluster_results_accumulator[sparsity_level][cluster]['global_not_unique']['count'] += 1
    
    # Compute averages
    cluster_results = defaultdict(lambda: defaultdict(dict))
    for sparsity_level in cluster_results_accumulator:
        for cluster in cluster_results_accumulator[sparsity_level]:
            for metric in cluster_results_accumulator[sparsity_level][cluster]:
                total = cluster_results_accumulator[sparsity_level][cluster][metric]['sum']
                num_samples = cluster_results_accumulator[sparsity_level][cluster][metric]['count']
                cluster_results[sparsity_level][cluster][metric] = total / num_samples if num_samples > 0 else 0
    
    # Average accuracies
    if accuracy_accumulator is not None:
        pruning = sorted(accuracy_accumulator.keys())
        accuracies = [accuracy_accumulator[p]['sum'] / accuracy_accumulator[p]['count'] 
                      if accuracy_accumulator[p]['count'] > 0 else 0 
                      for p in pruning]

    # Prepare data for plotting
    clusters = defaultdict(lambda: defaultdict(list))
    totals = defaultdict(lambda: defaultdict(list))
    expl_neurons = defaultdict(lambda: defaultdict(list))
   
    for s in sorted(cluster_results.keys()):
        for c, v in cluster_results[s].items():
            if c=='global': continue
            clusters[c]['pre'].append(v['pre'])
            clusters[c]['hyp'].append(v['hyp'])
            clusters[c]['not'].append(v['not'])
            clusters[c]['positive_unique'].append(v['positive_unique'])
            totals[c]['total'].append(v['total'])
            
            if c == 1:
                baseline = v['num_explainable_neurons']
            expl_neurons[c]['num_explainable_neurons'].append(v['num_explainable_neurons']/baseline)
        for k in clusters['global'].keys():
            clusters[k]
       
            
            
    
    # --- compute global y-axis limits ---
    all_vals = []
    for c in clusters.values():
        for v in c.values():
            all_vals.extend(v)
    
    ymin, ymax = min(all_vals) - 200, max(all_vals) + 200
    
    # --- plot ---
    for col, name in enumerate(sorted(clusters.keys())):
        ax = axes_concept_counts[row, col]
        for key, vals in clusters[name].items():
            ax.plot(pruning, vals, marker='o', label=key)
        
        ax.set_title(f"METHOD {m} Cluster {name}")
        ax.set_ylim(ymin, ymax)
        ax.set_xlabel("Pruning Fraction")
        ax.tick_params(axis='x', labelrotation=45)
        if col == 0:
            ax.set_ylabel("Count")
        ax.grid()
    fig_concept_counts.subplots_adjust(hspace=0.4)
    
    if accuracies is not None:
        # Plot accuracies
        ax = axes_accuracies[row]
        ax.set_title(f"METHOD {m} Accuracies")
        ax.plot(pruning, accuracies, marker='o')
        ax.set_xlabel("Pruning Fraction")
        ax.tick_params(axis='x', labelrotation=45)
        ax.set_ylabel("Percent")
        ax.grid()
    
    # Plot total concepts
    ax = axes_totalConcepts[row]
    for i in range(1, 4):
        ax.plot(pruning, totals[i]['total'], label=f"Cluster {i}", marker='o')
    ax.set_title(f"METHOD {m} Positive Total")
    ax.set_xlabel("Pruning Fraction")
    ax.tick_params(axis='x', labelrotation=45)
    ax.set_ylabel("Count")
    ax.grid()
    ax.legend()
    
    ax = axes_explNeurons[row]
    for i in range(1, 4):
        ax.plot(pruning, expl_neurons[i]['num_explainable_neurons'], label=f"Cluster {i}", marker='o')
    ax.set_title(f"METHOD {m} Expl Neurons")
    ax.set_xlabel("Pruning Fraction")
    ax.tick_params(axis='x', labelrotation=45)
    ax.set_ylabel("Percent")
    ax.grid()
    ax.legend()
    
    

# Add legend to concept counts figure
handles, labels = axes_concept_counts[0, 0].get_legend_handles_labels()
fig_concept_counts.legend(handles, labels, loc="upper center", ncol=4)

plt.tight_layout()
plt.show()
# Out:
# CLUSTER RESULTS  dict_keys([1, 2, 3, 'global'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[149], line 120
#     117 print("CLUSTER RESULTS ", cluster_results[s].keys())
#     118 for c, v in cluster_results[s].items():
# --> 120     clusters[c]['pre'].append(v['pre'])
#     121     clusters[c]['hyp'].append(v['hyp'])
#     122     clusters[c]['not'].append(v['not'])
#
# KeyError: 'pre'

# %%
import nltk
from nltk import word_tokenize, pos_tag
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
# Ensure necessary NLTK data is downloaded (run once)

import pandas as pd
from collections import defaultdict
counts = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(dict))))
for method in ['lottery_ticket', 'CoFi']:
    model='BERT'
    file='Run0.25_5'
    root = f"/workspace/CCE_NLI/{model}/exp/{method}/{file}/Expls"
    
    conceptslist = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(list))))
    df=pd.read_csv(f'/workspace/CCE_NLI/BERT/exp/csv_output/{method}_global_all_sparsities.csv')
    cluster='all'
    for col in df.columns:
        if 'count' in col: continue
        sparsity = float(col.split("concept")[-1].split("%")[0])
        all_concepts = [concept for concept in df[col] if isinstance(concept,str)]



        words =list([word.split(":")[-1] for word in all_concepts if word not in ['AND', 'OR'] and 'tag:' not in word and 'oth:overlap' not in word and 'NOT' not in word])


        # 1. Tokenize the text into words
        tokens = word_tokenize(" ".join(words))

        # 2. Perform POS tagging
        # The result is a list of tuples: [('word', 'POS_tag'), ...]
        tagged_words = pos_tag(tokens)

        # 3. Filter for nouns and verbs
        nouns = [word for word, tag in tagged_words if tag.startswith('NN')]
       
        verbs = [word for word, tag in tagged_words if tag.startswith('VB')]
        adj = [word for word, tag in tagged_words if tag.startswith('JJ')]

        counts[method][sparsity][f'Cluster{cluster}']['Nouns'] = len(nouns)
        print(counts.keys())
        counts[method][sparsity][f'Cluster{cluster}']['Verbs'] = len(verbs)
        counts[method][sparsity][f'Cluster{cluster}']['Adj'] = len(adj)

        conceptslist[method][sparsity][f'Cluster{cluster}']['Nouns'] = nouns
        conceptslist[method][sparsity][f'Cluster{cluster}']['Verbs'] = verbs
        conceptslist[method][sparsity][f'Cluster{cluster}']['Adj'] = adj
pd.DataFrame(counts)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# dict_keys(['lottery_ticket'])
# dict_keys(['lottery_ticket'])
# dict_keys(['lottery_ticket'])
# dict_keys(['lottery_ticket'])
# dict_keys(['lottery_ticket'])
# dict_keys(['lottery_ticket'])
# dict_keys(['lottery_ticket', 'CoFi'])
# dict_keys(['lottery_ticket', 'CoFi'])
# dict_keys(['lottery_ticket', 'CoFi'])
# dict_keys(['lottery_ticket', 'CoFi'])
# dict_keys(['lottery_ticket', 'CoFi'])
# dict_keys(['lottery_ticket', 'CoFi'])
#                                               lottery_ticket  \
# 0.000000   {'Clusterall': {'Nouns': 200, 'Verbs': 97, 'Ad...
# 25.000000  {'Clusterall': {'Nouns': 209, 'Verbs': 97, 'Ad...
# 43.750000  {'Clusterall': {'Nouns': 220, 'Verbs': 104, 'A...
# 57.812000  {'Clusterall': {'Nouns': 224, 'Verbs': 106, 'A...
# 68.359000  {'Clusterall': {'Nouns': 224, 'Verbs': 103, 'A...
# 76.270000  {'Clusterall': {'Nouns': 227, 'Verbs': 98, 'Ad...
# 0.252674                                                 NaN
# 0.444328                                                 NaN
# 0.582675                                                 NaN
# 0.684185                                                 NaN
# 0.778975                                                 NaN
#
#                                                         CoFi
# 0.000000   {'Clusterall': {'Nouns': 219, 'Verbs': 102, 'A...
# 25.000000                                                NaN
# 43.750000                                                NaN
# 57.812000                                                NaN
# 68.359000                                                NaN
# 76.270000                                                NaN
# 0.252674   {'Clusterall': {'Nouns': 235, 'Verbs': 104, 'A...
# 0.444328   {'Clusterall': {'Nouns': 235, 'Verbs': 112, 'A...
# 0.582675   {'Clusterall': {'Nouns': 222, 'Verbs': 102, 'A...
# 0.684185   {'Clusterall': {'Nouns': 220, 'Verbs': 106, 'A...
# 0.778975   {'Clusterall': {'Nouns': 209, 'Verbs': 100, 'A...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create figure
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

# Plot 1: Lottery Ticket Accuracies
acc_df_lottery = pd.read_csv('/workspace/CCE_NLI/BERT/models/lottery_ticket/Run0.25_5/accuracy.csv')
ax1 = axes[0, 0]
ax1.plot(acc_df_lottery['Unnamed: 0'], acc_df_lottery['accs'], marker='o', linewidth=2)
ax1.set_xlabel('Pruning Iteration', fontsize=12)
ax1.set_ylabel('Accuracy', fontsize=12)
ax1.set_title('Lottery Ticket Accuracy', fontsize=14)
ax1.grid(True, alpha=0.3)
ax1.set_xticks(acc_df_lottery['Unnamed: 0'].values)  # Use .values

# Plot 2: CoFi Accuracies
acc_df_cofi = pd.read_csv('/workspace/CCE_NLI/BERT/models/CoFi/Run0.25_5/accuracy.csv')
ax2 = axes[0, 1]
ax2.plot(acc_df_cofi['Unnamed: 0'], acc_df_cofi['accs'], marker='o', linewidth=2, color='orange')
ax2.set_xlabel('Pruning Iteration', fontsize=12)
ax2.set_ylabel('Accuracy', fontsize=12)
ax2.set_title('CoFi Accuracy', fontsize=14)
ax2.grid(True, alpha=0.3)
ax2.set_xticks([int(i) for i in acc_df_cofi['Unnamed: 0'].values])  # Use .values

# Hide third plot in first row

# Plot POS counts for both methods

for idx, method in enumerate(['lottery_ticket', 'CoFi']):
    ax = axes[1, idx]

    # Extract data from counts dictionary
    sparsity_levels = sorted(counts[method].keys())

    clusters = sorted([k for k in counts[method][sparsity_levels[0]].keys() if 'Cluster' in k])

    # Plot each POS type
    for pos_type in ['Nouns', 'Verbs', 'Adj']:
        values = []
        print(sparsity_levels)
        for sparsity in sparsity_levels:
            cluster_vals = [int(counts[method][sparsity][cluster].get(pos_type, 0))  for cluster in clusters]
            values.append(sum(cluster_vals))  # Sum across clusters

        ax.plot(range(len(sparsity_levels)), values, marker='o', label=pos_type, linewidth=2)
    print(values)
    ax.set_xlabel('Sparsity Level', fontsize=12)
    ax.set_ylabel('Count', fontsize=12)
    ax.set_title(f'{method} POS Counts', fontsize=14)
    ax.set_xticks(range(len(sparsity_levels)))
    # Convert sparsity levels to strings for labels

    ax.set_xticklabels([s for s in sparsity_levels], rotation=45, ha='right')
    ax.legend()
    ax.grid(True, alpha=0.3)

print("DONE")
# Out:
# [0.0, 25.0, 43.75, 57.812, 68.359, 76.27]
# [0.0, 25.0, 43.75, 57.812, 68.359, 76.27]
# [0.0, 25.0, 43.75, 57.812, 68.359, 76.27]
# [73, 63, 69, 69, 63, 60]
# [0.0, 0.25267370011269075, 0.4443280775114645, 0.5826748728764346, 0.6841850626856109, 0.7789752992375562]
# [0.0, 0.25267370011269075, 0.4443280775114645, 0.5826748728764346, 0.6841850626856109, 0.7789752992375562]
# [0.0, 0.25267370011269075, 0.4443280775114645, 0.5826748728764346, 0.6841850626856109, 0.7789752992375562]
# [71, 59, 69, 68, 67, 56]
# DONE

# %%
import os
import csv
from collections import Counter, defaultdict

methods = ['lottery_ticket', 'CoFi']
global_red = defaultdict(list)
local_avg_reundnacy_at_sparsity_methods = []

output_dir = '/workspace/CCE_NLI/BERT/exp/csv_output'
os.makedirs(output_dir, exist_ok=True)

for method in methods:
    root = f'/workspace/CCE_NLI/BERT/exp/{method}/Run0.25_5/Expls'
    sparsities = os.listdir(root)
    
    local_avg_reundnacy_at_sparsity = []
    global_reundnacy_at_sparsity = []
    
    for sparsity in sparsities:
        concepts_redundnacy_at_cluster = []  # reset per sparsity
        global_concepts = []
        for cluster in range(1,4):
            per_unit, all_concepts = load_csv_data(os.path.join(root, sparsity, f"Cluster{cluster}IOUS1024N.csv"))
            all_concepts = [i for i in all_concepts if 'NOT ' not in i]
            counter = Counter(all_concepts)
            concepts_redundnacy_at_cluster.append(counter)
            global_concepts.extend(all_concepts)
        
        local_avg_reundnacy_at_sparsity.append(concepts_redundnacy_at_cluster)
        global_counter = Counter(global_concepts)
        global_reundnacy_at_sparsity.append(global_counter)
    
    global_red[method] = global_reundnacy_at_sparsity
    local_avg_reundnacy_at_sparsity_methods.append(local_avg_reundnacy_at_sparsity)

import os
import csv
from collections import Counter

output_dir = '/workspace/CCE_NLI/BERT/exp/csv_output'
os.makedirs(output_dir, exist_ok=True)

methods = ['lottery_ticket', 'CoFi']

for method_idx, method in enumerate(methods):
    local_data = local_avg_reundnacy_at_sparsity_methods[method_idx]  # list of sparsities, each has 3 cluster counters
    root = f'/workspace/CCE_NLI/BERT/exp/{method}/Run0.25_5/Expls'
    sparsities = sorted(os.listdir(root), key=lambda x: float(x.split("%")[0]))  # sort sparsity numerically

    num_clusters = 3
    for cluster_idx in range(num_clusters):
        # Collect concept counts for this cluster across all sparsities
        cluster_sparsity_counters = [local_data[s_idx][cluster_idx] for s_idx in range(len(sparsities))]

        # Create a **set of all concepts across all sparsities**
        all_concepts = set()
        for counter in cluster_sparsity_counters:
            all_concepts.update(counter.keys())

        # Sort concepts by count in the first sparsity (0% sparsity)
        sorted_concepts = sorted(all_concepts, key=lambda c: cluster_sparsity_counters[0].get(c, 0), reverse=True)

        # Write CSV for this cluster
        csv_name = f"{method}_cluster{cluster_idx+1}.csv"
        csv_path = os.path.join(output_dir, csv_name)
        with open(csv_path, 'w', newline='') as f:
            writer = csv.writer(f)

            # Header
            header = []
            for s in sparsities:
                header.extend([f"concept{s}", f"count{s}"])
            writer.writerow(header)

            # Rows
            for concept in sorted_concepts:
                row = []
                for counter in cluster_sparsity_counters:
                    row.append(concept if concept in counter else '')
                    row.append(counter.get(concept, 0))
                writer.writerow(row)

import os
import csv
from collections import Counter

output_dir = '/workspace/CCE_NLI/BERT/exp/csv_output'
os.makedirs(output_dir, exist_ok=True)

methods = ['lottery_ticket', 'CoFi']

for method in methods:
    global_data = global_red[method]  # list of Counters at each sparsity
    root = f'/workspace/CCE_NLI/BERT/exp/{method}/Run0.25_5/Expls'
    sparsities = sorted(os.listdir(root), key=lambda x: float(x.split("%")[0]))  # sort sparsities numerically

    # Build the set of all concepts across all sparsities
    all_concepts = set()
    for counter in global_data:
        all_concepts.update(counter.keys())

    # Sort concepts by count in the first sparsity (0%) descending
    sorted_concepts = sorted(all_concepts, key=lambda c: global_data[0].get(c, 0), reverse=True)

    # Write one CSV per method
    csv_name = f"{method}_global_all_sparsities.csv"
    csv_path = os.path.join(output_dir, csv_name)
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)

        # Header: concept0, count0, concept25, count25, ...
        header = []
        for s in sparsities:
            header.extend([f"concept{s}", f"count{s}"])
        writer.writerow(header)

        # Write rows
        for concept in sorted_concepts:
            row = []
            for counter in global_data:
                row.append(concept if concept in counter else '')
                row.append(counter.get(concept, 0))
            writer.writerow(row)

# %%
# Out:
# [Counter({'pre:tag:nn': 456,
#           'NOT hyp:tok:outside': 204,
#           'hyp:tag:nn': 179,
#           'oth:overlap:overlap25': 140,
#           'NOT hyp:tok:outdoors': 111,
#           'NOT hyp:tok:sleeping': 110,
#           'hyp:tag:dt': 106,
#           'pre:tag:jj': 101,
#           'NOT oth:overlap:overlap50': 97,
#           'pre:tag:.': 79,
#           'pre:tag:dt': 76,
#           'hyp:tag:vbg': 73,
#           'NOT oth:overlap:overlap75': 73,
#           'NOT hyp:tok:for': 73,
#           'pre:tag:in': 67,
#           'hyp:tag:in': 58,
#           'NOT pre:tok:walking': 51,
#           'NOT pre:tok:dog': 50,
#           'NOT hyp:tok:wearing': 49,
#           'NOT hyp:tok:tall': 49,
#           'pre:tok:man': 47,
#           'oth:overlap:overlap50': 46,
#           'NOT hyp:tok:inside': 45,
#           'NOT hyp:tok:nobody': 44,
#           'NOT pre:tok:girl': 42,
#           'NOT hyp:tok:eating': 40,
#           'pre:tok:woman': 37,
#           'NOT hyp:tok:walking': 36,
#           'NOT hyp:tok:people': 33,
#           'NOT pre:tok:woman': 31,
#           'NOT hyp:tag:ex': 29,
#           'NOT hyp:tok:swimming': 29,
#           'hyp:tok:man': 28,
#           'NOT hyp:tok:sitting': 28,
#           'hyp:tag:nns': 28,
#           'NOT hyp:tok:there': 27,
#           'NOT pre:tok:sitting': 26,
#           'pre:tag:vbg': 25,
#           'oth:overlap:overlap75': 24,
#           'NOT hyp:tok:woman': 24,
#           'hyp:tag:.': 23,
#           'NOT hyp:tok:near': 23,
#           'NOT hyp:tok:water': 23,
#           'NOT pre:tok:street': 23,
#           'NOT hyp:tok:black': 22,
#           'NOT hyp:tok:alone': 22,
#           'NOT pre:tok:boy': 21,
#           'pre:tag:nns': 21,
#           'NOT pre:tok:blue': 21,
#           'NOT pre:tok:women': 20,
#           'NOT hyp:tok:her': 20,
#           'NOT hyp:tok:standing': 19,
#           'NOT hyp:tok:person': 19,
#           'NOT pre:tok:pool': 18,
#           'NOT hyp:tok:blue': 18,
#           'hyp:tag:cd': 18,
#           'hyp:tok:woman': 18,
#           'hyp:tok:men': 17,
#           'NOT pre:tok:snow': 17,
#           'pre:tok:sitting': 17,
#           'NOT hyp:tok:women': 17,
#           'NOT hyp:tok:dog': 16,
#           'NOT pre:tok:standing': 16,
#           'pre:tag:cd': 16,
#           'pre:tag:vbz': 15,
#           'NOT hyp:tok:car': 15,
#           'NOT hyp:tok:they': 15,
#           'NOT hyp:tag:vb': 15,
#           'NOT pre:tok:stage': 14,
#           'NOT pre:tok:ball': 14,
#           'hyp:tok:playing': 14,
#           'NOT pre:tok:black': 14,
#           'NOT hyp:tok:man': 14,
#           'hyp:tok:girl': 14,
#           'hyp:tag:prp$': 13,
#           'NOT pre:tok:girls': 13,
#           'NOT hyp:tok:has': 13,
#           'pre:tok:men': 13,
#           'NOT pre:tok:jumping': 13,
#           'pre:tag:,': 13,
#           'NOT hyp:tok:park': 13,
#           'NOT pre:tok:sits': 13,
#           'NOT pre:tok:man': 13,
#           'NOT hyp:tok:something': 13,
#           'pre:tok:girl': 12,
#           'NOT pre:tok:water': 12,
#           'NOT hyp:tok:to': 12,
#           'NOT pre:tok:room': 12,
#           'NOT hyp:tok:men': 12,
#           'NOT hyp:tok:boy': 12,
#           'NOT hyp:tag:prp$': 12,
#           'NOT pre:tok:soccer': 11,
#           'NOT pre:tok:child': 11,
#           'NOT pre:tok:air': 11,
#           'NOT pre:tok:children': 11,
#           'NOT hyp:tok:running': 11,
#           'hyp:tag:vbp': 10,
#           'NOT pre:tok:men': 10,
#           'NOT hyp:tok:home': 10,
#           'NOT pre:tok:beach': 10,
#           'NOT pre:tok:red': 10,
#           'pre:tok:two': 10,
#           'NOT hyp:tok:no': 10,
#           'hyp:tok:to': 10,
#           'hyp:tag:jj': 10,
#           'NOT pre:tok:sidewalk': 10,
#           'NOT pre:tok:baseball': 9,
#           'NOT pre:tok:smiling': 9,
#           'NOT hyp:tok:child': 9,
#           'hyp:tok:are': 9,
#           'NOT pre:tok:bike': 9,
#           'NOT pre:tok:table': 9,
#           'NOT pre:tok:running': 9,
#           'NOT hyp:tag:nnp': 9,
#           'NOT hyp:tok:bike': 9,
#           'hyp:tok:in': 9,
#           'NOT pre:tok:walks': 9,
#           'hyp:tag:vb': 9,
#           'pre:tok:on': 9,
#           'NOT hyp:tok:playing': 9,
#           'NOT pre:tok:field': 9,
#           'NOT hyp:tok:friends': 8,
#           'NOT pre:tok:something': 8,
#           'pre:tok:black': 8,
#           'NOT hyp:tag:prp': 8,
#           'NOT pre:tok:working': 8,
#           'pre:tok:people': 8,
#           'pre:tag:cc': 8,
#           'NOT pre:tok:her': 8,
#           'NOT pre:tok:yellow': 8,
#           'NOT hyp:tok:dinner': 8,
#           'NOT hyp:tok:beach': 8,
#           'NOT hyp:tok:waiting': 8,
#           'pre:tok:young': 8,
#           'NOT hyp:tok:riding': 8,
#           'hyp:tag:vbz': 8,
#           'NOT hyp:tok:street': 7,
#           'pre:tok:and': 7,
#           'NOT pre:tok:colorful': 7,
#           'pre:tok:to': 7,
#           'NOT hyp:tok:room': 7,
#           'pre:tok:blue': 7,
#           'NOT pre:tok:dogs': 7,
#           'pre:tok:women': 7,
#           'NOT hyp:tok:girl': 7,
#           'pre:tag:prp$': 7,
#           'NOT pre:tok:talking': 7,
#           'NOT pre:tok:car': 7,
#           'NOT pre:tok:race': 7,
#           'pre:tok:dog': 7,
#           'NOT pre:tok:hair': 7,
#           'hyp:tok:two': 7,
#           'NOT hyp:tok:cat': 7,
#           'hyp:tok:sitting': 7,
#           'NOT pre:tok:pink': 7,
#           'NOT hyp:tok:pool': 7,
#           'NOT hyp:tok:was': 6,
#           'NOT pre:tok:building': 6,
#           'pre:tok:for': 6,
#           'NOT pre:tok:people': 6,
#           'NOT pre:tok:person': 6,
#           'NOT hyp:tok:human': 6,
#           'pre:tok:white': 6,
#           'NOT pre:tok:large': 6,
#           'NOT pre:tok:park': 6,
#           'pre:tag:vb': 6,
#           'NOT hyp:tok:dogs': 6,
#           'NOT pre:tok:purple': 6,
#           'NOT pre:tok:mountain': 6,
#           'NOT pre:tok:holding': 6,
#           'NOT hyp:tok:red': 6,
#           'pre:tok:at': 6,
#           'pre:tag:vbp': 6,
#           'NOT hyp:tok:working': 6,
#           'NOT pre:tok:train': 6,
#           'hyp:tok:women': 6,
#           'NOT pre:tok:outside': 6,
#           'pre:tok:boy': 6,
#           'NOT pre:tok:for': 6,
#           'NOT pre:tok:white': 6,
#           'pre:tok:in': 6,
#           'NOT hyp:tok:his': 6,
#           'NOT hyp:tok:driving': 6,
#           'NOT hyp:tok:white': 6,
#           'pre:tok:street': 5,
#           'NOT hyp:tok:stage': 5,
#           'hyp:tok:people': 5,
#           'pre:tag:nnp': 5,
#           'NOT pre:tok:wall': 5,
#           'NOT pre:tok:green': 5,
#           'NOT pre:tok:walk': 5,
#           'NOT pre:tok:microphone': 5,
#           'NOT pre:tok:playing': 5,
#           'NOT pre:tok:horse': 5,
#           'pre:tok:standing': 5,
#           'NOT pre:tok:construction': 5,
#           'NOT pre:tok:skateboard': 5,
#           'NOT hyp:tok:some': 5,
#           'pre:tok:ball': 5,
#           'hyp:tok:his': 5,
#           'NOT hyp:tok:watching': 5,
#           'pre:tok:playing': 5,
#           'hyp:tok:at': 5,
#           'NOT pre:tok:reading': 5,
#           'pre:tok:red': 5,
#           'NOT pre:tok:sand': 5,
#           'NOT pre:tok:blond': 5,
#           'NOT pre:tok:game': 5,
#           'NOT pre:tok:performing': 5,
#           'NOT hyp:tok:not': 4,
#           'NOT pre:tok:sit': 4,
#           'NOT pre:tok:gray': 4,
#           'NOT hyp:tok:ball': 4,
#           'NOT hyp:tok:it': 4,
#           'NOT hyp:tok:house': 4,
#           'hyp:tag:prp': 4,
#           'pre:tok:walking': 4,
#           'pre:tok:wearing': 4,
#           'NOT pre:tok:hat': 4,
#           'NOT hyp:tok:all': 4,
#           'NOT hyp:tok:from': 4,
#           'NOT pre:tok:together': 4,
#           'NOT pre:tok:old': 4,
#           'NOT pre:tok:food': 4,
#           'NOT pre:tok:brown': 4,
#           'NOT pre:tok:dirt': 4,
#           'NOT pre:tok:him': 4,
#           'NOT hyp:tok:young': 4,
#           'NOT pre:tok:they': 4,
#           'NOT hyp:tok:picture': 4,
#           'hyp:tok:race': 4,
#           'pre:tok:while': 4,
#           'NOT pre:tok:football': 4,
#           'NOT hyp:tok:new': 4,
#           'NOT hyp:tok:their': 4,
#           'NOT hyp:tok:game': 4,
#           'hyp:tok:outside': 4,
#           'pre:tok:orange': 3,
#           'NOT hyp:tag:jjr': 3,
#           'NOT hyp:tok:while': 3,
#           'pre:tok:his': 3,
#           'pre:tok:shorts': 3,
#           'NOT hyp:tok:sits': 3,
#           'NOT hyp:tok:bus': 3,
#           'NOT pre:tok:jumps': 3,
#           'NOT hyp:tag:cc': 3,
#           'NOT pre:tag:wdt': 3,
#           'NOT pre:tok:young': 3,
#           'NOT pre:tok:bicycle': 3,
#           'NOT pre:tok:older': 3,
#           'NOT pre:tag:jjr': 3,
#           'NOT pre:tok:pants': 3,
#           'NOT pre:tok:little': 3,
#           'pre:tok:running': 3,
#           'NOT pre:tok:long': 3,
#           'NOT pre:tok:wooden': 3,
#           'hyp:tok:boy': 3,
#           'NOT pre:tok:top': 3,
#           'NOT hyp:tok:she': 3,
#           'NOT hyp:tok:old': 3,
#           'pre:tok:green': 3,
#           'hyp:tok:running': 3,
#           'NOT pre:tok:guitar': 3,
#           'NOT hyp:tok:lady': 3,
#           'pre:tok:holding': 3,
#           'hyp:tok:is': 3,
#           'NOT pre:tok:colored': 3,
#           'NOT pre:tok:lady': 3,
#           'pre:tok:bike': 3,
#           'pre:tag:rb': 3,
#           'NOT hyp:tok:asleep': 3,
#           'pre:tok:other': 3,
#           'NOT pre:tok:looks': 3,
#           'NOT hyp:tok:at': 3,
#           'NOT hyp:tok:holds': 3,
#           'NOT pre:tok:dress': 3,
#           'NOT pre:tok:jacket': 3,
#           'NOT pre:tok:grass': 3,
#           'NOT hyp:tok:off': 3,
#           'NOT pre:tok:cap': 3,
#           'NOT pre:tok:baby': 3,
#           'NOT hyp:tok:field': 3,
#           'NOT pre:tok:getting': 3,
#           'pre:tag:vbn': 3,
#           'NOT hyp:tok:smiling': 3,
#           'pre:tag:prp': 3,
#           'NOT hyp:tok:shirt': 3,
#           'NOT pre:tok:down': 3,
#           'NOT hyp:tok:trying': 3,
#           'NOT pre:tok:crowd': 3,
#           'NOT pre:tok:looking': 3,
#           'NOT pre:tok:several': 3,
#           'NOT hyp:tok:indoors': 2,
#           'NOT hyp:tok:with': 2,
#           'NOT pre:tok:head': 2,
#           'NOT hyp:tok:day': 2,
#           'NOT pre:tok:cellphone': 2,
#           'NOT pre:tok:dancing': 2,
#           'NOT pre:tok:clothes': 2,
#           'NOT hyp:tok:about': 2,
#           'NOT pre:tok:ground': 2,
#           'NOT pre:tok:gathered': 2,
#           'NOT hyp:tok:and': 2,
#           'hyp:tok:eating': 2,
#           'NOT pre:tok:three': 2,
#           'NOT pre:tok:under': 2,
#           'NOT pre:tok:line': 2,
#           'NOT hyp:tag:pos': 2,
#           'NOT hyp:tok:doing': 2,
#           'NOT pre:tok:that': 2,
#           'NOT pre:tok:at': 2,
#           'pre:tok:dogs': 2,
#           'NOT hyp:tok:hair': 2,
#           'NOT hyp:tok:asian': 2,
#           'NOT pre:tok:all': 2,
#           'NOT hyp:tok:up': 2,
#           'NOT hyp:tag:md': 2,
#           'NOT hyp:tok:kids': 2,
#           'NOT pre:tok:their': 2,
#           'NOT pre:tok:bags': 2,
#           'NOT pre:tok:umbrella': 2,
#           'NOT hyp:tok:singing': 2,
#           'NOT hyp:tok:walks': 2,
#           'NOT hyp:tok:being': 2,
#           'NOT hyp:tok:dancing': 2,
#           'NOT pre:tok:stand': 2,
#           'NOT hyp:tok:football': 2,
#           'pre:tok:shirt': 2,
#           'hyp:tok:for': 2,
#           'NOT pre:tok:as': 2,
#           'pre:tok:children': 2,
#           "NOT pre:tok:'s": 2,
#           'NOT hyp:tok:going': 2,
#           'NOT pre:tok:each': 2,
#           'NOT pre:tok:hand': 2,
#           'hyp:tok:watching': 2,
#           'NOT pre:tok:some': 2,
#           'NOT hyp:tok:three': 2,
#           'NOT pre:tok:smiles': 2,
#           'pre:tok:one': 2,
#           'NOT hyp:tok:next': 2,
#           'hyp:tok:bike': 2,
#           'hyp:tok:riding': 2,
#           'NOT pre:tok:floor': 2,
#           'NOT hyp:tok:play': 2,
#           'NOT pre:tok:full': 2,
#           'NOT pre:tok:group': 2,
#           'NOT pre:tok:about': 2,
#           'NOT pre:tok:outdoor': 2,
#           'NOT pre:tok:asian': 2,
#           'NOT pre:tok:hands': 2,
#           'pre:tok:from': 2,
#           'NOT hyp:tok:carrying': 2,
#           'NOT pre:tok:helmet': 2,
#           'NOT hyp:tok:making': 2,
#           'NOT pre:tok:his': 2,
#           'NOT pre:tok:back': 2,
#           'NOT hyp:tok:baby': 2,
#           'NOT hyp:tok:he': 2,
#           'pre:tok:are': 2,
#           'pre:tok:hat': 2,
#           'NOT hyp:tok:taking': 2,
#           'NOT pre:tok:glasses': 2,
#           'hyp:tag:nnp': 2,
#           'hyp:tag:vbn': 2,
#           'NOT pre:tok:face': 2,
#           'pre:tok:three': 2,
#           'NOT pre:tok:bench': 2,
#           'NOT pre:tok:who': 2,
#           'NOT hyp:tok:little': 2,
#           'NOT pre:tok:riding': 2,
#           'NOT pre:tok:using': 2,
#           'NOT pre:tok:dark': 2,
#           "NOT pre:tag:''": 2,
#           'pre:tok:pool': 2,
#           'NOT pre:tok:carrying': 2,
#           'NOT hyp:tok:party': 2,
#           'NOT hyp:tok:after': 1,
#           'hyp:tok:boys': 1,
#           'NOT pre:tok:dressed': 1,
#           'hyp:tok:walking': 1,
#           'NOT pre:tok:watches': 1,
#           'NOT hyp:tok:horse': 1,
#           'NOT hyp:tok:who': 1,
#           'NOT hyp:tok:around': 1,
#           'pre:tok:by': 1,
#           'NOT hyp:tok:soccer': 1,
#           'NOT hyp:tag:,': 1,
#           'NOT hyp:tok:four': 1,
#           'NOT pre:tok:-': 1,
#           'NOT pre:tok:camera': 1,
#           'pre:tok:as': 1,
#           'pre:tok:across': 1,
#           'NOT pre:tok:from': 1,
#           'pre:tok:group': 1,
#           'NOT pre:tok:suit': 1,
#           'pre:tok:sand': 1,
#           'NOT pre:tok:shirt': 1,
#           'NOT pre:tag:vb': 1,
#           'NOT hyp:tok:children': 1,
#           'pre:tok:talking': 1,
#           'NOT hyp:tok:girls': 1,
#           'hyp:tok:young': 1,
#           'NOT hyp:tok:snow': 1,
#           'NOT pre:tok:female': 1,
#           'NOT pre:tok:swimming': 1,
#           'NOT hyp:tok:other': 1,
#           'NOT hyp:tok:reading': 1,
#           'NOT pre:tok:shopping': 1,
#           'hyp:tok:wearing': 1,
#           'NOT pre:tok:being': 1,
#           'NOT pre:tok:dance': 1,
#           'hyp:tok:car': 1,
#           'NOT pre:tok:behind': 1,
#           'hyp:tag:rp': 1,
#           'NOT pre:tok:eating': 1,
#           'hyp:tok:sleeping': 1,
#           'NOT pre:tok:middle': 1,
#           'NOT hyp:tok:watches': 1,
#           'NOT pre:tok:it': 1,
#           'NOT hyp:tok:someone': 1,
#           'pre:tok:stage': 1,
#           'NOT pre:tok:through': 1,
#           'hyp:tag:cc': 1,
#           'pre:tok:over': 1,
#           'NOT pre:tok:picture': 1,
#           'NOT hyp:tok:together': 1,
#           'hyp:tok:there': 1,
#           'NOT hyp:tok:looks': 1,
#           'hyp:tok:and': 1,
#           'NOT pre:tok:busy': 1,
#           'NOT pre:tok:uniform': 1,
#           'NOT hyp:tok:two': 1,
#           'NOT pre:tok:coat': 1,
#           'NOT pre:tok:just': 1,
#           'NOT pre:tok:along': 1,
#           'pre:tok:little': 1,
#           'NOT hyp:tok:hat': 1,
#           'NOT pre:tok:play': 1,
#           'NOT pre:tok:has': 1,
#           'NOT pre:tag:vbd': 1,
#           'NOT pre:tok:shorts': 1,
#           'NOT pre:tok:costume': 1,
#           'pre:tok:four': 1,
#           'pre:tok:brown': 1,
#           'hyp:tag:rb': 1,
#           'NOT pre:tok:bottle': 1,
#           'pre:tok:with': 1,
#           'NOT pre:tok:after': 1,
#           'NOT hyp:tok:ocean': 1,
#           'NOT hyp:tok:race': 1,
#           'NOT pre:tok:others': 1,
#           'NOT pre:tok:military': 1,
#           'NOT pre:tok:player': 1,
#           'NOT hyp:tag:wp': 1,
#           'hyp:tok:park': 1,
#           'NOT hyp:tok:train': 1,
#           'NOT pre:tok:over': 1,
#           'pre:tok:beach': 1,
#           'NOT pre:tok:restaurant': 1,
#           'NOT pre:tok:making': 1,
#           'NOT pre:tok:graffiti': 1,
#           'NOT pre:tok:basketball': 1,
#           'pre:tok:sidewalk': 1,
#           'NOT pre:tok:river': 1,
#           'NOT pre:tok:next': 1,
#           'pre:tok:water': 1,
#           'pre:tok:ocean': 1,
#           'NOT pre:tok:hanging': 1,
#           'NOT hyp:tok:building': 1,
#           'NOT pre:tok:clothing': 1,
#           'NOT hyp:tok:band': 1,
#           'NOT hyp:tok:green': 1,
#           'hyp:tok:white': 1,
#           'NOT pre:tok:pose': 1,
#           'hyp:tok:water': 1,
#           'pre:tok:costume': 1,
#           'hyp:tag:ex': 1,
#           'NOT pre:tok:outfit': 1,
#           'NOT hyp:tok:down': 1,
#           'NOT pre:tok:surrounded': 1,
#           'NOT hyp:tok:performing': 1,
#           'NOT hyp:tok:dressed': 1,
#           'hyp:tok:dog': 1,
#           'NOT hyp:tok:have': 1,
#           'NOT pre:tok:them': 1,
#           'NOT pre:tag:pos': 1,
#           'NOT pre:tok:runs': 1,
#           'hyp:tok:tall': 1,
#           'NOT hyp:tok:camera': 1,
#           'NOT pre:tok:trick': 1,
#           'NOT pre:tok:into': 1,
#           'NOT pre:tok:boots': 1,
#           'NOT hyp:tok:brown': 1,
#           'NOT pre:tag:nnp': 1,
#           'pre:tok:is': 1,
#           'hyp:tok:with': 1,
#           'pre:tok:middle': 1,
#           'pre:tok:or': 1,
#           'pre:tok:pink': 1,
#           'NOT hyp:tok:in': 1,
#           'pre:tok:front': 1,
#           'NOT hyp:tok:out': 1,
#           'NOT pre:tok:four': 1,
#           'hyp:tok:black': 1,
#           'NOT hyp:tok:-': 1,
#           'NOT pre:tok:team': 1,
#           'hyp:tok:red': 1,
#           'NOT pre:tok:holds': 1,
#           'pre:tok:their': 1,
#           'pre:tok:her': 1,
#           'NOT pre:tok:city': 1,
#           'NOT pre:tok:tree': 1,
#           'NOT pre:tok:bag': 1,
#           'NOT pre:tok:couple': 1,
#           'NOT pre:tok:band': 1,
#           'NOT hyp:tok:baseball': 1,
#           'NOT pre:tok:front': 1,
#           'hyp:tok:standing': 1,
#           'NOT hyp:tok:player': 1,
#           "NOT hyp:tok:'s": 1,
#           'pre:tok:dress': 1,
#           'NOT pre:tok:hockey': 1,
#           'NOT pre:tok:doing': 1,
#           'NOT pre:tok:sunglasses': 1,
#           'NOT pre:tok:kitchen': 1,
#           'NOT pre:tok:market': 1,
#           'NOT hyp:tag:vbn': 1,
#           'NOT hyp:tag:vbd': 1,
#           'pre:tok:looking': 1,
#           'NOT hyp:tok:friend': 1,
#           'hyp:tok:other': 1,
#           'NOT pre:tok:across': 1,
#           'pre:tok:room': 1,
#           'NOT pre:tok:faces': 1,
#           'NOT pre:tok:kids': 1,
#           'NOT pre:tok:ride': 1,
#           'NOT hyp:tok:basketball': 1,
#           'NOT pre:tok:cooking': 1,
#           'NOT hyp:tok:holding': 1,
#           'NOT hyp:tok:work': 1,
#           'NOT hyp:tok:lake': 1,
#           'NOT pre:tok:motorcycle': 1,
#           'pre:tok:riding': 1,
#           'NOT pre:tok:orange': 1,
#           'pre:tok:bench': 1,
#           'pre:tok:air': 1,
#           'NOT hyp:tok:bench': 1,
#           'NOT pre:tok:truck': 1,
#           'NOT hyp:tok:as': 1,
#           'hyp:tok:on': 1,
#           'NOT pre:tok:toy': 1,
#           'NOT pre:tok:striped': 1,
#           'NOT pre:tag:rp': 1,
#           'NOT hyp:tok:guy': 1,
#           'NOT pre:tok:store': 1,
#           'NOT hyp:tok:each': 1,
#           'NOT hyp:tok:several': 1,
#           'NOT pre:tok:sign': 1,
#           'NOT pre:tok:singing': 1,
#           'NOT hyp:tok:ice': 1,
#           'NOT hyp:tok:having': 1,
#           'NOT pre:tok:big': 1}),
#  Counter({'oth:overlap:overlap25': 224,
#           'NOT oth:overlap:overlap50': 223,
#           'pre:tag:nn': 205,
#           'NOT hyp:tok:for': 179,
#           'NOT hyp:tok:outside': 157,
#           'hyp:tag:nn': 138,
#           'NOT hyp:tag:prp$': 116,
#           'NOT hyp:tag:vb': 97,
#           'NOT hyp:tok:to': 92,
#           'hyp:tok:people': 84,
#           'oth:overlap:overlap50': 83,
#           'pre:tag:.': 80,
#           'hyp:tok:outside': 80,
#           'NOT oth:overlap:overlap25': 76,
#           'NOT pre:tok:woman': 75,
#           'pre:tag:jj': 75,
#           'hyp:tag:in': 74,
#           'NOT hyp:tok:sitting': 73,
#           'NOT hyp:tok:wearing': 71,
#           'NOT pre:tok:man': 69,
#           'hyp:tok:sleeping': 66,
#           'pre:tok:man': 66,
#           'hyp:tok:to': 64,
#           'NOT oth:overlap:overlap75': 64,
#           'NOT hyp:tok:people': 54,
#           'NOT pre:tok:dog': 52,
#           'NOT pre:tok:blue': 52,
#           'hyp:tag:dt': 50,
#           'NOT pre:tok:walking': 50,
#           'NOT hyp:tok:man': 48,
#           'NOT pre:tok:sitting': 48,
#           'hyp:tag:prp$': 47,
#           'hyp:tag:vbg': 45,
#           'NOT hyp:tok:sleeping': 45,
#           'pre:tok:woman': 42,
#           'hyp:tok:woman': 42,
#           'NOT pre:tok:black': 42,
#           'pre:tag:in': 39,
#           'pre:tok:men': 37,
#           'hyp:tok:for': 36,
#           'NOT pre:tok:girl': 36,
#           'NOT hyp:tok:playing': 34,
#           'NOT hyp:tok:woman': 33,
#           'hyp:tok:sitting': 31,
#           'NOT pre:tok:boy': 29,
#           'NOT hyp:tok:there': 28,
#           'oth:overlap:overlap75': 28,
#           'pre:tok:sitting': 27,
#           'pre:tok:dog': 27,
#           'hyp:tag:jj': 26,
#           'NOT hyp:tok:men': 26,
#           'NOT hyp:tag:ex': 25,
#           'hyp:tok:men': 25,
#           'pre:tok:black': 24,
#           'NOT pre:tok:street': 24,
#           'hyp:tag:vb': 24,
#           'hyp:tok:there': 24,
#           'pre:tok:girl': 23,
#           'pre:tok:blue': 23,
#           'hyp:tag:ex': 23,
#           'NOT hyp:tag:jj': 23,
#           'NOT pre:tok:men': 23,
#           'hyp:tok:man': 23,
#           'NOT pre:tok:red': 22,
#           'NOT hyp:tok:at': 22,
#           'NOT hyp:tok:standing': 22,
#           'NOT hyp:tok:in': 20,
#           'NOT pre:tok:people': 19,
#           'NOT pre:tok:standing': 19,
#           'NOT hyp:tok:black': 18,
#           'pre:tok:walking': 18,
#           'pre:tag:dt': 18,
#           'NOT hyp:tag:prp': 18,
#           'NOT hyp:tag:in': 17,
#           'NOT pre:tok:white': 17,
#           'hyp:tok:wearing': 17,
#           'NOT hyp:tok:person': 16,
#           'pre:tok:people': 16,
#           'NOT pre:tok:women': 16,
#           'hyp:tag:.': 15,
#           'NOT hyp:tag:nnp': 15,
#           'pre:tok:boy': 15,
#           'NOT hyp:tok:boy': 15,
#           'hyp:tok:dog': 14,
#           'NOT hyp:tok:his': 14,
#           'hyp:tok:eating': 14,
#           'NOT pre:tok:young': 14,
#           'NOT hyp:tok:girl': 14,
#           'hyp:tag:prp': 13,
#           'NOT hyp:tok:eating': 13,
#           'NOT hyp:tok:running': 12,
#           'pre:tok:street': 12,
#           'NOT hyp:tok:walking': 12,
#           'pre:tok:standing': 12,
#           'hyp:tok:playing': 11,
#           'pre:tok:white': 11,
#           'hyp:tag:nnp': 11,
#           'NOT pre:tok:his': 11,
#           'NOT hyp:tok:on': 11,
#           'pre:tok:his': 11,
#           'NOT pre:tag:,': 10,
#           'NOT pre:tok:yellow': 10,
#           'NOT pre:tok:water': 10,
#           'hyp:tok:girl': 9,
#           'NOT hyp:tok:dog': 9,
#           'pre:tok:women': 8,
#           'hyp:tok:nobody': 8,
#           'hyp:tok:women': 8,
#           'NOT pre:tag:vb': 8,
#           'NOT pre:tok:wearing': 8,
#           'hyp:tok:swimming': 8,
#           'pre:tok:green': 8,
#           'NOT hyp:tok:has': 8,
#           'hyp:tok:walking': 7,
#           'NOT pre:tok:at': 7,
#           'NOT hyp:tok:her': 7,
#           'hyp:tok:boy': 7,
#           'pre:tok:red': 7,
#           'pre:tok:water': 7,
#           'NOT hyp:tok:swimming': 6,
#           'NOT hyp:tok:white': 6,
#           'NOT pre:tok:her': 6,
#           'pre:tok:in': 6,
#           'pre:tag:vb': 6,
#           'NOT pre:tok:and': 6,
#           'pre:tag:prp$': 6,
#           'pre:tok:riding': 6,
#           'pre:tok:and': 6,
#           'hyp:tok:at': 6,
#           'hyp:tok:person': 6,
#           'pre:tok:girls': 5,
#           'pre:tag:,': 5,
#           'NOT pre:tok:green': 5,
#           'pre:tag:cc': 5,
#           'NOT hyp:tok:women': 5,
#           'NOT hyp:tag:vbg': 5,
#           'NOT hyp:tag:vbn': 5,
#           'pre:tok:ball': 5,
#           'NOT pre:tag:jj': 5,
#           'pre:tag:nnp': 5,
#           'NOT pre:tok:for': 5,
#           'NOT hyp:tok:inside': 5,
#           'NOT hyp:tok:park': 4,
#           'NOT pre:tok:ball': 4,
#           'pre:tok:her': 4,
#           'NOT pre:tok:sits': 4,
#           'NOT pre:tok:person': 4,
#           'NOT hyp:tok:children': 4,
#           'hyp:tok:riding': 4,
#           'pre:tag:nns': 4,
#           'hyp:tok:black': 4,
#           'pre:tok:brown': 4,
#           'hyp:tok:in': 4,
#           'NOT pre:tok:shirt': 4,
#           'NOT pre:tok:while': 4,
#           'hyp:tag:cd': 4,
#           'NOT hyp:tok:outdoors': 4,
#           'pre:tok:lady': 3,
#           'hyp:tok:while': 3,
#           'NOT pre:tok:table': 3,
#           'hyp:tok:outdoors': 3,
#           'NOT hyp:tok:their': 3,
#           'hyp:tok:football': 3,
#           'pre:tok:shirt': 3,
#           'NOT hyp:tok:home': 3,
#           'pre:tok:while': 3,
#           'hyp:tok:his': 3,
#           'hyp:tok:watching': 3,
#           'pre:tok:at': 3,
#           'NOT pre:tag:vbn': 3,
#           'pre:tok:to': 3,
#           'hyp:tok:blue': 3,
#           'hyp:tag:nns': 3,
#           'NOT pre:tag:nnp': 3,
#           'NOT pre:tok:playing': 3,
#           'hyp:tag:rb': 3,
#           'NOT hyp:tok:girls': 3,
#           'hyp:tok:inside': 3,
#           'hyp:tok:tall': 3,
#           'pre:tok:playing': 3,
#           'NOT hyp:tok:with': 3,
#           'pre:tok:baseball': 3,
#           'hyp:tok:water': 3,
#           'pre:tok:yellow': 3,
#           'NOT pre:tok:children': 3,
#           'hyp:tok:asleep': 3,
#           'pre:tok:air': 3,
#           'hyp:tok:near': 3,
#           'NOT hyp:tag:cd': 3,
#           'hyp:tok:has': 3,
#           'pre:tok:as': 3,
#           'hyp:tag:vbp': 3,
#           'hyp:tag:vbz': 3,
#           'pre:tok:wearing': 3,
#           'pre:tok:young': 3,
#           'pre:tok:for': 3,
#           'hyp:tok:bike': 3,
#           'NOT pre:tok:field': 3,
#           'pre:tok:three': 2,
#           'hyp:tok:dogs': 2,
#           'NOT hyp:tok:car': 2,
#           'pre:tok:walks': 2,
#           'pre:tok:outside': 2,
#           'pre:tok:children': 2,
#           'hyp:tok:shirt': 2,
#           'NOT pre:tok:beach': 2,
#           'hyp:tok:her': 2,
#           'hyp:tok:beach': 2,
#           'NOT pre:tok:child': 2,
#           'hyp:tok:driving': 2,
#           'pre:tok:race': 2,
#           'pre:tok:sits': 2,
#           'NOT hyp:tag:cc': 2,
#           'NOT hyp:tok:down': 2,
#           'NOT pre:tok:running': 2,
#           'pre:tok:dogs': 2,
#           'pre:tok:beach': 2,
#           'NOT hyp:tok:beach': 2,
#           'hyp:tok:on': 2,
#           'pre:tok:working': 2,
#           'hyp:tok:race': 2,
#           'hyp:tok:girls': 2,
#           'NOT pre:tok:as': 2,
#           'NOT hyp:tok:bike': 2,
#           'NOT pre:tok:outside': 2,
#           'NOT pre:tok:air': 2,
#           'pre:tok:one': 2,
#           'NOT hyp:tok:riding': 2,
#           'NOT pre:tok:crowd': 2,
#           'NOT pre:tok:car': 2,
#           'NOT pre:tok:riding': 2,
#           'NOT pre:tok:hair': 2,
#           'NOT pre:tok:large': 2,
#           'pre:tok:pool': 2,
#           'hyp:tok:by': 2,
#           'hyp:tok:next': 2,
#           'pre:tok:boys': 2,
#           'hyp:tok:white': 2,
#           'NOT pre:tag:cc': 2,
#           'pre:tok:bike': 2,
#           'pre:tok:crowd': 2,
#           'pre:tag:cd': 2,
#           'NOT pre:tok:looking': 2,
#           'NOT hyp:tok:blue': 2,
#           'NOT pre:tok:smiling': 2,
#           'NOT pre:tok:their': 2,
#           'hyp:tok:running': 2,
#           'NOT hyp:tok:water': 2,
#           'hyp:tok:park': 2,
#           'NOT pre:tok:ground': 1,
#           'NOT hyp:tok:friends': 1,
#           'pre:tag:wp': 1,
#           'NOT hyp:tok:day': 1,
#           'pre:tok:down': 1,
#           'NOT pre:tag:prp$': 1,
#           'pre:tok:sun': 1,
#           'NOT pre:tok:jumping': 1,
#           'NOT hyp:tok:game': 1,
#           'pre:tok:table': 1,
#           'NOT pre:tok:performing': 1,
#           'pre:tag:vbp': 1,
#           'pre:tok:running': 1,
#           'pre:tok:person': 1,
#           'NOT hyp:tok:red': 1,
#           'NOT pre:tok:hat': 1,
#           'NOT pre:tok:two': 1,
#           'hyp:tok:front': 1,
#           'NOT hyp:tag:nns': 1,
#           'pre:tok:purple': 1,
#           'NOT pre:tag:wdt': 1,
#           'pre:tok:cliff': 1,
#           'hyp:tok:two': 1,
#           'pre:tok:child': 1,
#           'NOT hyp:tok:about': 1,
#           'NOT pre:tok:into': 1,
#           'NOT hyp:tok:group': 1,
#           'NOT hyp:tok:dogs': 1,
#           'NOT pre:tag:rb': 1,
#           'hyp:tok:red': 1,
#           'hyp:tok:around': 1,
#           'pre:tok:picture': 1,
#           'NOT pre:tok:to': 1,
#           'NOT hyp:tag:rb': 1,
#           'hyp:tok:soccer': 1,
#           'NOT pre:tag:to': 1,
#           'pre:tok:guy': 1,
#           'pre:tok:performers': 1,
#           'hyp:tok:lady': 1,
#           'NOT pre:tok:blond': 1,
#           'pre:tok:male': 1,
#           'hyp:tok:boat': 1,
#           'NOT pre:tok:stage': 1,
#           'NOT hyp:tok:are': 1,
#           'pre:tok:smiling': 1,
#           'NOT pre:tok:one': 1,
#           'pre:tag:rp': 1,
#           'NOT hyp:tok:street': 1,
#           'pre:tok:band': 1,
#           'pre:tok:watching': 1,
#           'pre:tok:set': 1,
#           'NOT pre:tok:food': 1,
#           'pre:tok:pink': 1,
#           'pre:tok:eating': 1,
#           'hyp:tok:standing': 1,
#           'pre:tok:looking': 1,
#           'hyp:tok:together': 1,
#           'hyp:tok:table': 1,
#           'NOT pre:tok:park': 1,
#           'NOT pre:tok:train': 1,
#           'hyp:tok:guy': 1,
#           'pre:tok:group': 1,
#           'NOT pre:tok:wall': 1,
#           'NOT hyp:tok:young': 1,
#           'hyp:tok:ocean': 1,
#           'pre:tag:vbn': 1,
#           'NOT pre:tok:football': 1,
#           'NOT pre:tok:three': 1,
#           'pre:tok:sidewalk': 1,
#           'pre:tag:vbz': 1,
#           'hyp:tok:are': 1,
#           'NOT hyp:tok:they': 1,
#           'NOT pre:tok:dress': 1,
#           'NOT hyp:tok:lady': 1,
#           'NOT pre:tag:rp': 1,
#           'pre:tok:with': 1,
#           'hyp:tok:car': 1,
#           'pre:tok:just': 1,
#           'NOT pre:tok:next': 1,
#           'pre:tok:another': 1,
#           'pre:tok:-': 1,
#           'NOT pre:tok:front': 1,
#           'pre:tok:sand': 1,
#           'hyp:tok:something': 1,
#           'pre:tok:two': 1,
#           'pre:tok:blond': 1,
#           'pre:tok:waiting': 1,
#           'NOT pre:tok:doing': 1,
#           'NOT pre:tok:on': 1,
#           'hyp:tok:dancing': 1,
#           'NOT pre:tok:from': 1,
#           'pre:tok:bench': 1,
#           'NOT pre:tok:pink': 1,
#           'NOT pre:tag:vbp': 1,
#           'NOT hyp:tok:driving': 1,
#           'pre:tok:performing': 1,
#           'hyp:tag:cc': 1,
#           'hyp:tok:is': 1,
#           'NOT pre:tok:are': 1,
#           'pre:tok:toward': 1,
#           'pre:tok:orange': 1,
#           'pre:tok:into': 1,
#           'pre:tok:ocean': 1,
#           'NOT pre:tag:prp': 1,
#           'pre:tok:game': 1,
#           'pre:tok:food': 1,
#           'pre:tag:wrb': 1,
#           'pre:tok:held': 1,
#           'NOT pre:tok:camera': 1,
#           'NOT pre:tok:skateboard': 1,
#           'pre:tok:market': 1,
#           'NOT pre:tok:race': 1,
#           'hyp:tag:vbn': 1,
#           'NOT hyp:tag:vbd': 1,
#           'pre:tok:performs': 1,
#           'hyp:tok:pool': 1,
#           'pre:tok:some': 1,
#           'NOT pre:tag:vbz': 1,
#           'pre:tok:long': 1,
#           'NOT pre:tok:jumps': 1,
#           'pre:tok:track': 1}),
#  Counter({'hyp:tok:for': 124,
#           'oth:overlap:overlap50': 120,
#           'hyp:tok:outside': 116,
#           'hyp:tok:sleeping': 113,
#           'NOT oth:overlap:overlap50': 112,
#           'hyp:tok:there': 80,
#           'hyp:tok:outdoors': 80,
#           'hyp:tok:eating': 77,
#           'hyp:tok:tall': 76,
#           'hyp:tok:swimming': 73,
#           'hyp:tok:to': 68,
#           'NOT hyp:tag:prp$': 68,
#           'NOT pre:tok:man': 67,
#           'NOT oth:overlap:overlap25': 64,
#           'NOT hyp:tag:vb': 56,
#           'pre:tok:man': 55,
#           'oth:overlap:overlap75': 55,
#           'NOT hyp:tag:in': 54,
#           'hyp:tok:inside': 53,
#           'NOT hyp:tok:man': 48,
#           'hyp:tok:woman': 47,
#           'NOT pre:tok:woman': 47,
#           'hyp:tag:ex': 46,
#           'hyp:tok:sitting': 46,
#           'hyp:tok:human': 45,
#           'hyp:tok:cat': 39,
#           'pre:tok:woman': 38,
#           'pre:tok:sitting': 38,
#           'pre:tok:girl': 35,
#           'NOT oth:overlap:overlap75': 35,
#           'NOT hyp:tag:vbg': 34,
#           'NOT pre:tag:jj': 34,
#           'hyp:tok:alone': 33,
#           'pre:tag:jj': 33,
#           'NOT hyp:tag:jj': 33,
#           'hyp:tok:running': 32,
#           'hyp:tag:jj': 32,
#           'NOT pre:tok:sitting': 32,
#           'hyp:tag:vb': 32,
#           'NOT hyp:tok:to': 29,
#           'hyp:tok:man': 29,
#           'pre:tok:dog': 28,
#           'oth:overlap:overlap25': 27,
#           'hyp:tok:wearing': 27,
#           'pre:tok:people': 27,
#           'hyp:tok:person': 27,
#           'hyp:tok:walking': 25,
#           'pre:tok:walking': 25,
#           'pre:tok:blue': 24,
#           'pre:tok:pool': 24,
#           'hyp:tag:in': 23,
#           'hyp:tok:women': 22,
#           'hyp:tok:nobody': 22,
#           'hyp:tok:sits': 22,
#           'hyp:tok:football': 22,
#           'NOT pre:tok:for': 21,
#           'hyp:tok:watching': 21,
#           'hyp:tag:nn': 21,
#           'NOT hyp:tok:people': 21,
#           'hyp:tok:about': 20,
#           'pre:tok:women': 19,
#           'pre:tok:girls': 19,
#           'hyp:tok:men': 19,
#           'hyp:tok:indoors': 19,
#           'hyp:tag:nnp': 19,
#           'NOT pre:tok:dog': 18,
#           'NOT hyp:tok:woman': 18,
#           'hyp:tok:sad': 18,
#           'pre:tok:black': 18,
#           'hyp:tok:standing': 18,
#           'NOT hyp:tok:playing': 18,
#           'pre:tok:boy': 17,
#           'pre:tag:in': 17,
#           'NOT hyp:tok:sitting': 16,
#           'hyp:tok:dog': 16,
#           'pre:tok:smiling': 16,
#           'hyp:tag:prp$': 16,
#           'NOT pre:tok:black': 16,
#           'hyp:tok:park': 16,
#           'hyp:tok:asleep': 16,
#           'NOT hyp:tok:outside': 15,
#           'hyp:tok:girl': 15,
#           'hyp:tok:playing': 14,
#           'pre:tok:street': 14,
#           'hyp:tok:people': 14,
#           'hyp:tok:her': 14,
#           'hyp:tok:black': 14,
#           'NOT pre:tok:people': 14,
#           'pre:tok:soccer': 14,
#           'pre:tok:baseball': 13,
#           'NOT pre:tok:blue': 13,
#           'hyp:tok:at': 13,
#           'hyp:tok:something': 13,
#           'hyp:tag:.': 13,
#           'hyp:tok:bike': 12,
#           'pre:tok:bike': 12,
#           'hyp:tok:moon': 12,
#           'pre:tok:snow': 12,
#           'hyp:tok:driving': 12,
#           'hyp:tok:naked': 12,
#           'pre:tok:running': 11,
#           'hyp:tok:blue': 11,
#           'pre:tok:beach': 11,
#           'hyp:tok:water': 11,
#           'hyp:tok:his': 11,
#           'NOT hyp:tag:rb': 10,
#           'pre:tok:park': 10,
#           'NOT pre:tok:to': 10,
#           'hyp:tok:boy': 10,
#           'hyp:tok:after': 10,
#           'pre:tok:bicycle': 10,
#           'pre:tok:food': 10,
#           'hyp:tok:couch': 10,
#           'hyp:tok:dogs': 10,
#           'NOT hyp:tok:men': 10,
#           'pre:tag:nn': 9,
#           'NOT hyp:tok:his': 9,
#           'pre:tok:dogs': 9,
#           'NOT hyp:tok:for': 9,
#           'hyp:tag:prp': 9,
#           'hyp:tok:near': 9,
#           'NOT pre:tok:boy': 9,
#           'hyp:tok:sleeps': 9,
#           'NOT hyp:tok:walking': 9,
#           'pre:tok:water': 9,
#           'pre:tok:red': 9,
#           'NOT pre:tag:cc': 8,
#           'hyp:tok:beach': 8,
#           'pre:tok:standing': 8,
#           'pre:tok:pink': 8,
#           'NOT pre:tok:men': 8,
#           'pre:tok:white': 8,
#           'hyp:tag:dt': 8,
#           'hyp:tok:red': 8,
#           'pre:tok:field': 8,
#           'hyp:tok:home': 7,
#           'pre:tok:men': 7,
#           'pre:tok:baby': 7,
#           'hyp:tok:talking': 7,
#           'pre:tok:air': 7,
#           'hyp:tok:in': 7,
#           'hyp:tok:has': 7,
#           'hyp:tok:party': 7,
#           'pre:tok:performing': 7,
#           'NOT hyp:tag:cd': 7,
#           'pre:tok:something': 7,
#           'NOT pre:tok:girl': 7,
#           'pre:tok:table': 7,
#           'NOT pre:tok:and': 7,
#           'hyp:tok:soccer': 7,
#           'NOT pre:tag:,': 7,
#           'pre:tok:riding': 7,
#           'hyp:tok:friends': 7,
#           'hyp:tok:dancing': 6,
#           'NOT hyp:tok:wearing': 6,
#           'hyp:tok:white': 6,
#           'pre:tok:jumping': 6,
#           'NOT pre:tok:standing': 6,
#           'hyp:tok:their': 6,
#           'pre:tok:sits': 6,
#           'NOT pre:tok:young': 6,
#           'NOT pre:tok:white': 6,
#           'pre:tag:vb': 6,
#           'NOT hyp:tok:boy': 6,
#           'NOT hyp:tok:street': 6,
#           'hyp:tok:riding': 6,
#           'hyp:tok:lady': 6,
#           'pre:tok:her': 6,
#           'pre:tok:talking': 6,
#           'pre:tok:blond': 6,
#           'pre:tok:boat': 6,
#           'pre:tok:skateboard': 6,
#           'pre:tok:large': 5,
#           'pre:tok:working': 5,
#           'pre:tag:dt': 5,
#           'pre:tok:outside': 5,
#           'pre:tok:horse': 5,
#           'pre:tok:bench': 5,
#           'hyp:tok:holding': 5,
#           'NOT pre:tok:wearing': 5,
#           'NOT pre:tok:with': 5,
#           'hyp:tok:shirt': 5,
#           'hyp:tok:wet': 5,
#           'NOT hyp:tok:in': 5,
#           'NOT pre:tok:street': 5,
#           'NOT pre:tok:walking': 5,
#           'hyp:tok:humans': 5,
#           'pre:tag:.': 5,
#           'NOT pre:tag:prp$': 5,
#           'NOT pre:tok:playing': 5,
#           'pre:tok:microphone': 5,
#           'hyp:tok:nap': 5,
#           'hyp:tok:old': 5,
#           'pre:tok:game': 5,
#           'pre:tok:playing': 5,
#           'NOT pre:tok:shirt': 5,
#           'pre:tok:yellow': 5,
#           'hyp:tok:funny': 5,
#           'hyp:tok:is': 5,
#           'NOT pre:tag:vbz': 5,
#           'pre:tok:band': 5,
#           'hyp:tok:dinner': 5,
#           'hyp:tok:competition': 5,
#           'pre:tok:children': 5,
#           'pre:tok:ball': 5,
#           'hyp:tok:smiling': 5,
#           'hyp:tok:baseball': 5,
#           'hyp:tok:walks': 4,
#           'hyp:tok:phone': 4,
#           'pre:tok:football': 4,
#           'pre:tok:race': 4,
#           'pre:tok:car': 4,
#           'pre:tok:brown': 4,
#           'NOT pre:tok:at': 4,
#           'NOT pre:tok:while': 4,
#           'NOT hyp:tag:prp': 4,
#           'hyp:tok:they': 4,
#           'NOT hyp:tok:girl': 4,
#           'NOT pre:tok:red': 4,
#           'hyp:tok:girls': 4,
#           'hyp:tok:game': 4,
#           'hyp:tok:moving': 4,
#           'pre:tok:train': 4,
#           'hyp:tok:eats': 4,
#           'hyp:tag:vbg': 4,
#           'pre:tok:river': 4,
#           'pre:tok:person': 4,
#           'hyp:tok:not': 4,
#           'NOT pre:tag:vb': 4,
#           'pre:tok:stage': 4,
#           'pre:tok:forest': 4,
#           'hyp:tok:three': 4,
#           'NOT pre:tok:green': 3,
#           'hyp:tok:singing': 3,
#           'pre:tok:walk': 3,
#           'pre:tok:dirt': 3,
#           'pre:tok:for': 3,
#           'hyp:tok:horse': 3,
#           'NOT pre:tok:on': 3,
#           'pre:tok:book': 3,
#           'pre:tok:grass': 3,
#           'NOT hyp:tag:vbp': 3,
#           'NOT pre:tag:cd': 3,
#           'NOT hyp:tok:at': 3,
#           'pre:tok:boys': 3,
#           'pre:tok:old': 3,
#           'NOT hyp:tok:group': 3,
#           'pre:tok:construction': 3,
#           'hyp:tok:lunch': 3,
#           'hyp:tok:bed': 3,
#           'hyp:tok:on': 3,
#           'pre:tok:swimming': 3,
#           'hyp:tok:waiting': 3,
#           'pre:tok:dancing': 3,
#           'hyp:tok:train': 3,
#           'pre:tok:lake': 3,
#           'hyp:tok:no': 3,
#           'pre:tok:sidewalk': 3,
#           'NOT pre:tag:vbp': 3,
#           'hyp:tok:school': 3,
#           'hyp:tok:pool': 3,
#           'pre:tok:city': 3,
#           'NOT pre:tok:running': 3,
#           'NOT hyp:tag:nns': 3,
#           'pre:tok:mountain': 3,
#           'hyp:tok:and': 2,
#           'hyp:tok:friend': 2,
#           'pre:tok:through': 2,
#           'hyp:tag:nns': 2,
#           'pre:tok:team': 2,
#           'hyp:tok:bench': 2,
#           'pre:tag:vbg': 2,
#           'pre:tok:bed': 2,
#           'hyp:tok:bowling': 2,
#           'pre:tok:child': 2,
#           'pre:tok:female': 2,
#           'hyp:tok:street': 2,
#           'pre:tok:tree': 2,
#           'NOT hyp:tok:there': 2,
#           'NOT hyp:tok:two': 2,
#           'hyp:tok:eat': 2,
#           'pre:tok:dress': 2,
#           'pre:tag:nnp': 2,
#           'hyp:tok:are': 2,
#           'pre:tok:ride': 2,
#           'pre:tok:wearing': 2,
#           'NOT pre:tok:his': 2,
#           'hyp:tok:jumps': 2,
#           'pre:tag:jjr': 2,
#           'pre:tok:smiles': 2,
#           'hyp:tag:vbz': 2,
#           'pre:tok:restaurant': 2,
#           'hyp:tok:chasing': 2,
#           'pre:tok:climbing': 2,
#           'pre:tok:guitar': 2,
#           'hyp:tok:crowd': 2,
#           'pre:tok:jumps': 2,
#           'hyp:tok:laying': 2,
#           'hyp:tok:bikes': 2,
#           'pre:tok:volleyball': 2,
#           'hyp:tok:fishing': 2,
#           'hyp:tok:son': 2,
#           'hyp:tok:family': 2,
#           'hyp:tok:field': 2,
#           'NOT hyp:tok:on': 2,
#           'hyp:tok:climbing': 2,
#           'pre:tok:walks': 2,
#           'pre:tok:just': 2,
#           'NOT hyp:tok:dog': 2,
#           'pre:tok:eating': 2,
#           'hyp:tok:tv': 2,
#           'hyp:tok:day': 2,
#           'pre:tok:floor': 2,
#           'hyp:tok:bus': 2,
#           'hyp:tok:concert': 2,
#           'hyp:tok:wife': 2,
#           'hyp:tok:player': 2,
#           'hyp:tok:from': 2,
#           'NOT pre:tok:women': 2,
#           'pre:tok:older': 2,
#           'pre:tok:camera': 2,
#           'hyp:tok:couple': 2,
#           'hyp:tok:empty': 2,
#           'pre:tok:green': 2,
#           'pre:tok:runs': 2,
#           'pre:tok:long': 2,
#           'pre:tok:room': 2,
#           'NOT hyp:tok:and': 2,
#           'hyp:tok:reading': 2,
#           'hyp:tok:snow': 2,
#           'NOT pre:tok:race': 2,
#           'pre:tok:tennis': 2,
#           'hyp:tok:bicycle': 2,
#           'hyp:tok:enjoying': 2,
#           'NOT hyp:tok:standing': 2,
#           'hyp:tok:dance': 1,
#           'NOT pre:tok:small': 1,
#           'pre:tok:all': 1,
#           'hyp:tok:some': 1,
#           'hyp:tok:child': 1,
#           'pre:tok:cowboy': 1,
#           'hyp:tok:busy': 1,
#           'pre:tok:crafts': 1,
#           'pre:tok:court': 1,
#           'pre:tok:motorcycle': 1,
#           'pre:tok:waiting': 1,
#           'hyp:tok:lake': 1,
#           'pre:tok:uniforms': 1,
#           'NOT hyp:tag:cc': 1,
#           'pre:tok:crowd': 1,
#           'pre:tok:painting': 1,
#           'pre:tok:shirt': 1,
#           'pre:tok:apartment': 1,
#           'pre:tok:wedding': 1,
#           'hyp:tok:trying': 1,
#           'pre:tok:toddler': 1,
#           'pre:tok:instrument': 1,
#           'hyp:tok:volleyball': 1,
#           'pre:tok:little': 1,
#           'pre:tok:snowy': 1,
#           'hyp:tag:vbp': 1,
#           'hyp:tok:working': 1,
#           'hyp:tok:vacation': 1,
#           'pre:tok:track': 1,
#           'pre:tok:with': 1,
#           'NOT hyp:tok:child': 1,
#           'pre:tok:about': 1,
#           'pre:tok:military': 1,
#           'pre:tok:helmets': 1,
#           'NOT pre:tok:large': 1,
#           'NOT hyp:tok:riding': 1,
#           'hyp:tok:ocean': 1,
#           'pre:tok:into': 1,
#           'NOT pre:tok:camera': 1,
#           'pre:tok:his': 1,
#           'NOT pre:tok:through': 1,
#           'hyp:tok:snowboarder': 1,
#           'hyp:tok:while': 1,
#           'NOT pre:tok:is': 1,
#           'pre:tok:classroom': 1,
#           'hyp:tok:watches': 1,
#           'hyp:tok:road': 1,
#           'pre:tok:four': 1,
#           'NOT pre:tok:three': 1,
#           'NOT hyp:tok:her': 1,
#           'hyp:tok:down': 1,
#           'pre:tok:vendor': 1,
#           'hyp:tok:bald': 1,
#           'pre:tag:nns': 1,
#           'hyp:tok:crying': 1,
#           'hyp:tok:guitar': 1,
#           'pre:tag:vbz': 1,
#           'hyp:tok:performing': 1,
#           'NOT hyp:tok:next': 1,
#           'hyp:tok:married': 1,
#           'pre:tok:fish': 1,
#           'hyp:tok:skateboarder': 1,
#           'hyp:tok:ice': 1,
#           'hyp:tok:new': 1,
#           'NOT pre:tok:sits': 1,
#           'hyp:tok:play': 1,
#           'hyp:tok:another': 1,
#           'pre:tok:chef': 1,
#           'pre:tok:flying': 1,
#           'NOT pre:tok:dressed': 1,
#           'pre:tok:cellphone': 1,
#           'pre:tag:cd': 1,
#           'pre:tok:wooden': 1,
#           'pre:tok:drink': 1,
#           'hyp:tok:rain': 1,
#           'hyp:tok:smoking': 1,
#           'NOT hyp:tok:young': 1,
#           'hyp:tag:pos': 1,
#           'pre:tok:gray': 1,
#           'NOT hyp:tok:black': 1,
#           'pre:tok:suit': 1,
#           'hyp:tok:floor': 1,
#           'hyp:tok:one': 1,
#           'pre:tok:during': 1,
#           'pre:tok:sunglasses': 1,
#           'hyp:tok:jumping': 1,
#           'NOT pre:tok:beach': 1,
#           'hyp:tok:baby': 1,
#           'hyp:tok:holds': 1,
#           'hyp:tok:before': 1,
#           'hyp:tok:tree': 1,
#           'pre:tok:swing': 1,
#           'pre:tok:home': 1,
#           'pre:tok:sun': 1,
#           'pre:tok:sand': 1,
#           'hyp:tok:pink': 1,
#           'pre:tok:mountains': 1,
#           'hyp:tok:stage': 1,
#           'hyp:tok:kids': 1,
#           'hyp:tok:dead': 1,
#           'pre:tok:market': 1,
#           'hyp:tok:mountain': 1,
#           'pre:tag:cc': 1,
#           'pre:tok:kitchen': 1,
#           'pre:tok:dance': 1,
#           'pre:tok:down': 1,
#           'NOT hyp:tag:nn': 1,
#           'hyp:tag:md': 1,
#           'pre:tok:stands': 1,
#           'pre:tok:wall': 1,
#           'pre:tok:mcdonald': 1,
#           'pre:tok:ocean': 1,
#           'hyp:tok:someone': 1,
#           'pre:tok:desk': 1,
#           'pre:tok:holding': 1,
#           'hyp:tok:boys': 1,
#           'pre:tok:and': 1,
#           'NOT pre:tok:crowd': 1,
#           'pre:tok:elderly': 1,
#           'hyp:tok:runs': 1,
#           'NOT hyp:tok:are': 1,
#           'hyp:tok:stand': 1,
#           'hyp:tok:taking': 1,
#           'pre:tok:jeans': 1,
#           'hyp:tok:next': 1,
#           'pre:tok:bus': 1,
#           'hyp:tok:biker': 1,
#           'hyp:tok:it': 1,
#           'pre:tok:conversation': 1,
#           'hyp:tok:championship': 1,
#           'pre:tok:colorful': 1,
#           'hyp:tok:basketball': 1,
#           'NOT hyp:tok:with': 1,
#           'hyp:tok:local': 1,
#           'pre:tok:he': 1,
#           'NOT hyp:tok:beach': 1,
#           'hyp:tok:skier': 1,
#           'pre:tok:reading': 1,
#           'hyp:tok:break': 1,
#           'pre:tok:basketball': 1,
#           'pre:tok:watches': 1,
#           'hyp:tok:brown': 1,
#           'pre:tok:singing': 1,
#           'hyp:tok:green': 1,
#           'hyp:tok:first': 1,
#           'hyp:tok:boat': 1,
#           'hyp:tok:hat': 1,
#           'pre:tok:racing': 1,
#           'hyp:tok:painting': 1,
#           'hyp:tok:children': 1,
#           'pre:tok:gentleman': 1,
#           'pre:tok:rock': 1,
#           'pre:tok:sled': 1,
#           'hyp:tok:just': 1,
#           'NOT pre:tok:her': 1,
#           'pre:tok:doing': 1,
#           'NOT pre:tok:ball': 1,
#           'pre:tok:wading': 1,
#           'NOT pre:tok:water': 1,
#           'hyp:tok:vehicle': 1,
#           'hyp:tok:doing': 1,
#           'hyp:tok:least': 1,
#           'pre:tok:him': 1,
#           'NOT hyp:tok:person': 1,
#           'hyp:tok:animals': 1,
#           'pre:tok:meal': 1,
#           'NOT pre:tag:rb': 1,
#           'NOT pre:tag:vbn': 1,
#           'pre:tok:looking': 1,
#           'pre:tok:sit': 1,
#           'pre:tok:helmet': 1,
#           'pre:tok:hockey': 1,
#           'pre:tok:slide': 1,
#           'hyp:tok:cooking': 1,
#           'pre:tok:trick': 1,
#           'hyp:tok:sidewalk': 1,
#           'hyp:tok:cake': 1,
#           'hyp:tok:shopping': 1,
#           'hyp:tok:competing': 1,
#           'pre:tok:purse': 1,
#           'pre:tok:brunette': 1,
#           'hyp:tok:she': 1,
#           'hyp:tok:house': 1,
#           'NOT pre:tok:in': 1,
#           'hyp:tok:market': 1,
#           'NOT hyp:tok:shirt': 1,
#           'pre:tok:canoe': 1,
#           'pre:tok:cooking': 1,
#           'hyp:tok:bar': 1,
#           'pre:tok:snowboarder': 1,
#           'hyp:tok:else': 1,
#           'pre:tok:outfit': 1,
#           'pre:tag:rb': 1,
#           'NOT pre:tok:child': 1,
#           'NOT pre:tok:children': 1,
#           'NOT hyp:tok:running': 1,
#           'hyp:tok:bathroom': 1,
#           'hyp:tok:walk': 1,
#           'pre:tok:at': 1}),
#  Counter({'pre:tag:nn': 448,
#           'hyp:tag:nn': 203,
#           'NOT hyp:tok:outside': 182,
#           'oth:overlap:overlap25': 166,
#           'NOT oth:overlap:overlap75': 100,
#           'pre:tag:jj': 100,
#           'hyp:tag:dt': 91,
#           'NOT hyp:tok:outdoors': 91,
#           'hyp:tag:vbg': 90,
#           'NOT hyp:tok:sleeping': 82,
#           'pre:tag:.': 69,
#           'pre:tag:in': 65,
#           'pre:tag:dt': 63,
#           'NOT hyp:tok:tall': 61,
#           'NOT hyp:tok:wearing': 61,
#           'NOT oth:overlap:overlap50': 56,
#           'hyp:tag:in': 53,
#           'NOT hyp:tok:nobody': 51,
#           'NOT pre:tok:dog': 48,
#           'pre:tok:woman': 45,
#           'NOT hyp:tok:for': 44,
#           'NOT hyp:tok:there': 44,
#           'NOT pre:tok:sitting': 38,
#           'NOT hyp:tok:eating': 38,
#           'NOT pre:tok:walking': 37,
#           'NOT hyp:tok:sitting': 36,
#           'oth:overlap:overlap50': 35,
#           'NOT hyp:tok:swimming': 34,
#           'NOT hyp:tok:person': 34,
#           'hyp:tag:nns': 33,
#           'pre:tok:man': 33,
#           'NOT pre:tok:girl': 31,
# ...
#           'pre:tok:up': 1,
#           'NOT hyp:tok:dancing': 1,
#           'NOT hyp:tok:has': 1,
#           'pre:tok:down': 1,
#           'NOT pre:tok:yellow': 1,
#           'NOT pre:tok:guitar': 1,
#           'NOT pre:tok:riding': 1,
#           'pre:tok:behind': 1,
#           'NOT hyp:tok:with': 1,
#           'pre:tok:yellow': 1,
#           'pre:tok:room': 1,
#           'pre:tok:performing': 1,
#           'hyp:tok:food': 1,
#           'pre:tok:bike': 1,
#           'hyp:tok:street': 1,
#           'pre:tok:runs': 1,
#           'NOT hyp:tok:are': 1,
#           'NOT hyp:tok:getting': 1,
#           'NOT hyp:tok:building': 1,
#           'NOT pre:tok:train': 1,
#           'NOT pre:tok:walks': 1,
#           'pre:tok:reading': 1,
#           'pre:tok:holding': 1,
#           'hyp:tok:while': 1,
#           'hyp:tok:snow': 1,
#           'pre:tok:female': 1,
#           'pre:tok:sits': 1,
#           'NOT pre:tok:grass': 1,
#           'NOT pre:tok:skateboard': 1,
#           'hyp:tok:taking': 1,
#           'hyp:tag:prp': 1,
#           'pre:tag:nns': 1,
#           'NOT pre:tok:sits': 1,
#           'hyp:tok:horse': 1,
#           'pre:tok:rock': 1,
#           'hyp:tok:not': 1,
#           'NOT pre:tok:table': 1,
#           'NOT pre:tok:has': 1,
#           'pre:tok:front': 1,
#           'pre:tok:person': 1,
#           'NOT pre:tok:smiling': 1,
#           'NOT hyp:tok:dogs': 1,
#           'pre:tok:back': 1}),
#  Counter({'hyp:tok:outside': 132,
#           'oth:overlap:overlap75': 113,
#           'hyp:tok:outdoors': 105,
#           'hyp:tok:for': 105,
#           'hyp:tok:tall': 88,
#           'hyp:tok:sleeping': 87,
#           'hyp:tok:there': 86,
#           'oth:overlap:overlap50': 81,
#           'hyp:tok:to': 75,
#           'hyp:tok:eating': 66,
#           'hyp:tok:swimming': 65,
#           'hyp:tag:ex': 64,
#           'NOT oth:overlap:overlap50': 63,
#           'NOT hyp:tag:prp$': 57,
#           'hyp:tok:cat': 52,
#           'pre:tok:man': 48,
#           'NOT pre:tok:woman': 44,
#           'NOT hyp:tok:to': 43,
#           'hyp:tok:nobody': 40,
#           'hyp:tok:sitting': 39,
#           'pre:tok:dog': 37,
#           'NOT hyp:tag:vbg': 36,
#           'hyp:tok:running': 36,
#           'NOT pre:tok:man': 33,
#           'hyp:tok:woman': 32,
#           'hyp:tok:alone': 32,
#           'hyp:tok:riding': 32,
#           'NOT hyp:tok:man': 32,
#           'pre:tok:pool': 31,
#           'pre:tok:sitting': 31,
#           'hyp:tok:asleep': 31,
#           'hyp:tok:park': 29,
#           'pre:tok:black': 29,
#           'hyp:tok:soccer': 28,
#           'NOT hyp:tag:vb': 28,
#           'NOT pre:tok:walking': 27,
#           'hyp:tok:inside': 27,
#           'hyp:tok:human': 27,
#           'hyp:tok:something': 25,
#           'hyp:tok:bike': 25,
#           'hyp:tok:his': 25,
#           'NOT hyp:tag:in': 24,
#           'hyp:tok:walking': 22,
#           'pre:tok:blue': 22,
#           'pre:tok:walking': 22,
#           'hyp:tag:in': 22,
#           'NOT oth:overlap:overlap75': 22,
#           'NOT oth:overlap:overlap25': 21,
#           'hyp:tok:football': 21,
#           'pre:tok:running': 20,
#           'pre:tok:beach': 20,
#           'hyp:tok:man': 20,
#           'hyp:tok:dancing': 19,
#           'pre:tok:snow': 19,
#           'hyp:tok:horse': 19,
#           'pre:tok:football': 18,
#           'hyp:tok:person': 18,
#           'hyp:tok:playing': 17,
#           'hyp:tok:water': 17,
#           'hyp:tok:race': 17,
#           'NOT pre:tok:dog': 16,
#           'NOT pre:tok:sitting': 16,
#           'pre:tok:soccer': 16,
#           'pre:tok:woman': 16,
#           'pre:tok:red': 15,
#           'NOT hyp:tag:jj': 15,
#           'NOT hyp:tok:woman': 15,
#           'pre:tok:boy': 15,
#           'hyp:tag:prp$': 15,
#           'hyp:tok:men': 15,
#           'hyp:tok:concert': 14,
#           'hyp:tok:wearing': 14,
#           'hyp:tok:her': 14,
#           'hyp:tok:sad': 14,
#           'pre:tok:water': 14,
#           'pre:tok:pink': 14,
#           'oth:overlap:overlap25': 14,
#           'pre:tok:girl': 14,
#           'hyp:tok:blue': 13,
#           'hyp:tok:indoors': 13,
#           'hyp:tok:girl': 13,
#           'hyp:tok:near': 13,
#           'pre:tok:singing': 13,
#           'hyp:tok:beach': 13,
#           'pre:tag:jj': 13,
#           'pre:tok:mountain': 13,
#           'hyp:tok:at': 12,
#           'pre:tok:baseball': 12,
#           'hyp:tok:driving': 11,
#           'hyp:tok:party': 11,
#           'pre:tok:bicycle': 11,
#           'hyp:tok:friends': 11,
#           'hyp:tok:couch': 11,
#           'pre:tok:horse': 11,
#           'pre:tok:playing': 11,
#           'hyp:tok:standing': 11,
#           'hyp:tok:black': 11,
#           'pre:tok:guitar': 11,
#           'hyp:tok:after': 11,
#           'pre:tok:men': 10,
#           'NOT pre:tok:to': 10,
#           'NOT pre:tok:for': 10,
#           'pre:tok:stage': 10,
#           'pre:tok:bike': 10,
#           'pre:tok:girls': 10,
#           'pre:tok:dancing': 10,
#           'hyp:tok:people': 10,
#           'hyp:tok:home': 10,
#           'NOT pre:tok:street': 9,
#           'hyp:tok:sits': 9,
#           'pre:tok:dogs': 9,
#           'NOT hyp:tok:sitting': 9,
#           'hyp:tok:dinner': 9,
#           'NOT hyp:tok:walking': 9,
#           'pre:tok:park': 9,
#           'pre:tok:sleeping': 9,
#           'hyp:tok:boy': 9,
#           'hyp:tok:school': 8,
#           'pre:tok:smiling': 8,
#           'hyp:tok:watching': 8,
#           'hyp:tok:dog': 8,
#           'NOT pre:tok:black': 8,
#           'pre:tok:women': 8,
#           'pre:tok:table': 8,
#           'pre:tag:in': 8,
#           'pre:tok:bench': 8,
#           'pre:tok:book': 8,
#           'hyp:tok:snow': 8,
#           'pre:tok:room': 8,
#           'pre:tok:microphone': 7,
#           'pre:tok:car': 7,
#           'hyp:tok:dogs': 7,
#           'pre:tok:green': 7,
#           'hyp:tok:red': 7,
#           'pre:tok:cooking': 7,
#           'pre:tok:dance': 7,
#           'NOT pre:tok:girl': 7,
#           'NOT hyp:tok:girl': 7,
#           'pre:tok:food': 7,
#           'pre:tok:race': 6,
#           'hyp:tok:holding': 6,
#           'hyp:tok:competition': 6,
#           'NOT pre:tag:vb': 6,
#           'hyp:tag:nn': 6,
#           'NOT pre:tok:standing': 6,
#           'pre:tok:microscope': 6,
#           'hyp:tok:boat': 6,
#           'hyp:tok:racing': 6,
#           'pre:tok:talking': 6,
#           'hyp:tok:old': 6,
#           'NOT pre:tok:red': 6,
#           'pre:tok:sand': 6,
#           'pre:tok:skateboard': 6,
#           'NOT hyp:tok:his': 6,
#           'pre:tok:painting': 6,
#           'hyp:tok:food': 6,
#           'hyp:tok:game': 6,
#           'pre:tok:sits': 6,
#           'hyp:tok:is': 6,
#           'pre:tok:bed': 6,
#           'NOT hyp:tok:people': 6,
#           'hyp:tok:wet': 6,
#           'hyp:tok:reading': 6,
#           'hyp:tok:lunch': 6,
#           'hyp:tok:tv': 6,
#           'pre:tok:cowboy': 6,
#           'hyp:tok:women': 6,
#           'hyp:tok:instrument': 6,
#           'hyp:tok:bicycle': 5,
#           'hyp:tok:band': 5,
#           'hyp:tok:guitar': 5,
#           'pre:tok:riding': 5,
#           'hyp:tok:sleeps': 5,
#           'hyp:tok:tennis': 5,
#           'hyp:tok:flowers': 5,
#           'pre:tok:in': 5,
#           'NOT pre:tok:blue': 5,
#           'NOT hyp:tag:rb': 5,
#           'pre:tok:band': 5,
#           'hyp:tok:laying': 5,
#           'hyp:tok:basketball': 5,
#           'hyp:tok:baseball': 5,
#           'NOT pre:tok:running': 5,
#           'hyp:tok:car': 5,
#           'NOT pre:tag:jj': 5,
#           'hyp:tok:about': 5,
#           'pre:tok:field': 5,
#           'hyp:tag:jj': 5,
#           'pre:tok:working': 5,
#           'hyp:tok:birthday': 5,
#           'pre:tok:grass': 4,
#           'NOT pre:tok:wearing': 4,
#           'pre:tok:street': 4,
#           'hyp:tok:competing': 4,
#           'pre:tok:brown': 4,
#           'NOT pre:tok:men': 4,
#           'hyp:tok:grass': 4,
#           'hyp:tok:skateboard': 4,
#           'NOT hyp:tok:at': 4,
#           'hyp:tok:eats': 4,
#           'NOT hyp:tok:black': 4,
#           'hyp:tok:white': 4,
#           'hyp:tok:sand': 4,
#           'NOT pre:tag:prp$': 4,
#           'hyp:tok:performing': 4,
#           'pre:tok:kitchen': 4,
#           'hyp:tok:shopping': 4,
#           'hyp:tag:.': 4,
#           'hyp:tok:pool': 4,
#           'pre:tok:boys': 4,
#           'NOT pre:tag:cc': 4,
#           'pre:tok:walks': 4,
#           'pre:tok:river': 4,
#           'pre:tok:ball': 4,
#           'hyp:tok:naked': 4,
#           'pre:tok:sidewalk': 4,
#           'hyp:tok:singing': 4,
#           'pre:tok:train': 4,
#           'pre:tok:tennis': 4,
#           'hyp:tok:train': 4,
#           'hyp:tok:funny': 4,
#           'pre:tok:restaurant': 4,
#           'pre:tok:yellow': 4,
#           'hyp:tok:new': 4,
#           'pre:tok:store': 4,
#           'hyp:tok:music': 4,
#           'pre:tok:swimming': 4,
#           'pre:tok:cart': 4,
#           'pre:tok:children': 4,
#           'pre:tok:performing': 4,
#           'NOT pre:tok:at': 4,
#           'hyp:tok:are': 3,
#           'NOT pre:tok:playing': 3,
#           'hyp:tok:talking': 3,
#           'NOT pre:tok:people': 3,
#           'pre:tok:ocean': 3,
#           'pre:tok:walk': 3,
#           'pre:tok:runs': 3,
#           'hyp:tok:couple': 3,
#           'hyp:tok:restaurant': 3,
#           'pre:tok:snowboarder': 3,
#           'pre:tok:track': 3,
#           'hyp:tok:girls': 3,
#           'NOT hyp:tok:wearing': 3,
#           'hyp:tag:dt': 3,
#           'pre:tok:game': 3,
#           'pre:tok:tree': 3,
#           'pre:tok:shirt': 3,
#           'pre:tok:white': 3,
#           'hyp:tok:moon': 3,
#           'hyp:tok:nap': 3,
#           'pre:tok:orange': 3,
#           'NOT hyp:tok:her': 3,
#           'hyp:tok:no': 3,
#           'pre:tok:basketball': 3,
#           'hyp:tok:brown': 3,
#           'hyp:tok:snowboarder': 3,
#           'pre:tok:people': 3,
#           'pre:tok:standing': 3,
#           'hyp:tok:kids': 3,
#           'pre:tok:market': 3,
#           'pre:tok:eating': 3,
#           'pre:tok:hockey': 3,
#           'pre:tok:her': 3,
#           'hyp:tok:holds': 3,
#           'hyp:tok:cooking': 3,
#           'pre:tok:air': 3,
#           'NOT pre:tok:boy': 3,
#           'pre:tok:cellphone': 3,
#           'NOT pre:tag:,': 3,
#           'hyp:tok:going': 3,
#           'hyp:tag:vb': 3,
#           'hyp:tok:bikes': 2,
#           'hyp:tok:stage': 2,
#           'hyp:tok:street': 2,
#           'hyp:tok:store': 2,
#           'hyp:tok:bus': 2,
#           'NOT hyp:tok:street': 2,
#           'NOT hyp:tok:person': 2,
#           'hyp:tok:walks': 2,
#           'NOT hyp:tok:playing': 2,
#           'NOT hyp:tok:outside': 2,
#           'pre:tok:swing': 2,
#           'NOT hyp:tok:for': 2,
#           'pre:tok:shirtless': 2,
#           'hyp:tok:jumping': 2,
#           'hyp:tok:tired': 2,
#           'pre:tok:city': 2,
#           'NOT pre:tok:young': 2,
#           'hyp:tok:sleep': 2,
#           'NOT hyp:tok:in': 2,
#           'NOT hyp:tok:standing': 2,
#           'pre:tok:baby': 2,
#           'pre:tok:and': 2,
#           'hyp:tok:enjoying': 2,
#           'hyp:tag:nnp': 2,
#           'pre:tok:classroom': 2,
#           'hyp:tok:humans': 2,
#           'hyp:tok:fire': 2,
#           'pre:tok:dirt': 2,
#           'hyp:tok:looking': 2,
#           'hyp:tok:skateboarder': 2,
#           'pre:tok:asian': 2,
#           'hyp:tok:on': 2,
#           'hyp:tok:cake': 2,
#           'NOT hyp:tok:on': 2,
#           'hyp:tok:sit': 2,
#           'pre:tag:dt': 2,
#           'hyp:tok:frisbee': 2,
#           'pre:tok:boat': 2,
#           'pre:tok:older': 2,
#           'hyp:tok:crowd': 2,
#           'hyp:tok:in': 2,
#           'pre:tok:skateboarder': 2,
#           'pre:tok:purple': 2,
#           'pre:tok:laying': 2,
#           'hyp:tok:fishing': 2,
#           'pre:tok:flowers': 2,
#           'NOT pre:tag:vbp': 2,
#           'pre:tok:racing': 2,
#           'pre:tok:gathered': 2,
#           'NOT hyp:tag:cd': 2,
#           'pre:tok:blond': 2,
#           'NOT hyp:tok:men': 2,
#           'NOT hyp:tag:cc': 2,
#           'hyp:tok:not': 2,
#           'hyp:tok:ice': 2,
#           'hyp:tok:vacation': 2,
#           'pre:tok:couple': 1,
#           'hyp:tok:daughter': 1,
#           'hyp:tok:chasing': 1,
#           'pre:tok:floor': 1,
#           'pre:tag:vbg': 1,
#           'hyp:tok:mud': 1,
#           'hyp:tok:smiling': 1,
#           'pre:tok:grassy': 1,
#           'hyp:tok:bar': 1,
#           'pre:tok:violin': 1,
#           'pre:tok:racket': 1,
#           'hyp:tok:green': 1,
#           'pre:tok:truck': 1,
#           'pre:tok:snowboarding': 1,
#           'pre:tok:crowd': 1,
#           'pre:tok:team': 1,
#           'pre:tok:wear': 1,
#           'pre:tok:apron': 1,
#           'hyp:tok:through': 1,
#           'hyp:tok:young': 1,
#           'NOT pre:tok:yellow': 1,
#           'hyp:tok:sisters': 1,
#           'NOT hyp:tok:dog': 1,
#           'hyp:tok:movie': 1,
#           'NOT pre:tok:her': 1,
#           'hyp:tok:break': 1,
#           'NOT pre:tok:table': 1,
#           'pre:tok:police': 1,
#           'hyp:tok:drives': 1,
#           'pre:tok:podium': 1,
#           'pre:tok:jumping': 1,
#           'pre:tok:down': 1,
#           'hyp:tok:tricks': 1,
#           'hyp:tok:hat': 1,
#           'pre:tok:rocky': 1,
#           'pre:tok:paper': 1,
#           'pre:tok:writes': 1,
#           'NOT pre:tag:vbn': 1,
#           'pre:tok:sunglasses': 1,
#           'hyp:tok:ocean': 1,
#           'NOT hyp:tok:there': 1,
#           'NOT hyp:tok:their': 1,
#           'pre:tok:woods': 1,
#           'pre:tok:ice': 1,
#           'hyp:tok:christmas': 1,
#           'pre:tok:shoulder': 1,
#           'hyp:tok:swim': 1,
#           'pre:tok:group': 1,
#           'hyp:tok:house': 1,
#           'pre:tok:are': 1,
#           'pre:tok:outside': 1,
#           'hyp:tok:waiting': 1,
#           'pre:tok:uniforms': 1,
#           'hyp:tok:drinking': 1,
#           'pre:tok:jumps': 1,
#           'NOT pre:tok:water': 1,
#           'pre:tok:for': 1,
#           'pre:tok:fish': 1,
#           'hyp:tok:stick': 1,
#           'hyp:tok:coffee': 1,
#           'hyp:tok:cats': 1,
#           'hyp:tok:selling': 1,
#           'pre:tok:dark': 1,
#           'hyp:tok:animal': 1,
#           'hyp:tok:day': 1,
#           'hyp:tok:children': 1,
#           'pre:tok:hat': 1,
#           'NOT pre:tok:white': 1,
#           'hyp:tok:phone': 1,
#           'pre:tok:holding': 1,
#           'pre:tok:drinking': 1,
#           'pre:tok:volleyball': 1,
#           'pre:tok:having': 1,
#           'hyp:tok:motorcycle': 1,
#           'NOT hyp:tag:nn': 1,
#           'pre:tok:suit': 1,
#           'pre:tok:waiting': 1,
#           'NOT hyp:tok:next': 1,
#           'hyp:tok:empty': 1,
#           'pre:tok:ride': 1,
#           'hyp:tok:room': 1,
#           'hyp:tok:working': 1,
#           'hyp:tok:shirt': 1,
#           'pre:tok:something': 1,
#           'pre:tok:doing': 1,
#           'hyp:tok:he': 1,
#           'NOT hyp:tok:running': 1,
#           'hyp:tok:construction': 1,
#           'hyp:tok:another': 1,
#           'pre:tok:sit': 1,
#           'pre:tok:lying': 1,
#           'hyp:tok:lake': 1,
#           'pre:tok:bowling': 1,
#           'NOT pre:tok:beach': 1,
#           'pre:tok:child': 1,
#           'pre:tok:cake': 1,
#           'NOT pre:tag:nnp': 1,
#           'NOT pre:tok:group': 1,
#           'pre:tok:reading': 1,
#           'pre:tok:snowy': 1,
#           'pre:tok:trick': 1,
#           'pre:tok:plays': 1,
#           'pre:tok:sweater': 1,
#           'hyp:tok:has': 1,
#           'hyp:tok:dance': 1,
#           'pre:tok:play': 1,
#           'hyp:tok:walk': 1,
#           'pre:tok:kids': 1,
#           'NOT hyp:tok:red': 1,
#           'hyp:tok:kitchen': 1,
#           'NOT pre:tok:women': 1,
#           'NOT hyp:tag:vbn': 1,
#           'hyp:tok:wedding': 1,
#           'hyp:tok:martial': 1,
#           'pre:tok:motorcycle': 1,
#           'pre:tok:home': 1,
#           'NOT hyp:tok:boy': 1,
#           'hyp:tok:falls': 1,
#           'hyp:tok:horses': 1,
#           'pre:tok:desk': 1,
#           'pre:tok:headphones': 1,
#           'NOT hyp:tok:car': 1,
#           'hyp:tok:field': 1,
#           'NOT hyp:tag:nnp': 1,
#           'pre:tok:preparing': 1,
#           'pre:tok:wave': 1,
#           'hyp:tok:as': 1,
#           'pre:tok:hair': 1,
#           'hyp:tok:painting': 1,
#           'NOT hyp:tok:women': 1,
#           'NOT hyp:tok:water': 1,
#           'pre:tok:dress': 1,
#           'pre:tok:building': 1,
#           'pre:tok:rocks': 1,
#           'pre:tok:young': 1,
#           'pre:tok:trunks': 1,
#           'hyp:tok:rock': 1,
#           'NOT hyp:tok:are': 1,
#           'hyp:tok:their': 1})]

# %% [markdown]
# **OLD**

# %%
import spacy
nlp = spacy.load("en_core_web_sm")  # large model, trained on huge corpus

doc = nlp("sand")
for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# sand VERB VB

# %%
import nltk
from nltk.corpus import wordnet as wn
from collections import defaultdict

# Ensure resources are downloaded
nltk.download("wordnet")
nltk.download("omw-1.4")

# Mapping WordNet lexnames (supersenses) to semantic categories
SUPERSENSE_TO_CATEGORY = {
    # Verbs
    "verb.motion": "actions",
    "verb.contact": "actions",
    "verb.consumption": "actions",
    "verb.stative": "states",
    "verb.perception": "states",

    # Nouns
    "noun.location": "locations",
    "noun.person": "entities",
    "noun.animal": "entities",
    "noun.artifact": "entities",
    "noun.object": "entities",
    "noun.food": "entities",
    "noun.substance": "entities",

    # Adjectives
    "adj.all": "attributes",
    "adj.pert": "attributes"
}

def get_word_pos_set(word):
    """Return all POS in WordNet for this word"""
    pos_set = set()
    for pos in [wn.NOUN, wn.VERB, wn.ADJ, wn.ADV]:
        if wn.synsets(word, pos=pos):
            pos_set.add(pos)
    return pos_set

def categorize_word(word):
    pos_set = get_word_pos_set(word)
    
    # No synsets at all → abstract
    if not pos_set:
        return "abstract"
    
    # Multiple POS → ambiguous → abstract
    if len(pos_set) > 1:
        for i in range(len(pos_set)):
            pos_set.update(get_word_pos_set(word))
        print(Counter(pos_set))
        
    
    # Single POS → pick dominant sense (first synset)
    pos = pos_set.pop()
    synset = wn.synsets(word, pos=pos)[0]
    lexname = synset.lexname()
    return SUPERSENSE_TO_CATEGORY.get(lexname, "abstract")

def categorize_words(words):
    categories = defaultdict(list)
    for word in words:
        cat = categorize_word(word.lower())
        categories[cat].append(word)
    return dict(categories)

# Example usage
words = [
    "running", "swimming", "sleeping", "asleep",
    "inside", "outside", "outdoors",
    "person", "people", "dog", "cat",
    "tall", "blue",
    "to", "for", "they", "is",
    "horse", "sand"
]

result = categorize_words(words)
print(result)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 77
#      67 # Example usage
#      68 words = [
#      69     "running", "swimming", "sleeping", "asleep",
#      70     "inside", "outside", "outdoors",
#    (...)
#      74     "horse", "sand"
#      75 ]
# ---> 77 result = categorize_words(words)
#      78 print(result)
#
# Cell In[61], line 63, in categorize_words(words)
#      61 categories = defaultdict(list)
#      62 for word in words:
# ---> 63     cat = categorize_word(word.lower())
#      64     categories[cat].append(word)
#      65 return dict(categories)
#
# Cell In[61], line 51, in categorize_word(word)
#      49     for i in range(len(pos_set)):
#      50         pos_set.update(get_word_pos_set(word))
# ---> 51     print(Counter(pos_set))
#      54 # Single POS → pick dominant sense (first synset)
#      55 pos = pos_set.pop()
#
# NameError: name 'Counter' is not defined
